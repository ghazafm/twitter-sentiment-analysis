# %%
import pickle
import pandas as pd
import Funct_modelling
# Out:
# /var/folders/4f/xq7119ld627_2wyd6dkmwl0m0000gn/T/ipykernel_19921/3669787247.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df1 = pd.read_csv('../scraping/result/anis/anis_mei012023_juni302023.csv')
df2 = pd.read_csv('../scraping/result/anis/anis_juli012023_agustus312023.csv')
df3 = pd.read_csv('../scraping/result/anis/anis_september012023_oktober312023.csv')
df4 = pd.read_csv('../scraping/result/anis/anis_november012023_desember312023.csv')
df5 = pd.read_csv('../scraping/result/anis/anis_januari012024_februari292024.csv')
df = pd.concat([df1,df2,df3,df4,df5])

# %%
df['created_at'] = df['created_at'].apply(Funct_modelling.extract_date)

# %%
df = df[['created_at','user_id_str','username','tweet_url','no_tag']]

# %%
df['Tweet'] = df['no_tag']
df.drop('no_tag',axis=1,inplace=True)

# %%
df = Funct_modelling.clean_text(df,tag=True)
# Out:
# clean_text
# no_double
# no_alay
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df = Funct_modelling.clean_text(df,tag=True)
#
# File ~/Coding/SocialMediaSentiment/implement/Funct_modelling.py:281, in clean_text(data, tag)
#     278 data["no_double"] = data["clean_text"].apply(clear_double)
#     280 print("no_alay")
# --> 281 data["no_alay"] = data["no_double"].apply(clear_alay)
#     283 if tag:
#     284     print("pos_tag")
#
# File ~/miniconda3/envs/bismillah/lib/python3.10/site-packages/pandas/core/series.py:4904, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4769 def apply(
#    4770     self,
#    4771     func: AggFuncType,
#    (...)
#    4776     **kwargs,
#    4777 ) -> DataFrame | Series:
#    4778     """
#    4779     Invoke function on values of Series.
#    4780
#    (...)
#    4895     dtype: float64
# ...

# %%
model = pickle.load(open('../model/tag/pickle/NaiveBayes_Tag.pkl','rb'))
