# %% [markdown]
# Desember 2022 - April 2023

# %%
#@title Twitter Auth Token

twitter_auth_token = '88419bb735b02f989454300432e32024268ba877'

# %%
# Crawl Data
filename = 'anies.csv'
search_keyword = 'anies presiden indonesia 2024 lang:id until:2023-12-31 since:2023-11-01'
limit = 4000

# !npx --yes tweet-harvest@2.2.8 -o "{filename}" -s "{search_keyword}" -l {limit} --token {twitter_auth_token}
# Out:
# Welcome to the Twitter Crawler 🕷️
#
# This script uses Chromium Browser to crawl data from Twitter with *your* Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
# m#########⠂⠂⠂⠂⠂⠂⠂⠂⠂) ⠏ idealTree: timing idealTree Completed in 1693ms
# up to date, audited 5 packages in 2s
#
# found 0 vulnerabilities
#
# Opening twitter search page...
#
#
# Found existing file ./tweets-data/anies.csv, renaming to ./tweets-data/anies.old.csv
#
# Filling in keywords: anies presiden indonesia 2024 lang:id until:2023-12-31 since:2023-11-01
#
#
# Got some tweets, saving to file...
# Error parsing response json: {"_type":"Response","_guid":"response@1754c13d4cc947154d89e99893cc47a4"}
# Most likely, you have already exceeded the Twitter rate limit. Read more on https://twitter.com/elonmusk/status/1675187969420828672?s=46.
#
# Got some tweets, saving to file...
# Error parsing response json: {"_type":"Response","_guid":"response@ffe0e0915cb89d8ae3a0d6ca5c988f14"}
# Most likely, you have already exceeded the Twitter rate limit. Read more on https://twitter.com/elonmusk/status/1675187969420828672?s=46.
# ^C
# page.waitForTimeout: Target page, context or browser has been closed
#     at /Users/fauzanghaza/.npm/_npx/006edd9c57a6e29b/node_modules/tweet-harvest/dist/crawl.js:158:79
#     at step (/Users/fauzanghaza/.npm/_npx/006edd9c57a6e29b/node_modules/tweet-harvest/dist/crawl.js:56:23)
#     at Object.next (/Users/fauzanghaza/.npm/_npx/006edd9c57a6e29b/node_modules/tweet-harvest/dist/crawl.js:37:53)
#     at step (/Users/fauzanghaza/.npm/_npx/006edd9c57a6e29b/node_modules/tweet-harvest/dist/crawl.js:41:139)
#     at Object.next (/Users/fauzanghaza/.npm/_npx/006edd9c57a6e29b/node_modules/tweet-harvest/dist/crawl.js:37:53)
#     at fulfilled (/Users/fauzanghaza/.npm/_npx/006edd9c57a6e29b/node_modules/tweet-harvest/dist/crawl.js:28:58)
# Keywords: anies presiden indonesia 2024 lang:id until:2023-12-31 since:2023-11-01
# Twitter Harvest v 2.2.8
# node:internal/process/promises:289
#             triggerUncaughtException(err, true /* fromPromise */);
#             ^
#
# page.screenshot: Target page, context or browser has been closed
#     at /Users/fauzanghaza/.npm/_npx/006edd9c57a6e29b/node_modules/tweet-harvest/dist/crawl.js:437:47
#     at step (/Users/fauzanghaza/.npm/_npx/006edd9c57a6e29b/node_modules/tweet-harvest/dist/crawl.js:56:23)
#     at Object.throw (/Users/fauzanghaza/.npm/_npx/006edd9c57a6e29b/node_modules/tweet-harvest/dist/crawl.js:37:53)
#     at rejected (/Users/fauzanghaza/.npm/_npx/006edd9c57a6e29b/node_modules/tweet-harvest/dist/crawl.js:29:65)
#
# Node.js v21.6.2

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=";")

# Display the DataFrame
display(df)
# Out:
#                         created_at               id_str  \
# 0   Mon Oct 30 14:15:04 +0000 2023  1718994933426905323
# 1   Mon Oct 30 14:03:03 +0000 2023  1718991912076734856
# 2   Mon Oct 30 14:02:55 +0000 2023  1718991876353818956
# 3   Mon Oct 30 13:52:42 +0000 2023  1718989304004046951
# 4   Mon Oct 30 13:35:10 +0000 2023  1718984893106126910
# ..                             ...                  ...
# 80  Wed Oct 25 11:50:44 +0000 2023  1717146671812157823
# 81  Wed Oct 25 11:50:29 +0000 2023  1717146609270792517
# 82  Wed Oct 25 11:50:06 +0000 2023  1717146512629858649
# 83  Wed Oct 25 09:34:52 +0000 2023  1717112478935679203
# 84  Wed Oct 25 06:57:11 +0000 2023  1717072796537483353
#
#                                             full_text  quote_count  \
# 0   Momen Presiden Jokowi makan siang di Istana Ne...            0
# 1   @GeiszChalifah I like it..jokowi dimulyakan ka...            0
# 2   Dengan undangan makan siang kepada tiga calon ...            0
# 3   @cobeh2022 Itulah doa terbaik bagi masa depan ...            0
# 4   Pastinya Anies Baswedan jadi Presiden Indonesi...            0
# ..                                                ...          ...
# 80  @voiceofpkb @aniesbaswedan @cakimiNOW Anies Mu...            0
# 81  @voiceofpkb @aniesbaswedan @cakimiNOW Anies Mu...            0
# 82  @cakimiNOW Anies Muhaimin for 2024,semoga Lanc...            0
# 83  Saingan tiga penjuru pemilihan Presiden Indone...            1
# 84  @Malika6027 Sangat beda levelnya.... satu leve...            0
#
#     reply_count  retweet_count  favorite_count lang          user_id_str  \
# 0             0              0               0   in  1679896540285120512
# 1             0              0               0   in  1683163250685538304
# 2             1              0               2   in            519296882
# 3             0              0               0   in  1637489335162503170
# 4             0              0               0   in  1350839591247331328
# ..          ...            ...             ...  ...                  ...
# 80            0              0               0   in           1466977848
# 81            0              0               0   in           1466977848
# 82            0              0               0   in           1466977848
# 83            0              1               1   in            331383958
# 84            0              0               0   in   832458432271704065
#
#     conversation_id_str         username  \
# 0   1718994933426905323  daulatrakyatcom
# 1   1718943606764077216         odilerha
# 2   1718991876353818956     Ainulyausman
# 3   1718786103023648846      creepto2023
# 4   1718984893106126910     Jali86476093
# ..                  ...              ...
# 80  1717136375391441006      rudiaswad78
# 81  1717132469844238531      rudiaswad78
# 82  1717142313573777723      rudiaswad78
# 83  1717112478935679203      SinarOnline
# 84  1716820779009249763   DM_Sihombing16
#
#                                             tweet_url
# 0   https://twitter.com/daulatrakyatcom/status/171...
# 1   https://twitter.com/odilerha/status/1718991912...
# 2   https://twitter.com/Ainulyausman/status/171899...
# 3   https://twitter.com/creepto2023/status/1718989...
# 4   https://twitter.com/Jali86476093/status/171898...
# ..                                                ...
# 80  https://twitter.com/rudiaswad78/status/1717146...
# 81  https://twitter.com/rudiaswad78/status/1717146...
# 82  https://twitter.com/rudiaswad78/status/1717146...
# 83  https://twitter.com/SinarOnline/status/1717112...
# 84  https://twitter.com/DM_Sihombing16/status/1717...
#
# [85 rows x 12 columns]

# %%
def remove_tag(content):
    stemmed = content.split()
    stemmed = [word for word in stemmed if not '@' in word]
    stemmed = ' '.join(stemmed)
    return stemmed

# %%
df['no_tag'] = df['full_text'].apply(remove_tag)

# %%
df['no_tag']
# Out:
# 0     Momen Presiden Jokowi makan siang di Istana Ne...
# 1     I like it..jokowi dimulyakan karena menjadi pi...
# 2     Dengan undangan makan siang kepada tiga calon ...
# 3     Itulah doa terbaik bagi masa depan Indonesia.....
# 4     Pastinya Anies Baswedan jadi Presiden Indonesi...
#                             ...
# 80    Anies Muhaimin for 2024,semoga Lancar sampai A...
# 81    Anies Muhaimin for 2024,semoga Lancar sampai A...
# 82    Anies Muhaimin for 2024,semoga Lancar sampai A...
# 83    Saingan tiga penjuru pemilihan Presiden Indone...
# 84    Sangat beda levelnya.... satu level presiden (...
# Name: no_tag, Length: 85, dtype: object

# %%
df.to_csv('/Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/result/anis_november012023_desember312023.csv')
