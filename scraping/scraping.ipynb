# %% [markdown]
# Desember 2022 - April 2023

# %%
#@title Twitter Auth Token

twitter_auth_token = '88419bb735b02f989454300432e32024268ba877'

# %%
# Crawl Data
filename = 'ganjar.csv'
search_keyword = 'ganjar presiden indonesia 2024 lang:id until:2024-02-29 since:2024-01-01'
limit = 4000

# !npx --yes tweet-harvest@2.2.8 -o "{filename}" -s "{search_keyword}" -l {limit} --token {twitter_auth_token}
# Out:
# Welcome to the Twitter Crawler 🕷️
#
# This script uses Chromium Browser to crawl data from Twitter with *your* Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
# m#########⠂⠂⠂⠂⠂⠂⠂⠂⠂) ⠏ idealTree: timing idealTree Completed in 498ms
# up to date, audited 5 packages in 882ms
#
# found 0 vulnerabilities
#
# Opening twitter search page...
#
#
# Found existing file ./tweets-data/ganjar.csv, renaming to ./tweets-data/ganjar.old.csv
#
# Filling in keywords: ganjar presiden indonesia 2024 lang:id until:2024-02-29 since:2024-01-01
#
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 7
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 9
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 14
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 15
#
# Got some tweets, saving to file...
# No more tweets found, please check your search criteria and csv file result
# Already got 15 tweets, done scrolling...

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=";")

# Display the DataFrame
display(df)
# Out:
#                         created_at               id_str  \
# 0   Wed Feb 28 04:01:08 +0000 2024  1762689364898017500
# 1   Mon Feb 26 16:14:15 +0000 2024  1762149085514186821
# 2   Mon Feb 26 10:42:16 +0000 2024  1762065537495073201
# 3   Mon Feb 26 04:31:39 +0000 2024  1761972269726015956
# 4   Mon Feb 26 03:59:14 +0000 2024  1761964110068195329
# 5   Sun Feb 25 15:05:32 +0000 2024  1761769401806946715
# 6   Sun Feb 25 07:13:03 +0000 2024  1761650499198329099
# 7   Sun Feb 25 02:28:13 +0000 2024  1761578819423523033
# 8   Sun Feb 25 02:01:01 +0000 2024  1761571973325541689
# 9   Fri Feb 23 12:47:13 +0000 2024  1761009817613992043
# 10  Fri Feb 23 03:56:24 +0000 2024  1760876236610703753
# 11  Fri Feb 23 03:55:35 +0000 2024  1760876028589953093
# 12  Thu Feb 22 10:29:39 +0000 2024  1760612812467196136
# 13  Thu Feb 22 07:41:45 +0000 2024  1760570559094747314
# 14  Wed Feb 21 12:00:28 +0000 2024  1760273278290252138
#
#                                             full_text  quote_count  \
# 0   Apa kalau Anies Ganjar jadi Presiden Indonesia...            0
# 1   @Rokib_saidani @narkosun Siapa takut? Kalo hak...            0
# 2   Dukungan masyarakat Jawa Tengah terhadap Ganja...            0
# 3   Wacana membawa dugaan kecurangan dalam Pemilu ...            0
# 4   Calon presiden Prabowo Subianto menerima ucapa...            0
# 5   Lembaga Survei Indonesia (LSI) memotret terger...            0
# 6   Calon presiden 2024 yang diidamkan harus memil...            0
# 7   @detikcom G usah pikirin partai  yg kalah, pik...            0
# 8   @Mdy_Asmara1701 Hak Angket DPR RI melahirkan p...            0
# 9   Kunjungan Calon Presiden nomor urut 03, Ganjar...            0
# 10  rayakan kemenangan ganjar mahfud presiden raky...            0
# 11  ganjar mahfud calon presiden rakyat indonesia ...            0
# 12  Ketua Umum PBNU Yahya Cholil Staquf (Gus Yahya...            0
# 13  Dukungan masyarakat Jawa Tengah terhadap Ganja...            0
# 14  PENELITI Forum Masyarakat Peduli Parlemen Indo...            0
#
#     reply_count  retweet_count  favorite_count lang          user_id_str  \
# 0             0              0               0   in             95578036
# 1             1              0               1   in  1727860654642733056
# 2             0              0               0   in  1684822794880868352
# 3             0              6              37   in   797761417894051840
# 4             0              4               3   in  1469097798326841345
# 5             0              0               0   in   704238913158782977
# 6             0              0               0   in  1685938251155329024
# 7             0              0               0   in  1569589180912762880
# 8             0              0               2   in            147198181
# 9             0              0               0   in             46693036
# 10            0              0               0   in            832306284
# 11            0              0               0   in            832306284
# 12            0              1               3   in            150581612
# 13            0              0               0   in  1689136148285902849
# 14            0              0               0   in             68930552
#
#     conversation_id_str        username  \
# 0   1762689364898017500   awangprasetya
# 1   1762114826195865732   tanpafollower
# 2   1762065537495073201       burhnnrdn
# 3   1761972269726015956     MarahIchsan
# 4   1761964110068195329    DeWiKecEb0nG
# 5   1761769401806946715       tinusflip
# 6   1761650499198329099  AdiPrasetyoo12
# 7   1761316283407016402   brainnolimit1
# 8   1761339584942608834         gea_asa
# 9   1761009817613992043    inilahdotcom
# 10  1760876236610703753    tammy_sendut
# 11  1760876028589953093    tammy_sendut
# 12  1760612812467196136    dw_indonesia
# 13  1760570559094747314   DitoEkspresxx
# 14  1760273278290252138  mediaindonesia
#
#                                             tweet_url
# 0   https://twitter.com/awangprasetya/status/17626...
# 1   https://twitter.com/tanpafollower/status/17621...
# 2   https://twitter.com/burhnnrdn/status/176206553...
# 3   https://twitter.com/MarahIchsan/status/1761972...
# 4   https://twitter.com/DeWiKecEb0nG/status/176196...
# 5   https://twitter.com/tinusflip/status/176176940...
# 6   https://twitter.com/AdiPrasetyoo12/status/1761...
# 7   https://twitter.com/brainnolimit1/status/17615...
# 8   https://twitter.com/gea_asa/status/17615719733...
# 9   https://twitter.com/inilahdotcom/status/176100...
# 10  https://twitter.com/tammy_sendut/status/176087...
# 11  https://twitter.com/tammy_sendut/status/176087...
# 12  https://twitter.com/dw_indonesia/status/176061...
# 13  https://twitter.com/DitoEkspresxx/status/17605...
# 14  https://twitter.com/mediaindonesia/status/1760...

# %%
def remove_tag(content):
    stemmed = content.split()
    stemmed = [word for word in stemmed if not '@' in word]
    stemmed = ' '.join(stemmed)
    return stemmed

# %%
df['no_tag'] = df['full_text'].apply(remove_tag)

# %%
df['no_tag']
# Out:
# 0     Apa kalau Anies Ganjar jadi Presiden Indonesia...
# 1     Siapa takut? Kalo hak anget bisa bergulir dan ...
# 2     Dukungan masyarakat Jawa Tengah terhadap Ganja...
# 3     Wacana membawa dugaan kecurangan dalam Pemilu ...
# 4     Calon presiden Prabowo Subianto menerima ucapa...
# 5     Lembaga Survei Indonesia (LSI) memotret terger...
# 6     Calon presiden 2024 yang diidamkan harus memil...
# 7     G usah pikirin partai yg kalah, pikirin rakyat...
# 8     Hak Angket DPR RI melahirkan pemimpin baru Gan...
# 9     Kunjungan Calon Presiden nomor urut 03, Ganjar...
# 10    rayakan kemenangan ganjar mahfud presiden raky...
# 11    ganjar mahfud calon presiden rakyat indonesia ...
# 12    Ketua Umum PBNU Yahya Cholil Staquf (Gus Yahya...
# 13    Dukungan masyarakat Jawa Tengah terhadap Ganja...
# 14    PENELITI Forum Masyarakat Peduli Parlemen Indo...
# Name: no_tag, dtype: object

# %%
df.to_csv('/Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/result/ganjar/ganjar_januari012024_februari292023.csv')
