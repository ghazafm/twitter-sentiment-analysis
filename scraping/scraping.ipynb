# %% [markdown]
# Desember 2022 - April 2023

# %%
#@title Twitter Auth Token

twitter_auth_token = '88419bb735b02f989454300432e32024268ba877'

# %%
# Crawl Data
filename = 'ganjar.csv'
search_keyword = 'ganjar presiden indonesia 2024 lang:id until:2023-06-30 since:2023-05-01'
limit = 4000

# !npx --yes tweet-harvest@2.2.8 -o "{filename}" -s "{search_keyword}" -l {limit} --token {twitter_auth_token}
# Out:
# Welcome to the Twitter Crawler 🕷️
#
# This script uses Chromium Browser to crawl data from Twitter with *your* Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
# m#########⠂⠂⠂⠂⠂⠂⠂⠂⠂) ⠏ idealTree: timing idealTree Completed in 1869ms
# up to date, audited 5 packages in 2s
#
# found 0 vulnerabilities
#
# Opening twitter search page...
#
#
# Filling in keywords: ganjar presiden indonesia 2024 lang:id until:2023-06-30 since:2023-05-01
#
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 6
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 15
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 26
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 45
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 56
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 75
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 83
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 94
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 108
#
# --Taking a break, waiting for 10 seconds...
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 126
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 139
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 146
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 159
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 173
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 185
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 197
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 210
#
# --Taking a break, waiting for 10 seconds...
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 225
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 243
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 259
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 275
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 292
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 302
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 316
#
# --Taking a break, waiting for 10 seconds...
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 331
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 337
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 343
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 353
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 368
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 384
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 395
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/ganjar.csv
# Total tweets saved: 404
#
# Got some tweets, saving to file...
# Error parsing response json: {"_type":"Response","_guid":"response@9c126fc61fa0801414b32a452b7cda7b"}
# Most likely, you have already exceeded the Twitter rate limit. Read more on https://twitter.com/elonmusk/status/1675187969420828672?s=46.
# ^C
# page.waitForTimeout: Target page, context or browser has been closed
#     at /Users/fauzanghaza/.npm/_npx/006edd9c57a6e29b/node_modules/tweet-harvest/dist/crawl.js:158:79
#     at step (/Users/fauzanghaza/.npm/_npx/006edd9c57a6e29b/node_modules/tweet-harvest/dist/crawl.js:56:23)
#     at Object.next (/Users/fauzanghaza/.npm/_npx/006edd9c57a6e29b/node_modules/tweet-harvest/dist/crawl.js:37:53)
#     at step (/Users/fauzanghaza/.npm/_npx/006edd9c57a6e29b/node_modules/tweet-harvest/dist/crawl.js:41:139)
#     at Object.next (/Users/fauzanghaza/.npm/_npx/006edd9c57a6e29b/node_modules/tweet-harvest/dist/crawl.js:37:53)
#     at fulfilled (/Users/fauzanghaza/.npm/_npx/006edd9c57a6e29b/node_modules/tweet-harvest/dist/crawl.js:28:58)
# Keywords: ganjar presiden indonesia 2024 lang:id until:2023-06-30 since:2023-05-01
# Twitter Harvest v 2.2.8
# node:internal/process/promises:289
#             triggerUncaughtException(err, true /* fromPromise */);
#             ^
#
# page.screenshot: Target page, context or browser has been closed
#     at /Users/fauzanghaza/.npm/_npx/006edd9c57a6e29b/node_modules/tweet-harvest/dist/crawl.js:437:47
#     at step (/Users/fauzanghaza/.npm/_npx/006edd9c57a6e29b/node_modules/tweet-harvest/dist/crawl.js:56:23)
#     at Object.throw (/Users/fauzanghaza/.npm/_npx/006edd9c57a6e29b/node_modules/tweet-harvest/dist/crawl.js:37:53)
#     at rejected (/Users/fauzanghaza/.npm/_npx/006edd9c57a6e29b/node_modules/tweet-harvest/dist/crawl.js:29:65)
#
# Node.js v21.6.2

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=";")

# Display the DataFrame
display(df)
# Out:
#                          created_at               id_str  \
# 0    Wed Feb 28 13:30:06 +0000 2024  1762832549347565670
# 1    Wed Feb 28 12:59:25 +0000 2024  1762824828111749278
# 2    Wed Feb 28 12:35:22 +0000 2024  1762818777077662081
# 3    Wed Feb 28 09:41:59 +0000 2024  1762775143171153934
# 4    Wed Feb 28 07:21:47 +0000 2024  1762739858785853951
# ..                              ...                  ...
# 729  Tue Jan 23 07:48:27 +0000 2024  1749700608792330353
# 730  Tue Jan 23 07:44:34 +0000 2024  1749699630764621974
# 731  Tue Jan 23 07:20:25 +0000 2024  1749693554279235955
# 732  Tue Jan 23 01:34:14 +0000 2024  1749606433275126083
# 733  Tue Jan 23 00:24:55 +0000 2024  1749588987629781493
#
#                                              full_text  quote_count  \
# 0    Th. 2024  Prabowo jadi presiden.  Putri Ariani...            0
# 1    Prabowo Subianto merupakan salah satu calon Pr...            0
# 2    Catatan Kelam Demokrasi  Kekejaman berbuah ken...            0
# 3    Kesabaran dan Pengabdian Tulus akan membuahkan...            8
# 4    Selamat kepada Jenderal TNI Prabowo Subianto.T...            0
# ..                                                 ...          ...
# 729  @yusuf_dumdum @AriefAnarya Contoh surat suara ...            0
# 730  @AntoniusCDN @ganjarpranowo @mohmahfudmd @Arsj...            0
# 731  @ZulkifliLubis69 Rugi banget Indonesia kalau t...            0
# 732  @republikaonline Sudah pak... Kami tegas kabar...            0
# 733  @fadlizon Apapun kata Paslon Capres-cawapres n...            0
#
#      reply_count  retweet_count  favorite_count lang          user_id_str  \
# 0              0              0               0   in             11151852
# 1              0              0               2   in            135783107
# 2              1              0               1   in  1751938268206448640
# 3            120             17             175   in            190679407
# 4              1              2              11   in  1462319970184929284
# ..           ...            ...             ...  ...                  ...
# 729            0              0               0   in  1213085911782584321
# 730            0              0               0   in  1213085911782584321
# 731            0              0               1   in  1688381419188584449
# 732            0              0               0   in  1544657716962291712
# 733            0              0               0   in  1652143728075898880
#
#      conversation_id_str        username  \
# 0    1762832549347565670      antokarief
# 1    1762824828111749278      detiksport
# 2    1762818777077662081   COKRONINGRAT_
# 3    1762775143171153934   andre_rosiade
# 4    1762739858785853951          G0mb4k
# ..                   ...             ...
# 729  1749678103696453769       macan1962
# 730  1749663267994357873       macan1962
# 731  1749457273544675379  2024_ourfuture
# 732  1749556510865457424      MaxMan007_
# 733  1749253702408687828    yusak_j34777
#
#                                              tweet_url
# 0    https://twitter.com/antokarief/status/17628325...
# 1    https://twitter.com/detiksport/status/17628248...
# 2    https://twitter.com/COKRONINGRAT_/status/17628...
# 3    https://twitter.com/andre_rosiade/status/17627...
# 4    https://twitter.com/G0mb4k/status/176273985878...
# ..                                                 ...
# 729  https://twitter.com/macan1962/status/174970060...
# 730  https://twitter.com/macan1962/status/174969963...
# 731  https://twitter.com/2024_ourfuture/status/1749...
# 732  https://twitter.com/MaxMan007_/status/17496064...
# 733  https://twitter.com/yusak_j34777/status/174958...
#
# [734 rows x 12 columns]

# %%
def remove_tag(content):
    stemmed = content.split()
    stemmed = [word for word in stemmed if not '@' in word]
    stemmed = ' '.join(stemmed)
    return stemmed

# %%
df['no_tag'] = df['full_text'].apply(remove_tag)

# %%
df['no_tag']
# Out:
# 0      Th. 2024 Prabowo jadi presiden. Putri Ariani k...
# 1      Prabowo Subianto merupakan salah satu calon Pr...
# 2      Catatan Kelam Demokrasi Kekejaman berbuah kena...
# 3      Kesabaran dan Pengabdian Tulus akan membuahkan...
# 4      Selamat kepada Jenderal TNI Prabowo Subianto.T...
#                              ...
# 729    Contoh surat suara pemilu 2024. COBLOS NO 2 PR...
# 730    Contoh surat suara pemilu 2024. COBLOS NO 2. P...
# 731    Rugi banget Indonesia kalau tdk memilih presid...
# 732    Sudah pak... Kami tegas kabarkan ke semua oran...
# 733    Apapun kata Paslon Capres-cawapres no urut 1 d...
# Name: no_tag, Length: 734, dtype: object

# %%
df.to_csv('/Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/result/ganjar/ganjar_mei012023_juni302023.csv')
