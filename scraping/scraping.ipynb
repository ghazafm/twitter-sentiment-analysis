# %% [markdown]
# Desember 2022 - April 2023

# %%
#@title Twitter Auth Token

twitter_auth_token = '88419bb735b02f989454300432e32024268ba877'

# %%
# Crawl Data
filename = 'prabowo.csv'
search_keyword = 'prabowo presiden indonesia 2024 lang:id until:2023-12-31 since:2023-11-01'
limit = 4000

# !npx --yes tweet-harvest@2.2.8 -o "{filename}" -s "{search_keyword}" -l {limit} --token {twitter_auth_token}
# Out:
# Welcome to the Twitter Crawler 🕷️
#
# This script uses Chromium Browser to crawl data from Twitter with *your* Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
# m#########⠂⠂⠂⠂⠂⠂⠂⠂⠂) ⠏ idealTree: timing idealTree Completed in 551ms
# up to date, audited 5 packages in 946ms
#
# found 0 vulnerabilities
#
# Opening twitter search page...
#
#
# Found existing file ./tweets-data/prabowo.csv, renaming to ./tweets-data/prabowo.old.csv
#
# Filling in keywords: prabowo presiden indonesia 2024 lang:id until:2023-12-31 since:2023-11-01
#
#
# Got some tweets, saving to file...
# Your tweets saved to: /Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/tweets-data/prabowo.csv
# Total tweets saved: 14
# Scrolling more...
#
# Got some tweets, saving to file...
# ...

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=";")

# Display the DataFrame
display(df)
# Out:
#                          created_at               id_str  \
# 0    Sat Dec 30 22:00:44 +0000 2023  1741217783789314164
# 1    Sat Dec 30 19:29:46 +0000 2023  1741179790005240004
# 2    Sat Dec 30 18:07:26 +0000 2023  1741159070202314955
# 3    Sat Dec 30 18:04:32 +0000 2023  1741158343815868749
# 4    Sat Dec 30 17:26:37 +0000 2023  1741148801233281254
# ..                              ...                  ...
# 261  Mon Dec 18 15:13:00 +0000 2023  1736766520464920762
# 262  Mon Dec 18 14:37:36 +0000 2023  1736757610546872388
# 263  Mon Dec 18 14:17:15 +0000 2023  1736752488026677755
# 264  Mon Dec 18 14:00:03 +0000 2023  1736748160763265078
# 265  Mon Dec 18 13:48:38 +0000 2023  1736745289644757329
#
#                                              full_text  quote_count  \
# 0    @PahetKopi28207 @PartaiSocmed Presiden 2024 di...            0
# 1    @xquitavee Saya selalu memastikan kalau piliha...            0
# 2    @dhemit_is_back Bismillah Prabowo Presiden Ind...            0
# ...

# %%
def remove_tag(content):
    stemmed = content.split()
    stemmed = [word for word in stemmed if not '@' in word]
    stemmed = ' '.join(stemmed)
    return stemmed

# %%
df['no_tag'] = df['full_text'].apply(remove_tag)

# %%
df['no_tag']
# Out:
# 0      Presiden 2024 didunia maya anies baswedan dan ...
# 1      Saya selalu memastikan kalau pilihan saya akan...
# 2      Bismillah Prabowo Presiden Indonesia 2024 Mena...
# 3      Indonesia Butuh Pilot Untuk Bawa Ke Indonesia ...
# 4      Jelang Pilpres 2024, para kandidat tengah sibu...
#                              ...
# 261    aku tidak Menemukan orang yang paling ikhlas u...
# 262    Kelas! Survei Roy Morgan: Elektabilitas Ganjar...
# 263    Pihak asing malahan mendukung prabowo Gibran u...
# 264    2024 Prabowo Presiden RI Ndasmu Siang Ijazah O...
# 265    Bapak prabowo subianto capres presiden indones...
# Name: no_tag, Length: 266, dtype: object

# %%
df.to_csv('/Users/fauzanghaza/Coding/SocialMediaSentiment/scraping/result/prabowo/prabowo_november012023_desember312023.csv')
