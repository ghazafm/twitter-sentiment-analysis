# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ghazafm/SocialMediaSentiment/main/preprocessing/EDA/clean/anis.csv')
df
# Out:
#       Unnamed: 0        Date       User ID  \
# 0              1  2023-04-16  7.710306e+08
# 1              2  2023-04-16  3.807551e+08
# 2              5  2023-04-16  6.342276e+08
# 3              6  2023-04-16  6.342276e+08
# 4              7  2023-04-16  6.342276e+08
# ...          ...         ...           ...
# 1878        9932  2023-01-06  4.243285e+07
# 1879        9934  2023-01-06  1.119876e+09
# 1880        9936  2023-01-06  1.260553e+08
# 1881        9937  2023-01-06  1.260553e+08
# 1882        9999  2023-01-05  1.620599e+08
#
#                                                   Tweet     label  \
# 0     politisi partai gerindra sandiaga uno menjawab...  Positive
# 1      lanjut pak anies kita kawal sampai jadi presiden  Positive
# 2     kader pdip jadi presiden yang mana menterinya ...  Negative
# 3     jika tidak ada deklarasi dari partai pendukung...  Positive
# 4                                          suara rakyat  Positive
# ...

# %%
plt.bar(df['label'].unique(), df['label'].value_counts(), color=['blue', 'red'])
plt.show()
