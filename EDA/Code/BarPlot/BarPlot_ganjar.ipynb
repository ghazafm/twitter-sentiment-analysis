# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ghazafm/SocialMediaSentiment/main/preprocessing/EDA/clean/ganjar.csv')
df
# Out:
#       Unnamed: 0        Date       User ID  \
# 0             21  2023-04-16  2.251776e+09
# 1             22  2023-04-16  2.251776e+09
# 2             23  2023-04-16  2.251776e+09
# 3             24  2023-04-16  2.251776e+09
# 4             27  2023-04-16  2.997689e+08
# ...          ...         ...           ...
# 1658        9975  2022-10-27  4.669304e+07
# 1659        9978  2022-10-27  4.350041e+08
# 1660        9979  2022-10-27  3.814322e+09
# 1661        9981  2022-10-27  6.918316e+07
# 1662        9996  2022-10-27  5.795586e+08
#
#                                                   Tweet     label  \
# 0     survei smrc dukungan capres untuk ganjar prano...  Positive
# 1     smrc elektabilitas ganjar pranowo kembali menguat  Positive
# 2     survei terbaru smrc elektabilitas ganjar rebou...  Positive
# 3     elektabilitas ganjar pranowo kembali menguat i...  Positive
# 4     ganjar pranowo pemimpin yang dicintai semua ka...  Positive
# ...

# %%
plt.bar(df['label'].unique(), df['label'].value_counts(), color=['blue', 'red'])
plt.show()
