# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ghazafm/SocialMediaSentiment/main/preprocessing/EDA/kotor/anis.csv')
df
# Out:
#       Unnamed: 0        Date      User ID  \
# 0              0  2023-04-16          NaN
# 1              1  2023-04-16  771030588.0
# 2              2  2023-04-16  380755133.0
# 3              3  2023-04-16          NaN
# 4              4  2023-04-16          NaN
# ...          ...         ...          ...
# 9992        9995  2023-01-05          NaN
# 9993        9996  2023-01-05          NaN
# 9994        9997  2023-01-05          NaN
# 9995        9998  2023-01-05          NaN
# 9996        9999  2023-01-05  162059920.0
#
#                                                   Tweet     label
# 0                                  info  anies presiden  Positive
# 1     politisi partai gerindra sandiaga uno menjawab...  Positive
# 2      lanjut pak anies kita kawal sampai jadi presiden  Positive
# 3     semoga allah swt menyelamatkan bangsa dan nega...  Positive
# 4     chotimah kasian ya pa anies makanya sudah teka...  Positive
# ...

# %%
plt.bar(df['label'].unique(), df['label'].value_counts(), color=['blue', 'red'])
plt.show()
