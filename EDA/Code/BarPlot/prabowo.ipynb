# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ghazafm/SocialMediaSentiment/main/preprocessing/EDA/clean/prabowo.csv')
df
# Out:
#       Unnamed: 0        Date       User ID  \
# 0              3  2023-04-16  4.745574e+09
# 1              5  2023-04-16  5.767560e+08
# 2             12  2023-04-16  4.652806e+08
# 3             13  2023-04-16  1.984000e+08
# 4             14  2023-04-16  4.652806e+08
# ...          ...         ...           ...
# 1933        9974  2022-12-09  1.863042e+09
# 1934        9981  2022-12-08  3.151954e+09
# 1935        9989  2022-12-08  6.893055e+07
# 1936        9991  2022-12-08  8.690021e+07
# 1937        9992  2022-12-08  8.690021e+07
#
#                                                   Tweet     label  \
# 0     selamat hut kopassus ke semoga semangat patrio...  Positive
# 1               prabowo presiden cebong kampret pensiun  Negative
# 2     komunitas pedagang tabanan bali deklarasi duku...  Positive
# 3     dari tetap bersama pk prabowo semoga pk prabow...  Positive
# 4     gemira dan semeton muslim bali deklarasi dukun...  Positive
# ...

# %%
plt.bar(df['label'].unique(), df['label'].value_counts(), color=['blue', 'red'])
plt.show()
