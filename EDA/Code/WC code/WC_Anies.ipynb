# %%
import matplotlib.pyplot as plt 
from wordcloud import WordCloud
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Fatoni Murfid
# [nltk_data]     S\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import pandas as pd 
df = pd.read_csv('https://raw.githubusercontent.com/ghazafm/SocialMediaSentiment/main/preprocessing/EDA/datasets/anis.csv')
df.head(10)
# Out:
#    Unnamed: 0        Date      User ID  Tweet Count         Tweet Location  \
# 0           1  2023-04-16  771030588.0        30121      Palmerah, Jakarta
# 1           2  2023-04-16  380755133.0          230        Jakarta - Utara
# 2           5  2023-04-16  634227637.0         5297  Jawa Barat, Indonesia
# 3           6  2023-04-16  634227637.0         5297  Jawa Barat, Indonesia
# 4           7  2023-04-16  634227637.0         5297  Jawa Barat, Indonesia
# 5           8  2023-04-16  171458202.0           35      Tangerang Selatan
# 6           9  2023-04-16  634227637.0         5297  Jawa Barat, Indonesia
# 7          10  2023-04-16  634227637.0         5297  Jawa Barat, Indonesia
# 8          11  2023-04-16  634227637.0         5297  Jawa Barat, Indonesia
# 9          12  2023-04-16  634227637.0         5297  Jawa Barat, Indonesia
#
#                                                Tweet     label  \
# 0  politisi partai gerindra sandiaga uno menjawab...  Positive
# 1   lanjut pak anies kita kawal sampai jadi presiden  Positive
# 2  kader pdip jadi presiden yang mana menterinya ...  Negative
# 3  jika tidak ada deklarasi dari partai pendukung...  Positive
# 4                                       suara rakyat  Positive
# 5  amien rais akan pilih prabowo subianto bila an...  Negative
# 6                             siapa dulu gunernurnya  Positive
# 7  kpk bergerak keadilan bagi seluruh rakyat indo...  Negative
# 8                                      anies prabowo  Positive
# 9  bisa jadi gubernur karena ada partai yang mend...  Negative
#
#                                                Clean               city
# 0  politisi partai gerindra sandiaga uno menjawab...           Palmerah
# 1                  lanjut pak kita kawal sampai jadi    Jakarta - Utara
# 2  kader pdip jadi yang mana menterinya impor pangan         Jawa Barat
# 3  jika tidak ada deklarasi dari partai pendukung...         Jawa Barat
# 4                                       suara rakyat         Jawa Barat
# 5  amien rais akan pilih subianto bila gagal jadi...  Tangerang Selatan
# 6                             siapa dulu gunernurnya         Jawa Barat
# 7  kpk bergerak keadilan bagi seluruh rakyat indo...         Jawa Barat
# 8                                                NaN         Jawa Barat
# 9  bisa jadi gubernur karena ada partai yang mend...         Jawa Barat

# %%
# sw = stopwords.words('indonesian')
# df['Clean'] = df['Clean'].astype(str)
# keyword = ['yg']
# for i in keyword:
#     df['Clean'] = df['Clean'].str.replace(i,'')
    

sw = stopwords.words('indonesian')
df['Clean'] = df['Clean'].astype(str)

singkatan = ['kalo','ya','gak','pk','nya', 'pa', 'ma', 'amp',"tp", "yg", "km", "gw", "lg", "jd", "bgt", "jg", "ga", "udh", "dr", "tdk", "dlm", "dgn", "bs", "srg", "td", "gmn", "bkn", "skrg", "sm", "krn", "dg", "sy", "org", "emg", "hrs", "lm", "blm", "pny", "jln", "aja", "kl", "sdh", "nntn", "tuh", "tlg", "smua", "kmrn", "gini", "jg", "krja", "hbs", "dri", "jdi", "lgi", "bgtu", "ni", "sih", "lw", "mgkn", "hri", "bner", "ngomong", "klwrg", "gpp", "psn", "klw", "sblm", "dpt", "bsa", "tau", "ntr", "dpt", "nih", "bngt", "tmn", "gt", "dnger", "pdhl", "kn", "mksd", "tdi", "klg", "brp", "krja", "lgsg", "psn", "yg", "syg", "knpa", "mnrt", "msk", "psti", "cma", "gtw", "lgkp", "dikit", "pake", "tmn2", "bsk", "dtg", "bilg", "hri", "smpt", "lgkp", "trus", "byk", "dpet", "lmyn", "slesai", "smp", "emng", "rmai", "ssuai", "jdwl", "smpe", "jwb", "mksud", "ny", "byr", "bwt", "lgsng", "mksh", "smpai", "dd", "numpang", "kasian", "y", "biasa", "drmh", "cr", "hehe", "dgr", "blng", "kq", "wkt", "kyk", "lwt", "sering2", "spt", "msih", "lk", "skt", "kmn", "taun", "sekolh", "msalah", "dikit", "syg", "mgkin", "slmt", "mnt", "bwa", "pgn", "mnding", "dk", "istg", "pulang2", "dpt"]

keyword = sw + singkatan

for i in keyword:
    # Menghapus kata kunci dari setiap teks dalam kolom 'Clean' jika muncul sebagai kata terpisah
    df['Clean'] = df['Clean'].apply(lambda x: ' '.join([word for word in x.split() if word.lower() != i]))

# Hasilnya adalah 'Clean' dataframe yang telah dimodifikasi
print(df['Clean'])
result = ""
for text in df['Clean']:
    result += text + " "
print(result)
# Out:
# 0       politisi partai gerindra sandiaga uno diduetka...
# 1                                                   kawal
# 2                      kader pdip menterinya impor pangan
# 3       deklarasi partai pendukung hasil survei berman...
# 4                                            suara rakyat
#                               ...
# 1878      ratusan kader pan banjarnegara deklarasi dukung
# 1879    bagus jk survei jokowi turun pd aj pemerintah ...
# 1880    tricks jokowi efisien tinggal hobby masuk goro...
# 1881    tricks jokowi efisien tinggal hobby masuk goro...
# 1882    pilih puang maharani erick thohir jokowi erlan...
# Name: Clean, Length: 1883, dtype: object
# politisi partai gerindra sandiaga uno diduetkan mantan gubernur dki jakarta pemilihan kawal kader pdip menterinya impor pangan deklarasi partai pendukung hasil survei bermanfaat suara rakyat amien rais pilih subianto gagal calon pilpres gunernurnya kpk bergerak keadilan rakyat indonesia nan gubernur partai mendukungnya pikirin kalah pejabat partai politik lu kritik partainya nggak terkejut  pro istana achmadi yuk dukung ri id mari dukung ri insya allah ri agama negeri bangkit harmoni bingkai nkri sederhana emang traget ngapain maju capres menhan pas gimana tolong samapikan ayah biaya kampanye ayah manfaat pangunan rezim selanjut makar alloh swt bagus berlaku in sya alloh the next ri aamiinx yra mengusung calon pilpres subianto semoga orang dicopot jabatannya kereta cepat cepat cepat ustadz hafus ditemui ustadz layak ditemui barokallah gus baha lu jadiin masjid takjil materi cerita bohong romadhon amal dilipat gandakan doa diijabah menyepi insya allah si curut sitompul nggak waras memfitnah ri festival hadrah seprovinsi jawa timur ishari nu gema abw via festival hadrah ramadhan ishari nu gema abw ri insya allahsehat madinah mashaallah penjual madinah bismillah biidznillah ri insya allah partai berdiri berkomitmen membangun perubahan indonesia peradaban partai duta peradaban pendukung partai mengusung rasyid calon setuju fathur nakula pecah jutaan jemaah teriakkan insyaallah dukung menghadapi pilpres nasdem mendeklarasikan mantan gubernur dki jakarta calon subianto ketua badan pembina organisasi keanggotaan kaderisasi bpopkk dpp partai demokrat herman khaeron buka suara isu mengusung menko polhukam mahfud md pendamping pemilihan survei kandidat calon pemilu indonesia subianto survei terbaru bursa calon pemilu indonesia survey center isc menemukan subianto unggul subianto orang dikenal solid ayo follow acount resmi pks pks tembus juta follower sd rabu februari pks menang lihat video ayiceopesantrenpolitikcom dukung inismyname anak muda cerdas inshaallah ri mudahan republik indonesia raffi nagita nasibnya beda bohir sibuk ngamanin periode moeldoko membantah tudingan ahy peninjauan dilayangkan menjegal calon hubungannya suka berhalusinasi puan vs khofifah ri hidup koruptor menyebar andai sandi nerima pinangan cawapres wagub gubernur dki andai kepilih cawapres chotimah ri buzzerp recehan panik ketakutan ri hilang akal buzzerp recehan memfitnah insya allah republik indonesia maju pemilu iblis bani cebong ade berusaha sekuat tenaga mengganggu menggagalkn pencalonan sbg capreskrn iblis akn kepanasan klo didu ri inimah sedekah foto terpanpang tulisan alasannya pelakunya jumatan dimasjid kampanye sehat ri mandul serangan densy ri peneliti senior indonesia survey center isc chairul ansari alasan subianto unggul survei bursa calon pemilu subianto sosok mahfud md digadanggadang cocok calon wakil pasangan kancah pilpres simak berita selengkapnya politik nan nan nan nan nan simak ahli tarot ramal keturunan jawa suka pakai topi poskota mahfud md dinilai cocok mendampingi bertarung pilpres rezim pemerintahan joko widodo menurutmu tulis kolom komentar sir mp relawan jokowi netral pilpres sikap menyelamatkan bangsa karir politik jokowi turun kursi jokowi netral nasibnya terancam pasca purna tugas tirulah sikap netral sby jabatannya pd th sir mp relawan jokowi netral pilpres sikap menyelamatkan bangsa karir politik jokowi turun kursi jokowi netral nasibnya terancam pasca purna tugas tirulah sikap netral sby jabatannya th inismyname iya jokowi didukung gerindra ditunggu bpk jgn panik stres menteri kalah ditikungan mulu abangda akhlaknya super duperitu ganti lapor beli token listrik prabayar pln mobile rincian sbb listrik pln denom rp biaya layanan rp metode pembayaran va total bayar rp kwh harga kwh rpkwh orang cerdas pilih abdillahtoha insya allah ri fahnoor inismyname aneh diem salah uda warga kasih pendapat beda narasi eluh pejabat ngadih pendapat belom uda bukti perubahannya dimana aneh ri alhamdulillah dukungan mas pilpres hadir tingkat desa b ...

# %%
# #Membuka file teks baru dalam mode tulis ('w')
# with open('anies.txt', 'w') as file:
#     # Tulis string ke dalam file
#     file.write(result)

# %%
wc = WordCloud(background_color="white", max_words=50).generate(result)
wc.to_file("anies.png")

# %%
from collections import Counter

# Misalkan 'result' adalah teks yang ingin Anda analisis

# Membagi teks menjadi kata-kata
words = result.split()

# Menghitung frekuensi kemunculan setiap kata
word_freq = Counter(words)

# Mengambil 10 kata yang paling sering muncul
top_words = word_freq.most_common(30)
testing = pd.DataFrame(top_words)


# Menampilkan hasil
for word, freq in top_words:
    print(f"Kata: {word}, Jumlah: {freq}")
# Out:
# Kata: ri, Jumlah: 580
# Kata: calon, Jumlah: 399
# Kata: indonesia, Jumlah: 334
# Kata: partai, Jumlah: 306
# Kata: pks, Jumlah: 270
# Kata: pilpres, Jumlah: 195
# Kata: rakyat, Jumlah: 179
# Kata: dukung, Jumlah: 134
# Kata: pemilu, Jumlah: 125
# Kata: allah, Jumlah: 122
# Kata: capres, Jumlah: 114
# Kata: nasdem, Jumlah: 112
# Kata: jokowi, Jumlah: 109
# Kata: demokrat, Jumlah: 100
# Kata: perubahan, Jumlah: 94
# Kata: ahy, Jumlah: 91
# Kata: semoga, Jumlah: 87
# Kata: ya, Jumlah: 86
# Kata: resmi, Jumlah: 85
# Kata: pemimpin, Jumlah: 85
# Kata: jd, Jumlah: 84
# Kata: jakarta, Jumlah: 80
# Kata: wakil, Jumlah: 80
# Kata: maju, Jumlah: 78
# Kata: koalisi, Jumlah: 78
# Kata: mendukung, Jumlah: 78
# Kata: sejahtera, Jumlah: 75
# Kata: pilih, Jumlah: 74
# Kata: amp, Jumlah: 74
# Kata: ketua, Jumlah: 71
