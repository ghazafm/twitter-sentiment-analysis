# %%
import pandas as pd 
columns = ['No','word']
df_n = pd.read_csv('https://raw.githubusercontent.com/ghazafm/SocialMediaSentiment/main/preprocessing/EDA/word_cloud/anis/negative.csv', names=columns)
# df_n['User ID'].dropna(axis=0, inplace=True)

# %%
df_n.dropna(axis=0, inplace=True)
df_n.isna().sum()
# Out:
# No      0
# word    0
# dtype: int64

# %%
df_n['word'] = df_n['word'].astype(str)
result = ""
for text in df_n['word']:
    result += text + " "
print(result)
# Out:
# kader mana menterinya impor pangan amien rais bila gagal kpk bergerak keadilan bagi seluruh mendukungnya pikirin kenapa kalah pejabat lu kritik partainya pertanyaan sederhana emang traget awal ngapain menhan pas gimana tolong samapikan ayah biaya kampanye ayah manfaat pangunan rezim selanjut kereta cepat cepat cepat lu jadiin masjid takjil materi cerita bohong mengenai kandidat terbaru mengenai bursa dilakukan center isc menemukan unggul vs khofifah koruptor menyebar didu inimah sedekah jelas foto terpanpang tulisan alasannya pelakunya jumatan dimasjid maka kampanye sehat mandul serangan densy peneliti senior center isc chairul ansari mengungkapkan empat alasan unggul bursa mendatang simak ataupun ahli tarot ramal keturunan suka pakai topi poskota mahfud md dinilai mendampingi bertarung bagian rezim pemerintahan bagaimana menurutmu tulis kolom komentar lapor beli token listrik prabayar pln mobile rincian sbb listrik pln denom rp biaya layanan rp metode pembayaran melalui va bayar rp kwh didapat harga kwh rpkwh perubahan mksdx pasti berubah apakah makanya gk perubahan program the real president dikuasai rezimjika istana happy pencapresan wajar rezim memimpin lihatlah asmara didu saewad idha sir prabowoganjaranies menurutmu suara terbanyak ayo dipilih dipilih ditutup besok senin jam politisi sandiaga uno menjawab soal diduetkan mantan dki jakarta mendatang politisi sandiaga uno menjawab soal diduetkan mantan dki jakarta mendatang apakah maksud zulhas kendalikan koalisi melawan bila netral bagaimana lembaga negara berada bawah kendali dijamin netralitasnya sandiaga uno jawab wacana dampingi restu acuan sandiaga uno menjawab wacana dipasangkannya ia usungan restu acuan klaim miliaran pasien kejahatan bidang kesehatan kios dikontrakkan pedagang tanpa sewa kios apakah ekonomi baik pengamat komunikasi universitas gadjah mada ugm nyarwi mengatakan barat kuda hitam wakil mendampingi pengamat komunikasi universitas gadjah mada ugm nyarwi mengatakan barat kuda hitam wakil mendampingi pengamat komunikasi universitas gadjah mada ugm nyarwi mengatakan barat kuda hitam wakil mendampingi jangan mimpi bos pun tentu habitat mending perjuangkan pt lewat jalur indepnden dijajah parpol perjuangan revolusi mental preseden jikowo kritik pemeribtah target dikandangin making teriak maling tampak bersih tetiak maling iblis kebagian stop petugas melihat percaturan memang seru incumbent pingin periode block dkk incumbent ajukan diblock mrk ajukan digenjet istana melawan gencet didukung ummat parrtai kubu moeldoko membantah tudingan peninjauan dilayangkan menjegal bagian persoalan internal catat bocil moeldoko kubu moeldoko membantah tudingan ketua agus harimurti yudhoyono peninjauan dilayangkan menjegal melindungi melanggar hukum titik nol nusantara ujung pulau aceh papua udah parpol mengikuti tentunya pembagian amplop berlogo dikategorikan curi start kampanye sedangkan sering warning justru ditetapkan kpu pengamat komunikasi universitas gadjah mada ugm nyarwi mengatakan barat kuda hitam wakil mendampingi lantas apakah koalisi mengusung benarkah koalisi dibentuk melawan satumeja babak baru penjegalan oknum istana kpk airlangga vs khofifah swt segera mencabut nyawa pejabat jahat rakus sdg berkuasa sdg berusaha menggagalkan pencalonan bang pd via malaikat maut diminta tanggung jawabnya kubur mahkamah agung diajukan kepala staff ksp moeldoko upaya guna menggagalkan pencapresan kenakalan bahar newcastle senin ketua agus harimurti yudhoyono menilai upaya serius menggagalkan pencalonan pengamat komunikasi universitas gadjah mada ugm nyarwi mengatakan barat kuda hitam wakil mendampingi koalisi pemerintah mengumumkan airlangga hartarto wakil sementara lain sepakat tinggal mengumumkan akhirnya pengamat komunikasi universitas gadjah mada ugm nyarwi mengatakan barat kuda hitam wakil mendampingi posting mudik gratis warganet respect fix klo punya prinsip asal dah sajak timnas palestina sj lah klo yaman sj keduanya kelaut sj ichsan pokoknya lanjutkan bung lah kepala  ...

# %%
import matplotlib.pyplot as plt 
from wordcloud import WordCloud
wc = WordCloud(background_color="white", max_words=50).generate(result)
wc.to_file("anies_n.png")

# %%
import pandas as pd 
columns = ['No','word']
df_p = pd.read_csv('https://raw.githubusercontent.com/ghazafm/SocialMediaSentiment/main/preprocessing/EDA/word_cloud/anis/positive.csv', names=columns)
# df_cl['User ID'].dropna(axis=0, inplace=True)

# %%
df_p.dropna(axis=0, inplace=True)
df_p.isna().sum()
# Out:
# No      0
# word    0
# dtype: int64

# %%
df_p['word'] = df_p['word'].astype(str)
result = ""
for text in df_p['word']:
    result += text + " "
print(result)
# Out:
# politisi sandiaga uno menjawab soal diduetkan mantan dki jakarta mendatang lanjut kawal sampai deklarasi pendukung maka bermanfaat suara dulu gunernurnya nggak terkejut lanjut pro selalu berada luar istana achmadi yuk id mari insya agama negeri bangkit harmoni bingkai nkri makar alloh swt bagus berlaku in sya alloh the next aamiinx yra mengusung dicopot jabatannya ustadz mana hafus ditemui ustadz tahu ditemui barokallah gus baha romadhon ketika amal dilipat gandakan ketika doa diijabah menyepi insya selama curut sitompul nggak waras memfitnah festival hadrah seprovinsi timur ishari nu gema abw via festival hadrah ramadhan ishari nu gema abw insya allahsehat madinah mashaallah sampai penjual madinah pun tahu bismillah biidznillah insya berdiri berkomitmen membangun perubahan baik menuju peradaban baru duta peradaban pendukung mengusung setuju fathur nakula pecah jutaan jemaah teriakkan insyaallah malah naik bila menghadapi sebelumnya mendeklarasikan mantan dki jakarta ketua badan pembina organisasi keanggotaan