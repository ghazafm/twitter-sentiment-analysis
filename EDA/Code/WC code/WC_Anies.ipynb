# %%
import matplotlib.pyplot as plt 
from wordcloud import WordCloud, STOPWORDS
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
stop_w = set(STOPWORDS)
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Fatoni Murfid
# [nltk_data]     S\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import pandas as pd 
df = pd.read_csv('https://raw.githubusercontent.com/ghazafm/SocialMediaSentiment/main/preprocessing/csv/anis.csv')
df.head(10)
# Out:
#    Unnamed: 0        Date       User ID  Tweet Count         Tweet Location  \
# 0           0  2023-04-16  1.640000e+18           22                    NaN
# 1           1  2023-04-16  7.710306e+08        30121      Palmerah, Jakarta
# 2           2  2023-04-16  3.807551e+08          230        Jakarta - Utara
# 3           3  2023-04-16  9.210000e+17         2670               Jakarta
# 4           4  2023-04-16  1.540000e+18          766          Lebak, Banten
# 5           5  2023-04-16  6.342276e+08         5297  Jawa Barat, Indonesia
# 6           6  2023-04-16  6.342276e+08         5297  Jawa Barat, Indonesia
# 7           7  2023-04-16  6.342276e+08         5297  Jawa Barat, Indonesia
# 8           8  2023-04-16  1.714582e+08           35      Tangerang Selatan
# 9           9  2023-04-16  6.342276e+08         5297  Jawa Barat, Indonesia
#
#                                                Tweet     label  \
# 0                               info  anies presiden  Positive
# 1  politisi partai gerindra sandiaga uno menjawab...  Positive
# 2   lanjut pak anies kita kawal sampai jadi presiden  Positive
# 3  semoga allah swt menyelamatkan bangsa dan nega...  Positive
# 4  chotimah kasian ya pa anies makanya sudah teka...  Positive
# 5  kader pdip jadi presiden yang mana menterinya ...  Negative
# 6  jika tidak ada deklarasi dari partai pendukung...  Positive
# 7                                       suara rakyat  Positive
# 8  amien rais akan pilih prabowo subianto bila an...  Negative
# 9                             siapa dulu gunernurnya  Positive
#
#                 city
# 0                NaN
# 1           Palmerah
# 2    Jakarta - Utara
# 3           Jakarta
# 4              Lebak
# 5         Jawa Barat
# 6         Jawa Barat
# 7         Jawa Barat
# 8  Tangerang Selatan
# 9         Jawa Barat

# %%
sw = stopwords.words('indonesian')
df['Tweet'] = df['Tweet'].astype(str)
# keyword = ['ya','yg', 'maju', 'ampa','utk','gak']
# for i in keyword:
#     df['Tweet'] = df['Tweet'].str.replace(i,'')
result = ""
for text in df['Tweet']:
    result += text + " "


print(result)
# Out:
# info  anies presiden politisi partai gerindra sandiaga uno menjawab soal diduetkan kembali dengan mantan gubernur dki jakarta anies baswedan dalam pemilihan presiden mendatang lanjut pak anies kita kawal sampai jadi presiden semoga allah swt menyelamatkan bangsa dan negara republik indonesia dari para penghianat amanat rakyat yaa allah yang maha pengasih lagi maha penyayang angkatlah derajat bang anies rasyid baswedan menjadi presiden republik indonesia tahun dan seterusnya aamiin yra chotimah kasian ya pa anies makanya sudah tekad kluarga saya pilih pa anies presiden kader pdip jadi presiden yang mana menterinya impor pangan jika tidak ada deklarasi dari partai pendukung maka hasil survei ini tak bermanfaat suara rakyat amien rais akan pilih prabowo subianto bila anies baswedan gagal jadi calon presiden pada pilpres siapa dulu gunernurnya kpk bergerak keadilan bagi seluruh rakyat indonesia anies prabowo bisa jadi gubernur karena ada partai yang mendukungnya pikirin kenapa bisa kalah pejabat itu dari partai politik lu kritik partainya nggak terkejut lanjut ya sudah kita yang pro anies akan selalu berada di luar istana herianto anies cerdas sangat cocok presiden ri begitu sibuknya kalian urus capres kami anies baswedan rekam jejak anies yang kalian posting tidak mencerminkan prestasi sesungguhnya anies rakyat sudah cerdas menilai tenang saja anies kan jadi presiden ri id insya allah bang anies mjd presiden mantaap bkn itu sih konspirasi pasukan cebong sakit hati yg sgt kesel pks usung anies jd capres anies presiden cebong punah anies presidenlihat video asad mahrizal partai demokrat menyatakan kader partai gerindra sandiaga uno tak memenuhi kriteria calon wakil presiden cawapres pendamping anies baswedan di pilpres gabung yooo di relawan barisan nasional koalisi anies bersatu bnkab untuk gerakan perubahan anies for presiden call chat iklas gabung yo jadi relawan anies for presiden plase call insyaallah pak anies baswedan menjadi presiden ri doain aja ya biar kamu pengangguran buzzerrp dapet kerjaan gak kere kayak sekarang kasian semoga anies baswedan jadi presiden ri agar kasus rs sumber waras tuntas pembangunan ka cepat jakban mampus ayo kita perjuangkan anies baswedan sampai jadi presiden ri tahun tidak ada yang lain yang lain kalau tidak palsu berarti pengkhianat jangan lupa ngopi sebelum imsak fahnoor inismyname bowo pengkhianat orang berakal tidak akan mengulang kesalahan yang sama bersama rg dengan adanya wacana koalisi besar yang beranggotakan lima partai politik pendukung istana terlihat anies seperti sedang dikeroyok ketum partai keroyok anies yg bukan anggota partai anies baik kok ditakuti takut ya penjelasan oleh sebagian saksi kunci pendukung ab patut dijadikan tolak ukur utk menaikkan hasil survei anies untuk perubahan anies presiden moga anies jd presiden nkri aamiinaamiinaamiin knp takut sama anies baswedan presiden ri pak anies baswedan jadi presiden yakin itu achmadi yuk kita dukung anies baswedan presiden ri apapun judul lagunya tetap mviral glombang dukungan rakyat bagi anies baswedan abw sebagai calon presiden pada pemilu terus meningkat tiga partai dari koalisi perubahan yang mengusung anies baswedan menargetkan suara mantan gubernur dki jakarta itu saat pemilihan presiden pilpres bisa mencapai persen di ta id mari kita dukung anies baswedan presiden ri ini beneran nanya kah kalau beneran iya udah diganti sama pelaksana gubernur namanya pak heru jabatan anies cuman tahun aja sampe pak heru dari lucunya buat ngisi kekosongan bukannya pake orang yg udah dipilih rakyat malah orang yg dapet free pass presiden chotimah ganjar pranowo menang tapi anies baswedan tetap presiden indonesia priode insya allah pak anies presiden ri dan semua agama di negeri ini bangkit dan harmoni dalam bingkai nkri anies mundur dari calon presiden menyerahkan sepenuhnya pada kpu siapa yg akan dijadikan presiden gara postingan ini saya jadi tambah yakin bahwa tuduhan itu tidak berpengaruh buat pak anies yang memang cocok untuk jadi pre ...

# %%
# Membuka file teks baru dalam mode tulis ('w')
# with open('anies.txt', 'w') as file:
#     # Tulis string ke dalam file
#     file.write(result)

# %%
wc = WordCloud( background_color="white", max_words=50).generate(result)
# wc.to_file("anies.png")

# %%
from collections import Counter

# Misalkan 'result' adalah teks yang ingin Anda analisis

# Membagi teks menjadi kata-kata
words = result.split()

# Menghitung frekuensi kemunculan setiap kata
word_freq = Counter(words)

# Mengambil 10 kata yang paling sering muncul
top_words = word_freq.most_common(30)

# Menampilkan hasil
for word, freq in top_words:
    print(f"Kata: {word}, Jumlah: {freq}")
# Out:
# Kata: anies, Jumlah: 9270
# Kata: presiden, Jumlah: 7977
# Kata: baswedan, Jumlah: 3230
# Kata: dan, Jumlah: 2831
# Kata: di, Jumlah: 2505
# Kata: ri, Jumlah: 2131
# Kata: jadi, Jumlah: 1870
# Kata: pak, Jumlah: 1835
# Kata: indonesia, Jumlah: 1732
# Kata: yg, Jumlah: 1664
# Kata: jokowi, Jumlah: 1658
# Kata: yang, Jumlah: 1305
# Kata: untuk, Jumlah: 1157
# Kata: calon, Jumlah: 1064
# Kata: menjadi, Jumlah: 1016
# Kata: allah, Jumlah: 986
# Kata: rakyat, Jumlah: 953
# Kata: ini, Jumlah: 948
# Kata: partai, Jumlah: 891
# Kata: akan, Jumlah: 835
# Kata: ada, Jumlah: 757
# Kata: ke, Jumlah: 736
# Kata: sebagai, Jumlah: 727
# Kata: semoga, Jumlah: 685
# Kata: tahun, Jumlah: 642
# Kata: perubahan, Jumlah: 634
# Kata: pilpres, Jumlah: 623
# Kata: itu, Jumlah: 606
# Kata: pks, Jumlah: 588
# Kata: dari, Jumlah: 584
