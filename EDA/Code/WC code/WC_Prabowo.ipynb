# %%
import matplotlib.pyplot as plt 
from wordcloud import WordCloud, STOPWORDS
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
stop_w = set(STOPWORDS)
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Fatoni Murfid
# [nltk_data]     S\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import pandas as pd 
df = pd.read_csv('https://raw.githubusercontent.com/ghazafm/SocialMediaSentiment/main/preprocessing/csv/prabowo.csv')
df.head(10)
# Out:
#    Unnamed: 0        Date       User ID  Tweet Count      Tweet Location  \
# 0           0  2023-04-16  1.020000e+18        12568       Khoiril Anwar
# 1           1  2023-04-16  1.190000e+18        63723                 NaN
# 2           2  2023-04-16  1.600000e+18         6596                 NaN
# 3           3  2023-04-16  4.745574e+09         7395                 NaN
# 4           4  2023-04-16  1.600000e+18          192                 NaN
# 5           5  2023-04-16  5.767560e+08       293022  Kebumen, Indonesia
# 6           6  2023-04-16  1.590000e+18          103                 NaN
# 7           7  2023-04-16  8.030000e+17         5137                 NaN
# 8           8  2023-04-16  8.030000e+17         5137                 NaN
# 9           9  2023-04-16  1.630000e+18          237          Texas, USA
#
#                                                Tweet     label
# 0  gemira dan semeton muslim bali deklarasi dukun...  Positive
# 1    fahnoor inismyname makanya kita dukung presiden  Negative
# 2  jokowi kali ini jatahnya bg kerutan di wajah a...  Positive
# 3  selamat hut kopassus ke semoga semangat patrio...  Positive
# 4  partai gerindra badung menggelar rapat konsoli...  Negative
# 5            prabowo presiden cebong kampret pensiun  Negative
# 6  alhamdulillah presiden indonesia hanya ganjar ...  Negative
# 7  sebagian kegiatan kampanye calon presiden dan ...  Positive
# 8  gorontalo netizen mendoakan menteri pertahanan...  Positive
# 9                   presiden dah tp aq tetap prabowo  Positive

# %%
sw = stopwords.words('indonesian')
df['Tweet'] = df['Tweet'].astype(str)
# keyword = ['ya','yg', 'maju', 'ampa','utk','gak']
# for i in keyword:
#     df['Tweet'] = df['Tweet'].str.replace(i,'')
result = ""
for text in df['Tweet']:
    result += text + " "


print(result)
# Out:
# gemira dan semeton muslim bali deklarasi dukung prabowo presiden update berita fahnoor inismyname makanya kita dukung presiden jokowi kali ini jatahnya bg kerutan di wajah amp rambut putih identik dgn bg aura pak berpindah pada menjawab dengan tulus dan jujur setuju mantap gitu prabowo subianto selamat hut kopassus ke semoga semangat patriotisme terus menyala dihati menjadi garda terdepan dalam menjaga kedaulatan amp keamanan negara republik indonesia maju terus kopassus sehat selalu bapak jenderal prabowo subianto presiden ri partai gerindra badung menggelar rapat konsolidasi bacaleg prabowo presiden cebong kampret pensiun alhamdulillah presiden indonesia hanya ganjar pranowo yang dapat mempersatukan bangsa ini prabowo subianto dan anis baswedan kedua kandidat ini rekam jejaknya dikelilingi oleh kadrun dan cendana sebagian kegiatan kampanye calon presiden dan calon wakil presiden yang difasilitasi negara pada pemilihan presiden pilpres mendatang bisa didanai dari anggaran pendapatan dan belanja negara apbn prabowo subianto gorontalo netizen mendoakan menteri pertahanan prabowo subianto menjadi presiden ri pada pilpres prabowo subianto presiden dah tp aq tetap prabowo presiden ri bapak tulis komentar akun regar prabowo subianto lagilagi berbagai komentar datang dari netizen yang mendoakan prabowo menjadi presiden selanjutnya prabowo subianto komunitas pedagang tabanan bali deklarasi dukung prabowo jadi presiden jurnas dari tetap bersama pk prabowo semoga pk prabowo menjadi presiden ri periode gemira dan semeton muslim bali deklarasi dukung prabowo presiden istana presiden sudah menunggu jendral siap perintah jenderal sebagian kegiatan kampanye calon presiden dan calon wakil presiden yang difasilitasi negara pada pemilihan presiden pilpres mendatang bisa didanai dari anggaran pendapatan dan belanja negara apbn prabowo subianto gorontalo netizen mendoakan menteri pertahanan prabowo subianto menjadi presiden ri pada pilpres prabowo subianto sehat selalu bapak prabowo subianto presiden ri amien rais akan pilih prabowo subianto bila anies baswedan gagal jadi calon presiden pada pilpres anies prabowo inismyname fahnoor dasco sngt tergantung presiden yg akan terpilih di kl saya berfikir secara intelektual bukan ikutan hanya presiden yg punya wibawa yg bs membantu kondisi ekonomi indonesia bukan presiden model jokowi tapi presiden bukan saya ikutan yg lain ini sdh dr dl jaman ada sby mulyadi minta ketua dprd kabupaten bogor jadikan prabowo subianto presiden di pemilu bogor rumah utama gerindra rbg koordinasi bersama dpc gerindra kabsragen dengan dpd gerindra jateng tentang bacaleg bakal calon legislatif tahun nantinya salam indonesia raya gerindra menang prabowo presiden inismyname he he yang perlu itu memenangkan hati rakyat meskipun tidak harus jadi presiden ente aham prabowo subianto sang pelanggar ham berat tak pantas jadi presiden di indonesia saya yakin lebih dari separuh dps tersebut akan memilih pak sebagai presiden nkri mari kita berdoa bersama untuk kesehatan pak agar bisa mengikuti kontestasi pilpres sampai akhirnya bisa menghadiri acara pelantikan atau sebagai presiden ri ke aamiin maaf ya itu urusan pak jokowi aku ga ikut nimbrung mau merekom ganjar airlangga erick atau siapalah itu terserah pak jokowi karena beliau punya kepentingan sendiri aku hanya dukung pak prabowo jadi presiden prabowo presiden amin seleksi alambiarlah mereka datang tanpa diminta tanpa dikasih janji tapi mereka datang karena sadar begitu layaknya seorang untuk didukung meneruskan yang sudah lakukan untuk republik tercinta saya haqqul yakin pak prabowo akan memenangkan pilpres nanti dan akan menjadi presiden republik indonesia yang ke insya allah amin ya rabbal alamin elektabilitas prabowo berada di no setelah di endorse presiden jokowi pertanyaannya jika ijtima ulama kelompok rizieq shihab hti fpi pa gnpf ulama mendukung prabowo capres apa pendapat kalian berbagi takjil di badan pemenangan presiden prabowo di kawasan slipi fahnoor inismyname di bula ...

# %%
# # Membuka file teks baru dalam mode tulis ('w')
# with open('prabowo.txt', 'w') as file:
#     # Tulis string ke dalam file
#     file.write(result)

# %%
wc = WordCloud( background_color="white", max_words=50).generate(result)
# wc.to_file("prabowo.png")

# %%
from collections import Counter

# Misalkan 'result' adalah teks yang ingin Anda analisis

# Membagi teks menjadi kata-kata
words = result.split()

# Menghitung frekuensi kemunculan setiap kata
word_freq = Counter(words)

# Mengambil 10 kata yang paling sering muncul
top_words = word_freq.most_common(30)

# Menampilkan hasil
for word, freq in top_words:
    print(f"Kata: {word}, Jumlah: {freq}")
# Out:
# Kata: prabowo, Jumlah: 12267
# Kata: presiden, Jumlah: 9984
# Kata: subianto, Jumlah: 6403
# Kata: di, Jumlah: 3084
# Kata: dan, Jumlah: 2336
# Kata: pak, Jumlah: 2326
# Kata: sebagai, Jumlah: 2039
# Kata: untuk, Jumlah: 1983
# Kata: gerindra, Jumlah: 1968
# Kata: calon, Jumlah: 1959
# Kata: pilpres, Jumlah: 1828
# Kata: yang, Jumlah: 1760
# Kata: jadi, Jumlah: 1591
# Kata: indonesia, Jumlah: 1507
# Kata: jokowi, Jumlah: 1460
# Kata: menjadi, Jumlah: 1449
# Kata: partai, Jumlah: 1223
# Kata: pada, Jumlah: 1189
# Kata: pemilu, Jumlah: 1148
# Kata: ri, Jumlah: 1080
# Kata: ini, Jumlah: 1062
# Kata: capres, Jumlah: 1043
# Kata: dalam, Jumlah: 917
# Kata: maju, Jumlah: 900
# Kata: akan, Jumlah: 892
# Kata: itu, Jumlah: 828
# Kata: yg, Jumlah: 819
# Kata: dukungan, Jumlah: 783
# Kata: dengan, Jumlah: 712
# Kata: dukung, Jumlah: 702
