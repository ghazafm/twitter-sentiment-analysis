# %%
import pandas as pd
import numpy as np
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
df1_temp = pd.read_csv('/Users/fauzanghaza/Coding/SocialMediaSentiment/Indonesia Presidential Candidates Dataset, 2024/labeled data/Anies Baswedan.csv',encoding= 'ISO-8859-1')
df_anis = pd.read_csv('/Users/fauzanghaza/Coding/SocialMediaSentiment/Indonesia Presidential Candidates Dataset, 2024/original data/Anies Baswedan.csv',encoding= 'ISO-8859-1')
df2_temp = pd.read_csv('/Users/fauzanghaza/Coding/SocialMediaSentiment/Indonesia Presidential Candidates Dataset, 2024/labeled data/Prabowo Subianto.csv',encoding= 'ISO-8859-1')
df_prabowo = pd.read_csv('/Users/fauzanghaza/Coding/SocialMediaSentiment/Indonesia Presidential Candidates Dataset, 2024/original data/Prabowo Subianto.csv',encoding= 'ISO-8859-1')
df3_temp = pd.read_csv('/Users/fauzanghaza/Coding/SocialMediaSentiment/Indonesia Presidential Candidates Dataset, 2024/labeled data/Ganjar Pranowo.csv',encoding= 'ISO-8859-1')
df_ganjar = pd.read_csv('/Users/fauzanghaza/Coding/SocialMediaSentiment/Indonesia Presidential Candidates Dataset, 2024/original data/Ganjar Pranowo.csv',encoding= 'ISO-8859-1')

# %%
df_anis['label'] = df1_temp['label']
df_prabowo['label'] = df2_temp['label']
df_ganjar['label'] = df3_temp['label']

df_anis = df_anis[['Tweet','label']]
df_prabowo = df_prabowo[['Tweet','label']]
df_ganjar = df_ganjar[['Tweet','label']]

# %%
df = pd.concat([df_anis,df_prabowo,df_ganjar])

# %%
df.head()
# Out:
#                                                Tweet     label
# 0                               info  anies presiden  Positive
# 1  politisi partai gerindra sandiaga uno menjawab...  Positive
# 2   lanjut pak anies kita kawal sampai jadi presiden  Positive
# 3  semoga allah swt menyelamatkan bangsa dan nega...  Positive
# 4  chotimah kasian ya pa anies makanya sudah teka...  Positive

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/fauzanghaza/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
print(stopwords.words('indonesian'))
# Out:
# ['ada', 'adalah', 'adanya', 'adapun', 'agak', 'agaknya', 'agar', 'akan', 'akankah', 'akhir', 'akhiri', 'akhirnya', 'aku', 'akulah', 'amat', 'amatlah', 'anda', 'andalah', 'antar', 'antara', 'antaranya', 'apa', 'apaan', 'apabila', 'apakah', 'apalagi', 'apatah', 'artinya', 'asal', 'asalkan', 'atas', 'atau', 'ataukah', 'ataupun', 'awal', 'awalnya', 'bagai', 'bagaikan', 'bagaimana', 'bagaimanakah', 'bagaimanapun', 'bagi', 'bagian', 'bahkan', 'bahwa', 'bahwasanya', 'baik', 'bakal', 'bakalan', 'balik', 'banyak', 'bapak', 'baru', 'bawah', 'beberapa', 'begini', 'beginian', 'beginikah', 'beginilah', 'begitu', 'begitukah', 'begitulah', 'begitupun', 'bekerja', 'belakang', 'belakangan', 'belum', 'belumlah', 'benar', 'benarkah', 'benarlah', 'berada', 'berakhir', 'berakhirlah', 'berakhirnya', 'berapa', 'berapakah', 'berapalah', 'berapapun', 'berarti', 'berawal', 'berbagai', 'berdatangan', 'beri', 'berikan', 'berikut', 'berikutnya', 'berjumlah', 'berkali-kali', 'berkata', 'berkehendak', 'berkeingina
# ...

# %%
df.dropna(inplace=True)

# %%
df['label'].value_counts()
# Out:
# label
# Positive    21654
# Negative     8074
# Name: count, dtype: int64

# %%
keyword = ['anis','anies',]
for i in keyword:
    df['Tweet'] = df['Tweet'].str.replace(i,'')

# %%
df
# Out:
#                                                   Tweet     label
# 0                                       info   presiden  Positive
# 1     politisi partai gerindra sandiaga uno menjawab...  Positive
# 2           lanjut pak  kita kawal sampai jadi presiden  Positive
# 3     semoga allah swt menyelamatkan bangsa dan nega...  Positive
# 4     chotimah kasian ya pa  makanya sudah tekad klu...  Positive
# ...                                                 ...       ...
# 9995  rt ganjaristdltras ganjarist deltras jatim sia...  Positive
# 9996                    artinya ganjar pranowo presiden  Positive
# 9997  semakin banyak rakyat yang siap mendukung ganj...  Positive
# 9998  rt ganjaristdltras ganjarist deltras jatim sia...  Positive
# 9999  selamat hari penerbangan nasional oktober terb...  Positive
#
# [29728 rows x 2 columns]

# %%
port_stem = PorterStemmer()

# %%
def stemming(content):
    stemmed = re.sub('[^a-z]',' ',content)
    stemmed = stemmed.lower()
    stemmed = stemmed.split()
    stemmed = [port_stem.stem(word) for word in stemmed if not word in stopwords.words('indonesian')]
    stemmed = ' '.join(stemmed)
    return stemmed

# %%
df['stemmed'] = df['Tweet'].apply(stemming)

# %%
df.head()
# Out:
#                                                Tweet     label  \
# 0                                    info   presiden  Positive
# 1  politisi partai gerindra sandiaga uno menjawab...  Positive
# 2        lanjut pak  kita kawal sampai jadi presiden  Positive
# 3  semoga allah swt menyelamatkan bangsa dan nega...  Positive
# 4  chotimah kasian ya pa  makanya sudah tekad klu...  Positive
#
#                                              stemmed
# 0                                      info presiden
# 1  politisi partai gerindra sandiaga uno diduetka...
# 2                                     kawal presiden
# 3  semoga allah swt menyelamatkan bangsa negara r...
# 4  chotimah kasian ya pa tekad kluarga pilih pa p...

# %%
x =df['stemmed']
y =df['label']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, stratify=y, random_state=2)

# %%
print(x_train)
# Out:
# 9155         samosir yess moncer in sha allah presiden ri
# 3493    pdi perjuangan menghargai aspirasi wacana duet...
# 4743                                      dumdum presiden
# 4003    ahi insya allah presiden ri wakil presiden ri ...
# 2517                  pilih ganjar pranowo calon presiden
#                               ...
# 6157    elektabilita ganjar unggul calon presiden pranowo
# 7727                 jatim dukung ganjar presiden pranowo
# 2881    jalan sehat samarinda gerindra kaltim dukung p...
# 1527    prabowo ganjar presiden wapr ri lawan kadrunka...
# 7751    pengamat politik qodari pilihan presiden jokow...
# Name: stemmed, Length: 23782, dtype: object

# %%
print(x.shape, x_train.shape, x_test.shape)
# Out:
# (29728,) (23782,) (5946,)

# %%
vectorizer = TfidfVectorizer()

x_train = vectorizer.fit_transform(x_train)
x_test = vectorizer.transform(x_test)

# %%
print(x_test)
# Out:
#   (0, 20604)	0.20483772070688408
#   (0, 20140)	0.1664720394088853
#   (0, 19023)	0.28996371075500993
#   (0, 18346)	0.18985969480786796
#   (0, 13404)	0.19787366883729313
#   (0, 12566)	0.15997170873074262
#   (0, 11061)	0.22490010011556388
#   (0, 9607)	0.20081350913013288
#   (0, 9235)	0.19723124674200518
#   (0, 8183)	0.20547827783211306
#   (0, 7685)	0.21821245597040206
#   (0, 6880)	0.2244090321649628
#   (0, 6414)	0.19942370775561896
#   (0, 6194)	0.20352608241408035
#   (0, 5743)	0.22251543487825529
#   (0, 5734)	0.17023572450847682
#   (0, 4825)	0.286523120620902
#   (0, 4548)	0.2938099632900746
#   (0, 3876)	0.179383641571813
#   (0, 3629)	0.2040444330330138
#   (0, 2916)	0.27117496254022677
#   (1, 17078)	0.3206771342035532
#   (1, 16266)	0.12879161052205101
#   (1, 7541)	0.5458575899154815
#   (1, 1481)	0.3389023733094641
#   :	:
#   (5943, 16266)	0.049440840990144
#   (5943, 15689)	0.20212813027693313
#   (5943, 14786)	0.36079993408020816
# ...

# %%
model = LogisticRegression(max_iter=2000)

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=2000)

# %%
# Accuracy score
predict = model.predict(x_test)
accuracy = accuracy_score(y_test,predict)

# %%
print(accuracy)
# Out:
# 0.8271106626303397

# %%
contoh = ['adapun hal itu disampaikan hashim dalam sambutannya pada acara yang diselenggarakan prabowo mania deklarasikan prabowo subianto presiden di museum joang jakarta minggu',
'presiden indonesia tahun kata dia harus prabowo subianto',
'pasti dan pedofilia akan diberantas prabowo presiden',
'dukungan terhadap prabowo subianto untuk maju sebagai calon presiden pada pemilu datang dari sulawesi utaracapres pemilu dekade terusmajubersamaprabowo mendingprabowo mendingprabowo',
'pemerintah gak becus',
'pemerintah becus'

]
contoh = vectorizer.transform(contoh)
predict = model.predict(contoh)
print(predict)
# Out:
# ['Negative' 'Negative' 'Negative' 'Positive' 'Positive' 'Positive']
