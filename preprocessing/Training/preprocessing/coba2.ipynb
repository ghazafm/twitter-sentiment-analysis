# %%
import pandas as pd
from nltk import word_tokenize
from nltk.tag import CRFTagger
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# %%
factory = StemmerFactory()
stemmer = factory.create_stemmer()
def stemming(data):
   temp = []
   for tup in content:
      tup[0] = stemmer.stem(data)
      temp.append(tup)
   return temp

# %%
text = [('info', 'NN'), ('anies', 'NN'), ('presiden', 'NN')]

# %%
text.apply(stemming)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[145], line 1
# ----> 1 text.apply(stemming)
#
# AttributeError: 'list' object has no attribute 'apply'

# %%
df = pd.read_csv('../data/clean/gabungan.csv')

# %%
ct = CRFTagger()
ct.set_model_file('all_indo_man_tag_corpus_model.crf.tagger')

# %%
def tokenizer(text):
    text = word_tokenize(text)
    return text

# %%
df.isna().sum()
df.dropna(inplace=True)

# %%
df['tokenize'] = df['no_stopwords'].apply(tokenizer)
df['tokenize2'] = df['no_alay'].apply(tokenizer)

# %%
df['pos'] = ct.tag_sents(df.tokenize)
df['pos2'] = ct.tag_sents(df.tokenize2)

# %%
def join_text(df):
    temp = []
    for list in df:
        tup_join = ' '.join(list)
        temp.append(tup_join)
    return ' '.join(temp)

# %%
# df['last'] = df['pos'].apply(join_text)
# df['last2'] = df['pos2'].apply(join_text)

# %%
df
# Out:
#                                                    Tweet     label  \
# 0                                   info  anies presiden  Positive
# 1      politisi partai gerindra sandiaga uno menjawab...  Positive
# 2       lanjut pak anies kita kawal sampai jadi presiden  Positive
# 3      semoga allah swt menyelamatkan bangsa dan nega...  Positive
# 4      chotimah kasian ya pa anies makanya sudah teka...  Positive
# ...                                                  ...       ...
# 24713           pa ganjar pranowo nex presiden indonesia  Negative
# 24714  rt ganjaristdltras ganjarist deltras jatim sia...  Negative
# 24715                    artinya ganjar pranowo presiden  Negative
# 24716  semakin banyak rakyat yang siap mendukung ganj...  Negative
# 24717  selamat hari penerbangan nasional oktober terb...  Negative
#
#                                                  no_alay  \
# 0                                    info anies presiden
# ...

# %%
df.to_csv('oke.csv')
