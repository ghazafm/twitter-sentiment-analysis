# %%
import pandas as pd
import os

# %%
dir = os.getcwd()
df_anis = pd.read_csv('datasets/anis.csv')
df_prabowo = pd.read_csv('datasets/prabowo.csv')
df_ganjar = pd.read_csv('datasets/ganjar.csv')

# %%
stopwords = [
    'di','dan','jadi','yang','dan','pak','sebagai','untuk','ini','akan','menjadi','pada',
    'dengan','itu','ke','dari','jika','dalam','nanti','saya','bapak','kami','bisa','kalau',
    'rakyat','siapa','apa','ada','orang','kepada','bakal','atau','anda','sama','pasang','jelang',
    'sudah','tahun','hari','hanya','juga','tapi','rosiade','hal','kita','saat','adalah','masih',
    'bersama','mau','tetap','bahwa','karena','lagi','ingin','buat','kembali', 'for','bukan','semua',
    'terhadap','terus','dia','si','inilah','saja','kan','tak','oleh','banyak','belum','namun','meski',
    'lebih','keputusan','final','paling','hasil','mereka','para','umum','tepat','tersebut','total','klik',
    'telah','menurut','agar', 'capres','pilih','','pemilihan','terpilih','survei','survey',
    'pemilu','terkait','fahnoor','nan','calon','pilpres',
]
double_makna = [
    'maju',
    'hut',
    'dapat',
    'semoga',
    'beliau',
    'besar',
    'makin',
    'layak',
    'partai',
    'mendukung',
    'dukung',
    'dukungan',
    'gubernur',
    'masyarakat',
    'warga'
]
nama = [
    'inismyname',
    'indonesia',
    'joko',
    'jokowi'
    'widodo',
    'ridwan',
    'kamil',
    'rosiade',
    'thohir',
    'mujani',
    'erick',
    'saiful',
    'chotimah',
    'ahy',
    'bukan',
    'aniesahy',
    'ahmad',
    'pks',
    'pdip',
    'jawa',
    'puan',
    'maharani',
    'pan',
    'jateng',
    'tengah',
    'megawati',
    'ppp',
    'rasyid',
    'gerindra',



]

def clean_tweet(content):
    clean = str(content).lower()
    clean = clean.split()
    clean = [word for word in clean if not word in keyword]
    clean = [word for word in clean if not word in stopwords]
    clean = [word for word in clean if not word in double_makna]
    clean = [word for word in clean if not word in nama]
    clean = ' '.join(clean)
    return clean

# %%
def split(data):
    data = str(data)
    data = data.split(" ")
    for i in data:
        i = i.split(" ")
        split_word.extend(i)

# %%
word_anis_n = pd.DataFrame()
word_anis_p = pd.DataFrame()
word_prabowo_n = pd.DataFrame()
word_prabowo_p = pd.DataFrame()
word_ganjar_n = pd.DataFrame()
word_ganjar_p = pd.DataFrame()

# %%
word_anis_temp
# Out:
#       Unnamed: 0        Date       User ID  Tweet Count  \
# 2              5  2023-04-16  6.342276e+08         5297
# 5              8  2023-04-16  1.714582e+08           35
# 7             10  2023-04-16  6.342276e+08         5297
# 9             12  2023-04-16  6.342276e+08         5297
# 10            13  2023-04-16  6.342276e+08         5297
# ...          ...         ...           ...          ...
# 1870        9878  2023-01-07  9.179656e+07         3807
# 1871        9880  2023-01-06  3.351585e+08          115
# 1872        9889  2023-01-06  1.967453e+09         7230
# 1877        9931  2023-01-06  2.339265e+08          647
# 1882        9999  2023-01-05  1.620599e+08        27208
#
#              Tweet Location  \
# 2     Jawa Barat, Indonesia
# 5         Tangerang Selatan
# 7     Jawa Barat, Indonesia
# 9     Jawa Barat, Indonesia
# 10    Jawa Barat, Indonesia
# ...                     ...
# 1870              INDONESIA
# 1871               Jakarta
# 1872              Indonesia
# 1877                    NaN
# 1882              INDONESIA
#
#                                                   Tweet     label  \
# 2     kader pdip jadi presiden yang mana menterinya ...  Negative
# 5     amien rais akan pilih prabowo subianto bila an...  Negative
# 7     kpk bergerak keadilan bagi seluruh rakyat indo...  Negative
# 9     bisa jadi gubernur karena ada partai yang mend...  Negative
# 10                            pikirin kenapa bisa kalah  Negative
# ...                                                 ...       ...
# 1870  eh cebong memang kerjaan lo nyontek aja dari l...  Negative
# 1871  sdq waaah waahh ini salah anies nihhh coba ga ...  Negative
# 1872                               sudah mulai kampanye  Negative
# 1877                          tanjung anies presiden ri  Negative
# 1882  siapakah yg anda pilih presiden anies baswedan...  Negative
#
#                                                   Clean
# 2     kader pdip jadi yang mana menterinya impor pangan
# 5            amien rais akan pilih bila gagal jadi pada
# 7             kpk bergerak keadilan bagi seluruh rakyat
# 9     bisa jadi gubernur karena ada partai yang mend...
# 10                            pikirin kenapa bisa kalah
# ...                                                 ...
# 1870  eh cebong memang kerjaan lo nyontek dari lo mu...
# 1871  sdq waaah waahh ini salah nihhh coba ajukan di...
# 1872                               sudah mulai kampanye
# 1877                                            tanjung
# 1882  siapakah anda pilih puang maharani erick thohi...
#
# [596 rows x 8 columns]

# %%
split_word = []
word_anis_n = df_anis[df_anis['label'] == 'Negative'] 
word_anis_n = word_anis_n['Clean'].apply(clean_tweet)
print(word_anis_n)
word_anis_n = word_anis_n.apply(split)
split_word = pd.DataFrame(split_word)
split_word.dropna(inplace=True)
split_word.to_csv('word_cloud/anis/negative.csv')

split_word = []
word_anis_p = df_anis[df_anis['label'] == 'Positive']
word_anis_p = word_anis_p['Clean'].apply(clean_tweet)
word_anis_p = word_anis_p.apply(split)
split_word = pd.DataFrame(split_word)
split_word.dropna(inplace=True)
split_word.to_csv('word_cloud/anis/positive.csv')
# Out:
# 2                      kader mana menterinya impor pangan
# 5                                   amien rais bila gagal
# 7                      kpk bergerak keadilan bagi seluruh
# 9                                            mendukungnya
# 10                                   pikirin kenapa kalah
#                               ...
# 1870    eh cebong memang kerjaan lo nyontek lo mulai s...
# 1871    sdq waaah waahh salah nihhh coba ajukan diri b...
# 1872                                       mulai kampanye
# 1877                                              tanjung
# 1882    siapakah puang erlangga emil votes berikan vot...
# Name: Clean, Length: 596, dtype: object

# %%
split_word = [[],[]]
word_prabowo_n = df_prabowo[df_prabowo['label'] == 'Negative']
word_prabowo_n = word_prabowo_n['Clean'].apply(clean_tweet)
word_prabowo_n = word_prabowo_n.apply(split)
split_word = pd.DataFrame(split_word)
split_word.dropna(inplace=True)
split_word.to_csv('word_cloud/prabowo/negative.csv')

split_word = [[],[]]
word_prabowo_p = df_prabowo[df_prabowo['label'] == 'Positive']
word_prabowo_p = word_prabowo_p['Clean'].apply(clean_tweet)
word_prabowo_p = word_prabowo_p.apply(split)
split_word = pd.DataFrame(split_word)
split_word.dropna(inplace=True)
split_word.to_csv('word_cloud/prabowo/positive.csv')

# %%
split_word = [[],[]]
word_ganjar_n = df_ganjar[df_ganjar['label'] == 'Negative']
word_ganjar_n = word_ganjar_n['Clean'].apply(clean_tweet)
word_ganjar_n = word_ganjar_n.apply(split)
split_word = pd.DataFrame(split_word)
split_word.dropna(inplace=True)
print(split_word.shape)
split_word.to_csv('word_cloud/ganjar/negative.csv')

split_word = [[],[]]
word_ganjar_p = df_ganjar[df_ganjar['label'] == 'Positive']
word_ganjar_p = word_ganjar_p['Clean'].apply(clean_tweet) 
word_ganjar_p = word_ganjar_p.apply(split)
split_word = pd.DataFrame(split_word)
split_word.dropna(inplace=True)
print(split_word.shape)
split_word.to_csv('word_cloud/ganjar/positive.csv')
# Out:
# (1, 18)
# (2, 26)

# %%
df1 = pd.read_csv('word_cloud/anis/positive.csv')
df2 = pd.read_csv('word_cloud/prabowo/positive.csv')
df3 = pd.read_csv('word_cloud/ganjar/positive.csv')

positive = pd.concat([df1,df2,df3])
positive.to_csv('word_cloud/gabungan/positive.csv')

# %%
df1 = pd.read_csv('word_cloud/anis/negative.csv')
df2 = pd.read_csv('word_cloud/prabowo/negative.csv')
df3 = pd.read_csv('word_cloud/ganjar/negative.csv')

negative = pd.concat([df1,df2,df3])
negative.to_csv('word_cloud/gabungan/negative.csv')
