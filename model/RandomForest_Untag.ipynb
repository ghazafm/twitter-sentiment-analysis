# %% [markdown]
# # Dataframe

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('https://raw.githubusercontent.com/ghazafm/SocialMediaSentiment/main/preprocessing/Training/data/clean/regular/gabungan.csv')
df = df.dropna()
# Out:
# /var/folders/4f/xq7119ld627_2wyd6dkmwl0m0000gn/T/ipykernel_6260/2075837873.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df
# Out:
#                                                    Tweet     label  \
# 0                                   info  anies presiden  Positive
# 1      politisi partai gerindra sandiaga uno menjawab...  Positive
# 2       lanjut pak anies kita kawal sampai jadi presiden  Positive
# 3      semoga allah swt menyelamatkan bangsa dan nega...  Positive
# 4      chotimah kasian ya pa anies makanya sudah teka...  Positive
# ...                                                  ...       ...
# 24713           pa ganjar pranowo nex presiden indonesia  Negative
# 24714  rt ganjaristdltras ganjarist deltras jatim sia...  Negative
# 24715                    artinya ganjar pranowo presiden  Negative
# 24716  semakin banyak rakyat yang siap mendukung ganj...  Negative
# 24717  selamat hari penerbangan nasional oktober terb...  Negative
#
#                                                  no_alay  \
# 0                                    info anies presiden
# 1      politisi partai gerindra sandiaga uno menjawab...
# 2       lanjut pak anies kita kawal sampai jadi presiden
# 3      semoga allah swt menyelamatkan bangsa dan nega...
# 4      chotimah kasihan ya apa anies makanya sudah te...
# ...                                                  ...
# 24713          apa ganjar pranowo nex presiden indonesia
# 24714  rt ganjaristdltras ganjarist deltras jatim sia...
# 24715                    artinya ganjar pranowo presiden
# 24716  semakin banyak rakyat yang siap mendukung ganj...
# 24717  selamat hari penerbangan nasional oktober terb...
#
#                                             clean_manual  \
# 0                                                   info
# 1      politisi menjawab soal diduetkan kembali denga...
# 2                           lanjut pak kita kawal sampai
# 3      swt menyelamatkan bangsa dan negara republik d...
# 4           kasihan ya makanya sudah tekad keluarga saya
# ...                                                  ...
# 24713                                                nex
# 24714    rt ganjaristdltras ganjarist deltras jatim siap
# 24715                                            artinya
# 24716  semakin yang siap untuk sebagai ke selamat ula...
# 24717  selamat penerbangan nasional oktober terbangla...
#
#                                                  stemmed  \
# 0                                                   info
# 1      politis jawab soal duet kembali dengan mantan ...
# 2                           lanjut pak kita kawal sampai
# 3      swt selamat bangsa dan negara republik dari pa...
# 4           kasihan ya makanya sudah tekad keluarga saya
# ...                                                  ...
# 24713                                                nex
# 24714    rt ganjaristdltras ganjarist deltras jatim siap
# 24715                                               arti
# 24716  makin yang siap untuk bagai ke selamat ulang p...
# 24717  selamat terbang nasional oktober terbang tingg...
#
#                                             no_stopwords
# 0                                                   info
# 1      politis jawab soal duet dengan mantan dki jaka...
# 2                                       lanjut pak kawal
# 3      swt selamat bangsa negara republik para penghi...
# 4                         kasihan makanya tekad keluarga
# ...                                                  ...
# 24713                                                nex
# 24714    rt ganjaristdltras ganjarist deltras jatim siap
# 24715                                               arti
# 24716           makin siap bagai selamat ulang pak tuhan
# 24717  selamat terbang nasional oktober terbang tingg...
#
# [24384 rows x 6 columns]

# %% [markdown]
# # Function

# %%
# label encoder
def label_encoder(y):
    from sklearn.preprocessing import LabelEncoder
    le = LabelEncoder()
    y = le.fit_transform(y)
    return y

# under dan over sampling
def undersampling(x, y):
    from imblearn.under_sampling import RandomUnderSampler
    rus = RandomUnderSampler()
    x, y = rus.fit_resample(x.values.reshape(-1,1),y)
    x = x.flatten()
    return x, y

def oversampling(x, y):
    from imblearn.over_sampling import RandomOverSampler
    ros = RandomOverSampler()
    x, y = ros.fit_resample(x.values.reshape(-1,1),y)
    x = x.flatten()
    return x, y

# train test split
def bagi_data(x, y):
    from sklearn.model_selection import train_test_split
    x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=2)
    return x_train, x_test, y_train, y_test

# cetak csv
def cetak_csv(data):
    data.to_csv('name.csv')

# Vectorizing
def tfidf_vec(x_train, x_test):
    from sklearn.feature_extraction.text import TfidfVectorizer
    vectorizer = TfidfVectorizer()
    x_train = vectorizer.fit_transform(x_train)
    x_test = vectorizer.transform(x_test)
    return x_train, x_test

def count_vec(x_train, x_test):
    from sklearn.feature_extraction.text import CountVectorizer
    vectorizer = CountVectorizer()
    x_train = vectorizer.fit_transform(x_train)
    x_test = vectorizer.transform(x_test)
    return x_train, x_test

# Accuracy Score
def accuracy_score(y_test, y_pred):
    from sklearn.metrics import accuracy_score
    
    accuracy = accuracy_score(y_test, y_pred)
    return accuracy

def f1_score_pos(x):
    from sklearn.metrics import f1_score
    f1 = f1_score(x,pos_label='Positive')
    return f1
def f1_score_neg(x):
    from sklearn.metrics import f1_score
    f1 = f1_score(x,pos_label='Negative')
    return f1

def precission_pos(x):
    from sklearn.metrics import precision_score
    precision = precision_score(x,pos_label='Positive')
    return precision

def precission_neg(x):
    from sklearn.metrics import precision_score
    precision = precision_score(x,pos_label='Negative')
    return precision

def recall_pos(x):
    from sklearn.metrics import recall_score
    recall = recall_score(x,'Positive')
    return recall

def recall_neg(x):
    from sklearn.metrics import recall_score
    recall = recall_score(x,'Negative')
    return recall

def all_report (x,y):
    from sklearn.metrics import classification_report
    report = classification_report(x,y)
    return report

# %% [markdown]
# # splitting & under sampling

# %%
x = df['clean_manual']
y = df['label']

x, y = undersampling(x, y)

x_train, x_test, y_train, y_test = bagi_data(x, y)

y.value_counts()
# Out:
# label
# Negative    8770
# Positive    8770
# Name: count, dtype: int64

# %% [markdown]
# # TF-idf vectorizing

# %%
x_train, x_test = tfidf_vec(x_train, x_test)

# %% [markdown]
# # Modeling

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
random_forest = RandomForestClassifier(random_state=42, bootstrap=True, max_depth=40, max_features='sqrt', n_estimators=200)

# %%
parameter = {
    "n_estimators": [100, 200, 400],
    "max_features": ["auto", "sqrt"],
    "max_depth": [10, 20, 40],
    "bootstrap": [True,False]
}

from sklearn.model_selection import GridSearchCV
GS = GridSearchCV(estimator = random_forest,
                    param_grid = parameter,
                    scoring = 'accuracy', 
                    refit = 'accuracy',
                    cv=5,
                    verbose = 4)

# %%
GS.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV 1/5] END bootstrap=True, max_depth=10, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, max_depth=10, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, max_depth=10, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, max_depth=10, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, max_depth=10, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, max_depth=10, max_features=auto, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, max_depth=10, max_features=auto, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, max_depth=10, max_features=auto, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, max_depth=10, max_features=auto, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, max_depth=10, max_features=auto, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, max_depth=10, max_features=auto, n_estimators=400;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, max_depth=10, max_features=auto, n_estimators=400;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, max_depth=10, max_features=auto, n_estimators=400;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, max_depth=10, max_features=auto, n_estimators=400;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, max_depth=10, max_features=auto, n_estimators=400;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.561 total time=   1.7s
# [CV 2/5] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.550 total time=   1.6s
# [CV 3/5] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.581 total time=   1.6s
# [CV 4/5] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.561 total time=   1.7s
# [CV 5/5] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.556 total time=   1.6s
# [CV 1/5] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.585 total time=   3.6s
# [CV 2/5] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.564 total time=   3.6s
# [CV 3/5] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.567 total time=   3.6s
# [CV 4/5] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.565 total time=   3.6s
# [CV 5/5] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.568 total time=   3.6s
# [CV 1/5] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=400;, score=0.584 total time=   7.0s
# [CV 2/5] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=400;, score=0.569 total time=   7.0s
# [CV 3/5] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=400;, score=0.560 total time=   7.1s
# [CV 4/5] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=400;, score=0.578 total time=   7.3s
# [CV 5/5] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=400;, score=0.565 total time=   7.1s
# [CV 1/5] END bootstrap=True, max_depth=20, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, max_depth=20, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, max_depth=20, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, max_depth=20, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, max_depth=20, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, max_depth=20, max_features=auto, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, max_depth=20, max_features=auto, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, max_depth=20, max_features=auto, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, max_depth=20, max_features=auto, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, max_depth=20, max_features=auto, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, max_depth=20, max_features=auto, n_estimators=400;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, max_depth=20, max_features=auto, n_estimators=400;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, max_depth=20, max_features=auto, n_estimators=400;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, max_depth=20, max_features=auto, n_estimators=400;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, max_depth=20, max_features=auto, n_estimators=400;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=100;, score=0.580 total time=   3.8s
# [CV 2/5] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=100;, score=0.549 total time=   3.9s
# [CV 3/5] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=100;, score=0.569 total time=   3.8s
# [CV 4/5] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=100;, score=0.567 total time=   3.7s
# [CV 5/5] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=100;, score=0.569 total time=   3.8s
# [CV 1/5] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.577 total time=   7.7s
# [CV 2/5] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.559 total time=   7.5s
# [CV 3/5] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.560 total time=   7.5s
# [CV 4/5] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.579 total time=   7.5s
# [CV 5/5] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.572 total time=   7.6s
# [CV 1/5] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=400;, score=0.576 total time=  15.6s
# [CV 2/5] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=400;, score=0.561 total time=  15.1s
# [CV 3/5] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=400;, score=0.557 total time=  15.1s
# [CV 4/5] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=400;, score=0.581 total time=  15.0s
# [CV 5/5] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=400;, score=0.573 total time=  15.2s
# [CV 1/5] END bootstrap=True, max_depth=40, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, max_depth=40, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, max_depth=40, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, max_depth=40, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, max_depth=40, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, max_depth=40, max_features=auto, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, max_depth=40, max_features=auto, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, max_depth=40, max_features=auto, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, max_depth=40, max_features=auto, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, max_depth=40, max_features=auto, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, max_depth=40, max_features=auto, n_estimators=400;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, max_depth=40, max_features=auto, n_estimators=400;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, max_depth=40, max_features=auto, n_estimators=400;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, max_depth=40, max_features=auto, n_estimators=400;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, max_depth=40, max_features=auto, n_estimators=400;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, max_depth=40, max_features=sqrt, n_estimators=100;, score=0.574 total time=   8.7s
# [CV 2/5] END bootstrap=True, max_depth=40, max_features=sqrt, n_estimators=100;, score=0.556 total time=   8.6s
# [CV 3/5] END bootstrap=True, max_depth=40, max_features=sqrt, n_estimators=100;, score=0.571 total time=   8.6s
# [CV 4/5] END bootstrap=True, max_depth=40, max_features=sqrt, n_estimators=100;, score=0.570 total time=   8.6s
# [CV 5/5] END bootstrap=True, max_depth=40, max_features=sqrt, n_estimators=100;, score=0.576 total time=   8.6s
# [CV 1/5] END bootstrap=True, max_depth=40, max_features=sqrt, n_estimators=200;, score=0.580 total time=  17.6s
# [CV 2/5] END bootstrap=True, max_depth=40, max_features=sqrt, n_estimators=200;, score=0.559 total time=  17.4s
# [CV 3/5] END bootstrap=True, max_depth=40, max_features=sqrt, n_estimators=200;, score=0.563 total time=  17.2s
# [CV 4/5] END bootstrap=True, max_depth=40, max_features=sqrt, n_estimators=200;, score=0.581 total time=  17.2s
# [CV 5/5] END bootstrap=True, max_depth=40, max_features=sqrt, n_estimators=200;, score=0.576 total time=  17.5s
# [CV 1/5] END bootstrap=True, max_depth=40, max_features=sqrt, n_estimators=400;, score=0.582 total time=  35.0s
# [CV 2/5] END bootstrap=True, max_depth=40, max_features=sqrt, n_estimators=400;, score=0.557 total time=  35.0s
# [CV 3/5] END bootstrap=True, max_depth=40, max_features=sqrt, n_estimators=400;, score=0.566 total time=  34.4s
# [CV 4/5] END bootstrap=True, max_depth=40, max_features=sqrt, n_estimators=400;, score=0.575 total time=  34.6s
# [CV 5/5] END bootstrap=True, max_depth=40, max_features=sqrt, n_estimators=400;, score=0.572 total time=  35.1s
# [CV 1/5] END bootstrap=False, max_depth=10, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=False, max_depth=10, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=False, max_depth=10, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=False, max_depth=10, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=False, max_depth=10, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=False, max_depth=10, max_features=auto, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=False, max_depth=10, max_features=auto, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=False, max_depth=10, max_features=auto, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=False, max_depth=10, max_features=auto, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=False, max_depth=10, max_features=auto, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=False, max_depth=10, max_features=auto, n_estimators=400;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=False, max_depth=10, max_features=auto, n_estimators=400;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=False, max_depth=10, max_features=auto, n_estimators=400;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=False, max_depth=10, max_features=auto, n_estimators=400;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=False, max_depth=10, max_features=auto, n_estimators=400;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.561 total time=   2.4s
# [CV 2/5] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.546 total time=   2.4s
# [CV 3/5] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.546 total time=   2.4s
# [CV 4/5] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.567 total time=   2.4s
# [CV 5/5] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.550 total time=   2.4s
# [CV 1/5] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.564 total time=   4.8s
# [CV 2/5] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.550 total time=   4.8s
# [CV 3/5] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.542 total time=   4.8s
# [CV 4/5] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.568 total time=   4.9s
# [CV 5/5] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.555 total time=   4.9s
# [CV 1/5] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=400;, score=0.577 total time=   9.7s
# [CV 2/5] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=400;, score=0.549 total time=   9.7s
# [CV 3/5] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=400;, score=0.538 total time=   9.8s
# [CV 4/5] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=400;, score=0.566 total time=   9.8s
# [CV 5/5] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=400;, score=0.558 total time=  10.0s
# [CV 1/5] END bootstrap=False, max_depth=20, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=False, max_depth=20, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=False, max_depth=20, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=False, max_depth=20, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=False, max_depth=20, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=False, max_depth=20, max_features=auto, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=False, max_depth=20, max_features=auto, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=False, max_depth=20, max_features=auto, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=False, max_depth=20, max_features=auto, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=False, max_depth=20, max_features=auto, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=False, max_depth=20, max_features=auto, n_estimators=400;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=False, max_depth=20, max_features=auto, n_estimators=400;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=False, max_depth=20, max_features=auto, n_estimators=400;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=False, max_depth=20, max_features=auto, n_estimators=400;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=False, max_depth=20, max_features=auto, n_estimators=400;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=False, max_depth=20, max_features=sqrt, n_estimators=100;, score=0.564 total time=   5.6s
# [CV 2/5] END bootstrap=False, max_depth=20, max_features=sqrt, n_estimators=100;, score=0.547 total time=   5.6s
# [CV 3/5] END bootstrap=False, max_depth=20, max_features=sqrt, n_estimators=100;, score=0.545 total time=   5.6s
# [CV 4/5] END bootstrap=False, max_depth=20, max_features=sqrt, n_estimators=100;, score=0.565 total time=   5.6s
# [CV 5/5] END bootstrap=False, max_depth=20, max_features=sqrt, n_estimators=100;, score=0.556 total time=   5.5s
# [CV 1/5] END bootstrap=False, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.568 total time=  11.0s
# [CV 2/5] END bootstrap=False, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.547 total time=  11.1s
# [CV 3/5] END bootstrap=False, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.542 total time=  11.1s
# [CV 4/5] END bootstrap=False, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.563 total time=  11.2s
# [CV 5/5] END bootstrap=False, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.560 total time=  11.1s
# [CV 1/5] END bootstrap=False, max_depth=20, max_features=sqrt, n_estimators=400;, score=0.564 total time=  22.4s
# [CV 2/5] END bootstrap=False, max_depth=20, max_features=sqrt, n_estimators=400;, score=0.544 total time=  22.4s
# [CV 3/5] END bootstrap=False, max_depth=20, max_features=sqrt, n_estimators=400;, score=0.548 total time=  22.6s
# [CV 4/5] END bootstrap=False, max_depth=20, max_features=sqrt, n_estimators=400;, score=0.558 total time=  22.5s
# [CV 5/5] END bootstrap=False, max_depth=20, max_features=sqrt, n_estimators=400;, score=0.554 total time=  22.5s
# [CV 1/5] END bootstrap=False, max_depth=40, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=False, max_depth=40, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=False, max_depth=40, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=False, max_depth=40, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=False, max_depth=40, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=False, max_depth=40, max_features=auto, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=False, max_depth=40, max_features=auto, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=False, max_depth=40, max_features=auto, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=False, max_depth=40, max_features=auto, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=False, max_depth=40, max_features=auto, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=False, max_depth=40, max_features=auto, n_estimators=400;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=False, max_depth=40, max_features=auto, n_estimators=400;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=False, max_depth=40, max_features=auto, n_estimators=400;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=False, max_depth=40, max_features=auto, n_estimators=400;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=False, max_depth=40, max_features=auto, n_estimators=400;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=False, max_depth=40, max_features=sqrt, n_estimators=100;, score=0.587 total time=  13.3s
# [CV 2/5] END bootstrap=False, max_depth=40, max_features=sqrt, n_estimators=100;, score=0.532 total time=  13.1s
# [CV 3/5] END bootstrap=False, max_depth=40, max_features=sqrt, n_estimators=100;, score=0.553 total time=  13.1s
# [CV 4/5] END bootstrap=False, max_depth=40, max_features=sqrt, n_estimators=100;, score=0.577 total time=  13.2s
# [CV 5/5] END bootstrap=False, max_depth=40, max_features=sqrt, n_estimators=100;, score=0.569 total time=  13.2s
# [CV 1/5] END bootstrap=False, max_depth=40, max_features=sqrt, n_estimators=200;, score=0.589 total time=  26.8s
# [CV 2/5] END bootstrap=False, max_depth=40, max_features=sqrt, n_estimators=200;, score=0.546 total time=  26.6s
# [CV 3/5] END bootstrap=False, max_depth=40, max_features=sqrt, n_estimators=200;, score=0.548 total time=  26.2s
# [CV 4/5] END bootstrap=False, max_depth=40, max_features=sqrt, n_estimators=200;, score=0.568 total time=  26.3s
# [CV 5/5] END bootstrap=False, max_depth=40, max_features=sqrt, n_estimators=200;, score=0.568 total time=  26.9s
# [CV 1/5] END bootstrap=False, max_depth=40, max_features=sqrt, n_estimators=400;, score=0.586 total time=  54.4s
# [CV 2/5] END bootstrap=False, max_depth=40, max_features=sqrt, n_estimators=400;, score=0.549 total time=  55.0s
# [CV 3/5] END bootstrap=False, max_depth=40, max_features=sqrt, n_estimators=400;, score=0.548 total time=  52.5s
# [CV 4/5] END bootstrap=False, max_depth=40, max_features=sqrt, n_estimators=400;, score=0.565 total time=  53.1s
# [CV 5/5] END bootstrap=False, max_depth=40, max_features=sqrt, n_estimators=400;, score=0.581 total time=  53.7s
# C:\Users\Fatoni Murfid S\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 90 fits failed out of a total of 180.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 90 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Fatoni Murfid S\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Fatoni Murfid S\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Fatoni Murfid S\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Fatoni Murfid S\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Fatoni Murfid S\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan 0.5617882  0.56983968 0.57105117
#         nan        nan        nan 0.56691882 0.56934169 0.56955547
#         nan        nan        nan 0.5691996  0.57169361 0.5704106
#         nan        nan        nan 0.55416194 0.55572958 0.55765311
#         nan        nan        nan 0.55523088 0.55587205 0.55359174
#         nan        nan        nan 0.56364084 0.5638535  0.56584922]
#   warnings.warn(
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#              param_grid={'bootstrap': [True, False], 'max_depth': [10, 20, 40],
#                          'max_features': ['auto', 'sqrt'],
#                          'n_estimators': [100, 200, 400]},
#              refit='accuracy', scoring='accuracy', verbose=4)

# %%
GS.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 40,
#  'max_features': 'sqrt',
#  'n_estimators': 200}

# %%
random_forest.fit(x_train, y_train)
    
y_pred = random_forest.predict(x_test)

# %% [markdown]
# # Score Random Forest untag

# %%
print(all_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.59      0.49      0.54      1708
#     Positive       0.58      0.68      0.63      1800
#
#     accuracy                           0.59      3508
#    macro avg       0.59      0.58      0.58      3508
# weighted avg       0.59      0.59      0.58      3508

# %%
# from sklearn.metrics import f1_score

# # Menghitung F1-score dengan label positif "1"
# f1 = f1_score(y_test, y_pred, pos_label='Negative')

# # Mencetak hasil
# print("F1 Score:", f1)
# Out:
# F1 Score: 0.5796359499431172
