# %% [markdown]
# # Dataframe

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('https://raw.githubusercontent.com/ghazafm/SocialMediaSentiment/main/preprocessing/Training/data/clean/regular/gabungan.csv')
df = df.dropna()

# %%
df
# Out:
#                                                    Tweet     label  \
# 0                                   info  anies presiden  Positive
# 1      politisi partai gerindra sandiaga uno menjawab...  Positive
# 2       lanjut pak anies kita kawal sampai jadi presiden  Positive
# 3      semoga allah swt menyelamatkan bangsa dan nega...  Positive
# 4      chotimah kasian ya pa anies makanya sudah teka...  Positive
# ...                                                  ...       ...
# 24713           pa ganjar pranowo nex presiden indonesia  Negative
# 24714  rt ganjaristdltras ganjarist deltras jatim sia...  Negative
# 24715                    artinya ganjar pranowo presiden  Negative
# 24716  semakin banyak rakyat yang siap mendukung ganj...  Negative
# 24717  selamat hari penerbangan nasional oktober terb...  Negative
#
#                                                  no_alay  \
# 0                                    info anies presiden
# 1      politisi partai gerindra sandiaga uno menjawab...
# 2       lanjut pak anies kita kawal sampai jadi presiden
# 3      semoga allah swt menyelamatkan bangsa dan nega...
# 4      chotimah kasihan ya apa anies makanya sudah te...
# ...                                                  ...
# 24713          apa ganjar pranowo nex presiden indonesia
# 24714  rt ganjaristdltras ganjarist deltras jatim sia...
# 24715                    artinya ganjar pranowo presiden
# 24716  semakin banyak rakyat yang siap mendukung ganj...
# 24717  selamat hari penerbangan nasional oktober terb...
#
#                                             clean_manual  \
# 0                                                   info
# 1      politisi menjawab soal diduetkan kembali denga...
# 2                           lanjut pak kita kawal sampai
# 3      swt menyelamatkan bangsa dan negara republik d...
# 4           kasihan ya makanya sudah tekad keluarga saya
# ...                                                  ...
# 24713                                                nex
# 24714    rt ganjaristdltras ganjarist deltras jatim siap
# 24715                                            artinya
# 24716  semakin yang siap untuk sebagai ke selamat ula...
# 24717  selamat penerbangan nasional oktober terbangla...
#
#                                                  stemmed  \
# 0                                                   info
# 1      politis jawab soal duet kembali dengan mantan ...
# 2                           lanjut pak kita kawal sampai
# 3      swt selamat bangsa dan negara republik dari pa...
# 4           kasihan ya makanya sudah tekad keluarga saya
# ...                                                  ...
# 24713                                                nex
# 24714    rt ganjaristdltras ganjarist deltras jatim siap
# 24715                                               arti
# 24716  makin yang siap untuk bagai ke selamat ulang p...
# 24717  selamat terbang nasional oktober terbang tingg...
#
#                                             no_stopwords
# 0                                                   info
# 1      politis jawab soal duet dengan mantan dki jaka...
# 2                                       lanjut pak kawal
# 3      swt selamat bangsa negara republik para penghi...
# 4                         kasihan makanya tekad keluarga
# ...                                                  ...
# 24713                                                nex
# 24714    rt ganjaristdltras ganjarist deltras jatim siap
# 24715                                               arti
# 24716           makin siap bagai selamat ulang pak tuhan
# 24717  selamat terbang nasional oktober terbang tingg...
#
# [24384 rows x 6 columns]

# %% [markdown]
# # Function

# %%
# label encoder
def label_encoder(y):
    from sklearn.preprocessing import LabelEncoder
    le = LabelEncoder()
    y = le.fit_transform(y)
    return y

# under dan over sampling
def undersampling(x, y):
    from imblearn.under_sampling import RandomUnderSampler
    rus = RandomUnderSampler()
    x, y = rus.fit_resample(x.values.reshape(-1,1),y)
    x = x.flatten()
    return x, y

def oversampling(x, y):
    from imblearn.over_sampling import RandomOverSampler
    ros = RandomOverSampler()
    x, y = ros.fit_resample(x.values.reshape(-1,1),y)
    x = x.flatten()
    return x, y

# train test split
def bagi_data(x, y):
    from sklearn.model_selection import train_test_split
    x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=2)
    return x_train, x_test, y_train, y_test

# cetak csv
def cetak_csv(data):
    data.to_csv('name.csv')

# Vectorizing
def tfidf_vec(x_train, x_test):
    from sklearn.feature_extraction.text import TfidfVectorizer
    vectorizer = TfidfVectorizer()
    x_train = vectorizer.fit_transform(x_train)
    x_test = vectorizer.transform(x_test)
    return x_train, x_test

def count_vec(x_train, x_test):
    from sklearn.feature_extraction.text import CountVectorizer
    vectorizer = CountVectorizer()
    x_train = vectorizer.fit_transform(x_train)
    x_test = vectorizer.transform(x_test)
    return x_train, x_test

# Metric Scorer
def accuracy_score(y_test, y_pred):
    from sklearn.metrics import accuracy_score
    
    accuracy = accuracy_score(y_test, y_pred)
    return accuracy

def f1_score_pos(x,y):
    from sklearn.metrics import f1_score
    f1 = f1_score(x,y,pos_label='Positive')
    return f1
def f1_score_neg(x,y):
    from sklearn.metrics import f1_score
    f1 = f1_score(x,y,pos_label='Negative')
    return f1

def precission_pos(x,y):
    from sklearn.metrics import precision_score
    precision = precision_score(x,y,pos_label='Positive')
    return precision
def precission_neg(x,y):
    from sklearn.metrics import precision_score
    precision = precision_score(x,y,pos_label='Negative')
    return precision

def recall_pos(x,y):
    from sklearn.metrics import recall_score
    recall = recall_score(x,y,'Positive')
    return recall
def recall_neg(x,y):
    from sklearn.metrics import recall_score
    recall = recall_score(x,y,'Negative')
    return recall

def all_report (x,y):
    from sklearn.metrics import classification_report
    report = classification_report(x,y)
    return report

# %% [markdown]
# # splitting & under sampling

# %%
x = df['no_stopwords']
y = df['label']

x, y = undersampling(x, y)

x_train, x_test, y_train, y_test = bagi_data(x, y)

y.value_counts()
# Out:
# label
# Negative    8770
# Positive    8770
# Name: count, dtype: int64

# %% [markdown]
# # TF-idf vectorizing

# %%
x_train, x_test = tfidf_vec(x_train, x_test)

# %% [markdown]
# # Modeling

# %%
from sklearn.ensemble import RandomForestClassifier
random_forest = RandomForestClassifier

# [CV 2/5] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=100;, score=0.521 total time=   2.5s
# [CV 3/5] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=100;, score=0.521 total time=   2.7s
# [CV 4/5] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=100;, score=0.544 total time=   2.6s
# [CV 5/5] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=100;, score=0.517 total time=   2.6s
# [CV 1/5] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=200;, score=0.510 total time=   5.0s
# [CV 2/5] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=200;, score=0.513 total time=   5.1s
# [CV 3/5] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=200;, score=0.520 total time=   5.3s
# [CV 4/5] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=200;, score=0.521 total time=   5.2s
# [CV 5/5] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=200;, score=0.519 total time=   5.4s
# [CV 1/5] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=400;, score=0.502 total time=  10.8s
# [CV 2/5] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=400;, score=0.509 total time=  10.4s
# [CV 3/5] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=400;, score=0.511 total time=  10.7s
# [CV 4/5] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=400;, score=0.523 total time=  10.5s
# [CV 5/5] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=400;, score=0.523 total time=  10.4s
# [CV 1/5] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.520 total time=   6.9s
# [CV 2/5] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.518 total time=   6.9s
# [CV 3/5] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.499 total time=   6.9s
# [CV 4/5] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.588 total time=   6.8s
# [CV 5/5] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.509 total time=   7.0s
# [CV 1/5] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.523 total time=  13.7s
# [CV 2/5] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.524 total time=  13.9s
# [CV 3/5] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.504 total time=  13.4s
# [CV 4/5] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.582 total time=  13.3s
# [CV 5/5] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.518 total time=  13.6s
# [CV 1/5] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=400;, score=0.536 total time=  26.8s
# [CV 2/5] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=400;, score=0.511 total time=  26.7s
# [CV 3/5] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=400;, score=0.505 total time=  26.9s
# [CV 4/5] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=400;, score=0.587 total time=  27.1s
# [CV 5/5] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=400;, score=0.520 total time=  27.5s
# [CV 1/5] END bootstrap=False, max_depth=20, max_features=log2, n_estimators=100;, score=0.550 total time=   6.0s
# [CV 2/5] END bootstrap=False, max_depth=20, max_features=log2, n_estimators=100;, score=0.555 total time=   5.8s
# [CV 3/5] END bootstrap=False, max_depth=20, max_features=log2, n_estimators=100;, score=0.549 total time=   6.2s
# [CV 4/5] END bootstrap=False, max_depth=20, max_features=log2, n_estimators=100;, score=0.569 total time=   6.1s
# [CV 5/5] END bootstrap=False, max_depth=20, max_features=log2, n_estimators=100;, score=0.554 total time=   5.9s
# [CV 1/5] END bootstrap=False, max_depth=20, max_features=log2, n_estimators=200;, score=0.549 total time=  11.8s
# [CV 2/5] END bootstrap=False, max_depth=20, max_features=log2, n_estimators=200;, score=0.554 total time=  11.4s
# [CV 3/5] END bootstrap=False, max_depth=20, max_features=log2, n_estimators=200;, score=0.556 total time=  11.9s
# [CV 4/5] END bootstrap=False, max_depth=20, max_features=log2, n_estimators=200;, score=0.571 total time=  11.6s
# [CV 5/5] END bootstrap=False, max_depth=20, max_features=log2, n_estimators=200;, score=0.567 total time=  11.4s
# [CV 1/5] END bootstrap=False, max_depth=20, max_features=log2, n_estimators=400;, score=0.549 total time=  23.4s
# [CV 2/5] END bootstrap=False, max_depth=20, max_features=log2, n_estimators=400;, score=0.561 total time=  23.2s
# [CV 3/5] END bootstrap=False, max_depth=20, max_features=log2, n_estimators=400;, score=0.561 total time=  21.8s
# [CV 4/5] END bootstrap=False, max_depth=20, max_features=log2, n_estimators=400;, score=0.570 total time=  10.4s
# [CV 5/5] END bootstrap=False, max_depth=20, max_features=log2, n_estimators=400;, score=0.558 total time=   9.7s
# [CV 1/5] END bootstrap=False, max_depth=20, max_features=sqrt, n_estimators=100;, score=0.522 total time=   6.3s
# [CV 2/5] END bootstrap=False, max_depth=20, max_features=sqrt, n_estimators=100;, score=0.526 total time=   7.4s
# [CV 3/5] END bootstrap=False, max_depth=20, max_features=sqrt, n_estimators=100;, score=0.526 total time=   7.5s
# [CV 4/5] END bootstrap=False, max_depth=20, max_features=sqrt, n_estimators=100;, score=0.584 total time=   8.0s
# [CV 5/5] END bootstrap=False, max_depth=20, max_features=sqrt, n_estimators=100;, score=0.531 total time=   6.5s
# [CV 1/5] END bootstrap=False, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.530 total time=  13.3s
# [CV 2/5] END bootstrap=False, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.519 total time=  13.5s
# [CV 3/5] END bootstrap=False, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.517 total time=  19.6s
# [CV 4/5] END bootstrap=False, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.582 total time=  13.4s
# [CV 5/5] END bootstrap=False, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.529 total time=  13.4s
# [CV 1/5] END bootstrap=False, max_depth=20, max_features=sqrt, n_estimators=400;, score=0.540 total time=  29.2s
# [CV 2/5] END bootstrap=False, max_depth=20, max_features=sqrt, n_estimators=400;, score=0.516 total time=  31.3s
# [CV 3/5] END bootstrap=False, max_depth=20, max_features=sqrt, n_estimators=400;, score=0.513 total time=  31.2s
# [CV 4/5] END bootstrap=False, max_depth=20, max_features=sqrt, n_estimators=400;, score=0.584 total time=  31.7s
# [CV 5/5] END bootstrap=False, max_depth=20, max_features=sqrt, n_estimators=400;, score=0.521 total time=  34.5s
# [CV 1/5] END bootstrap=False, max_depth=40, max_features=log2, n_estimators=100;, score=0.561 total time=   9.4s
# [CV 2/5] END bootstrap=False, max_depth=40, max_features=log2, n_estimators=100;, score=0.567 total time=  10.7s
# [CV 3/5] END bootstrap=False, max_depth=40, max_features=log2, n_estimators=100;, score=0.555 total time=  14.0s
# [CV 4/5] END bootstrap=False, max_depth=40, max_features=log2, n_estimators=100;, score=0.575 total time=  11.7s
# [CV 5/5] END bootstrap=False, max_depth=40, max_features=log2, n_estimators=100;, score=0.557 total time=  10.0s
# [CV 1/5] END bootstrap=False, max_depth=40, max_features=log2, n_estimators=200;, score=0.560 total time=  19.4s
# [CV 2/5] END bootstrap=False, max_depth=40, max_features=log2, n_estimators=200;, score=0.564 total time=  18.4s
# [CV 3/5] END bootstrap=False, max_depth=40, max_features=log2, n_estimators=200;, score=0.566 total time=  19.3s
# [CV 4/5] END bootstrap=False, max_depth=40, max_features=log2, n_estimators=200;, score=0.580 total time=  18.8s
# [CV 5/5] END bootstrap=False, max_depth=40, max_features=log2, n_estimators=200;, score=0.569 total time=  18.4s
# [CV 1/5] END bootstrap=False, max_depth=40, max_features=log2, n_estimators=400;, score=0.563 total time=  38.9s
# [CV 2/5] END bootstrap=False, max_depth=40, max_features=log2, n_estimators=400;, score=0.558 total time=  33.5s
# [CV 3/5] END bootstrap=False, max_depth=40, max_features=log2, n_estimators=400;, score=0.569 total time=  34.1s
# [CV 4/5] END bootstrap=False, max_depth=40, max_features=log2, n_estimators=400;, score=0.580 total time=  33.1s
# [CV 5/5] END bootstrap=False, max_depth=40, max_features=log2, n_estimators=400;, score=0.561 total time=  33.4s
# [CV 1/5] END bootstrap=False, max_depth=40, max_features=sqrt, n_estimators=100;, score=0.584 total time=  20.8s
# [CV 2/5] END bootstrap=False, max_depth=40, max_features=sqrt, n_estimators=100;, score=0.537 total time=  20.8s
# [CV 3/5] END bootstrap=False, max_depth=40, max_features=sqrt, n_estimators=100;, score=0.548 total time=  21.2s
# [CV 4/5] END bootstrap=False, max_depth=40, max_features=sqrt, n_estimators=100;, score=0.579 total time=  21.1s
# [CV 5/5] END bootstrap=False, max_depth=40, max_features=sqrt, n_estimators=100;, score=0.587 total time=  21.4s
# [CV 1/5] END bootstrap=False, max_depth=40, max_features=sqrt, n_estimators=200;, score=0.579 total time=  43.5s
# [CV 2/5] END bootstrap=False, max_depth=40, max_features=sqrt, n_estimators=200;, score=0.555 total time=  38.7s
# [CV 3/5] END bootstrap=False, max_depth=40, max_features=sqrt, n_estimators=200;, score=0.551 total time=  39.2s
# [CV 4/5] END bootstrap=False, max_depth=40, max_features=sqrt, n_estimators=200;, score=0.584 total time=  38.7s
# [CV 5/5] END bootstrap=False, max_depth=40, max_features=sqrt, n_estimators=200;, score=0.587 total time=  39.2s
# [CV 1/5] END bootstrap=False, max_depth=40, max_features=sqrt, n_estimators=400;, score=0.580 total time= 1.3min
# [CV 2/5] END bootstrap=False, max_depth=40, max_features=sqrt, n_estimators=400;, score=0.548 total time= 1.5min
# [CV 3/5] END bootstrap=False, max_depth=40, max_features=sqrt, n_estimators=400;, score=0.553 total time= 1.5min
# [CV 4/5] END bootstrap=False, max_depth=40, max_features=sqrt, n_estimators=400;, score=0.579 total time= 1.4min
# [CV 5/5] END bootstrap=False, max_depth=40, max_features=sqrt, n_estimators=400;, score=0.582 total time= 1.4min
# {'bootstrap': True, 'max_depth': 40, 'max_features': 'sqrt', 'n_estimators': 200}

# %%
from sklearn.ensemble import RandomForestClassifier
random_forest = RandomForestClassifier(random_state=42, bootstrap=True, max_depth=40, max_features='sqrt', n_estimators=200)

# %%
random_forest.fit(x_train, y_train)
    
y_pred = random_forest.predict(x_test)

# %% [markdown]
# # Score Random Forest untag

# %%
print(all_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.58      0.52      0.55      1708
#     Positive       0.58      0.63      0.61      1800
#
#     accuracy                           0.58      3508
#    macro avg       0.58      0.58      0.58      3508
# weighted avg       0.58      0.58      0.58      3508

# %%
import pickle

# save the model to disk
filename = 'RandomForest_Untag.pkl'
pickle.dump(random_forest, open(filename, 'wb'))

# %%
# from sklearn.metrics import f1_score

# # Menghitung F1-score dengan label positif "1"
# f1 = f1_score(y_test, y_pred, pos_label='Negative')

# # Mencetak hasil
# print("F1 Score:", f1)
