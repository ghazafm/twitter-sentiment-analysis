# %% [markdown]
# # Dataframe

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('https://raw.githubusercontent.com/ghazafm/SocialMediaSentiment/main/preprocessing/Training/data/clean/regular/gabungan.csv')
df = df.dropna()
df
# Out:
#                                                    Tweet     label  \
# 0                                   info  anies presiden  Positive
# 1      politisi partai gerindra sandiaga uno menjawab...  Positive
# 2       lanjut pak anies kita kawal sampai jadi presiden  Positive
# 3      semoga allah swt menyelamatkan bangsa dan nega...  Positive
# 4      chotimah kasian ya pa anies makanya sudah teka...  Positive
# ...                                                  ...       ...
# 24713           pa ganjar pranowo nex presiden indonesia  Negative
# 24714  rt ganjaristdltras ganjarist deltras jatim sia...  Negative
# 24715                    artinya ganjar pranowo presiden  Negative
# 24716  semakin banyak rakyat yang siap mendukung ganj...  Negative
# 24717  selamat hari penerbangan nasional oktober terb...  Negative
#
#                                                  no_alay  \
# 0                                    info anies presiden
# 1      politisi partai gerindra sandiaga uno menjawab...
# 2       lanjut pak anies kita kawal sampai jadi presiden
# 3      semoga allah swt menyelamatkan bangsa dan nega...
# 4      chotimah kasihan ya apa anies makanya sudah te...
# ...                                                  ...
# 24713          apa ganjar pranowo nex presiden indonesia
# 24714  rt ganjaristdltras ganjarist deltras jatim sia...
# 24715                    artinya ganjar pranowo presiden
# 24716  semakin banyak rakyat yang siap mendukung ganj...
# 24717  selamat hari penerbangan nasional oktober terb...
#
#                                             clean_manual  \
# 0                                                   info
# 1      politisi menjawab soal diduetkan kembali denga...
# 2                           lanjut pak kita kawal sampai
# 3      swt menyelamatkan bangsa dan negara republik d...
# 4           kasihan ya makanya sudah tekad keluarga saya
# ...                                                  ...
# 24713                                                nex
# 24714    rt ganjaristdltras ganjarist deltras jatim siap
# 24715                                            artinya
# 24716  semakin yang siap untuk sebagai ke selamat ula...
# 24717  selamat penerbangan nasional oktober terbangla...
#
#                                                  stemmed  \
# 0                                                   info
# 1      politis jawab soal duet kembali dengan mantan ...
# 2                           lanjut pak kita kawal sampai
# 3      swt selamat bangsa dan negara republik dari pa...
# 4           kasihan ya makanya sudah tekad keluarga saya
# ...                                                  ...
# 24713                                                nex
# 24714    rt ganjaristdltras ganjarist deltras jatim siap
# 24715                                               arti
# 24716  makin yang siap untuk bagai ke selamat ulang p...
# 24717  selamat terbang nasional oktober terbang tingg...
#
#                                             no_stopwords
# 0                                                   info
# 1      politis jawab soal duet dengan mantan dki jaka...
# 2                                       lanjut pak kawal
# 3      swt selamat bangsa negara republik para penghi...
# 4                         kasihan makanya tekad keluarga
# ...                                                  ...
# 24713                                                nex
# 24714    rt ganjaristdltras ganjarist deltras jatim siap
# 24715                                               arti
# 24716           makin siap bagai selamat ulang pak tuhan
# 24717  selamat terbang nasional oktober terbang tingg...
#
# [24384 rows x 6 columns]

# %% [markdown]
# # Function

# %%
# label encoder
def label_encoder(y):
    from sklearn.preprocessing import LabelEncoder
    le = LabelEncoder()
    y = le.fit_transform(y)
    return y

# under dan over sampling
def undersampling(x, y):
    from imblearn.under_sampling import RandomUnderSampler
    rus = RandomUnderSampler()
    x, y = rus.fit_resample(x.values.reshape(-1,1),y)
    x = x.flatten()
    return x, y

def oversampling(x, y):
    from imblearn.over_sampling import RandomOverSampler
    ros = RandomOverSampler()
    x, y = ros.fit_resample(x.values.reshape(-1,1),y)
    x = x.flatten()
    return x, y

# train test split
def bagi_data(x, y):
    from sklearn.model_selection import train_test_split
    x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=2)
    return x_train, x_test, y_train, y_test

# cetak csv
def cetak_csv(data):
    data.to_csv('name.csv')

# Vectorizing
def tfidf_vec(x_train, x_test):
    from sklearn.feature_extraction.text import TfidfVectorizer
    vectorizer = TfidfVectorizer()
    x_train = vectorizer.fit_transform(x_train)
    x_test = vectorizer.transform(x_test)
    return x_train, x_test

def count_vec(x_train, x_test):
    from sklearn.feature_extraction.text import CountVectorizer
    vectorizer = CountVectorizer()
    x_train = vectorizer.fit_transform(x_train)
    x_test = vectorizer.transform(x_test)
    return x_train, x_test

# Metric Scorer
def accuracy_score(y_test, y_pred):
    from sklearn.metrics import accuracy_score
    
    accuracy = accuracy_score(y_test, y_pred)
    return accuracy

def f1_score_pos(x,y):
    from sklearn.metrics import f1_score
    f1 = f1_score(x,y,pos_label='Positive')
    return f1
def f1_score_neg(x,y):
    from sklearn.metrics import f1_score
    f1 = f1_score(x,y,pos_label='Negative')
    return f1

def precission_pos(x,y):
    from sklearn.metrics import precision_score
    precision = precision_score(x,y,pos_label='Positive')
    return precision
def precission_neg(x,y):
    from sklearn.metrics import precision_score
    precision = precision_score(x,y,pos_label='Negative')
    return precision

def recall_pos(x,y):
    from sklearn.metrics import recall_score
    recall = recall_score(x,y,'Positive')
    return recall
def recall_neg(x,y):
    from sklearn.metrics import recall_score
    recall = recall_score(x,y,'Negative')
    return recall

def all_report (x,y):
    from sklearn.metrics import classification_report
    report = classification_report(x,y)
    return report

# %% [markdown]
# # splitting & under sampling

# %%
x = df['no_stopwords']
y = df['label']

x, y = undersampling(x, y)

x_train, x_test, y_train, y_test = bagi_data(x, y)

y.value_counts()
# Out:
# label
# Negative    8770
# Positive    8770
# Name: count, dtype: int64

# %% [markdown]
# # TF-idf vectorizing

# %%
x_train, x_test = tfidf_vec(x_train, x_test)

# %% [markdown]
# # Modeling

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
tree = DecisionTreeClassifier(random_state=42)



parameter = {
    "criterion": ["gini", "entropy"],
    "max_depth": range(1,10),
    "min_samples_split": range(2,10),
    "min_samples_leaf": range(1,5)
}

# from sklearn.metrics import recall_score, make_scorer

# # Membuat scorer untuk recall positif
# scorer = make_scorer(recall_score, pos_label='Positive')

# from sklearn.metrics import precision_score, make_scorer

# # Membuat scorer untuk precision
# precision_score = make_scorer(precision_score, pos_label='Positive')


from sklearn.model_selection import GridSearchCV
GS = GridSearchCV(estimator = tree,
                    param_grid = parameter,
                    scoring = 'f1_macro', 
                    refit = False,
                    cv=5,
                    verbose = 3)

GS.fit(x_train, y_train)
print(GS.best_params_)
# Out:
# Fitting 5 folds for each of 576 candidates, totalling 2880 fits
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_leaf=1, min_samples_split
total time=   0.8s
# [CV 2/5] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=9;, score=0.413 total time=   0.8s
# [CV 3/5] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=9;, score=0.409 total time=   0.9s
# [CV 4/5] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=9;, score=0.428 total time=   0.8s
# [CV 5/5] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=9;, score=0.419 total time=   0.9s
# [CV 1/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=2;, score=0.422 total time=   0.9s
# [CV 2/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=2;, score=0.413 total time=   0.8s
# [CV 3/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=2;, score=0.408 total time=   0.9s
# [CV 4/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=2;, score=0.428 total time=   0.8s
# [CV 5/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=2;, score=0.419 total time=   0.8s
# [CV 1/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=3;, score=0.422 total time=   0.8s
# [CV 2/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=3;, score=0.413 total time=   0.8s
# [CV 3/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=3;, score=0.408 total time=   0.9s
# [CV 4/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=3;, score=0.428 total time=   0.9s
# [CV 5/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=3;, score=0.419 total time=   0.8s
# [CV 1/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=4;, score=0.422 total time=   0.8s
# [CV 2/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=4;, score=0.413 total time=   0.9s
# [CV 3/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=4;, score=0.408 total time=   0.9s
# [CV 4/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=4;, score=0.428 total time=   0.8s
# [CV 5/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=4;, score=0.419 total time=   0.8s
# [CV 1/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=5;, score=0.422 total time=   0.8s
# [CV 2/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=5;, score=0.413 total time=   0.8s
# [CV 3/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=5;, score=0.408 total time=   0.8s
# [CV 4/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=5;, score=0.428 total time=   0.8s
# [CV 5/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=5;, score=0.419 total time=   0.9s
# [CV 1/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=6;, score=0.422 total time=   0.8s
# [CV 2/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=6;, score=0.413 total time=   0.8s
# [CV 3/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=6;, score=0.408 total time=   0.8s
# [CV 4/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=6;, score=0.428 total time=   0.8s
# [CV 5/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=6;, score=0.419 total time=   0.8s
# [CV 1/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=7;, score=0.422 total time=   0.8s
# [CV 2/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=7;, score=0.413 total time=   0.8s
# [CV 3/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=7;, score=0.408 total time=   0.8s
# [CV 4/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=7;, score=0.428 total time=   0.9s
# [CV 5/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=7;, score=0.419 total time=   0.8s
# [CV 1/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=8;, score=0.422 total time=   0.9s
# [CV 2/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=8;, score=0.413 total time=   0.8s
# [CV 3/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=8;, score=0.408 total time=   0.8s
# [CV 4/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=8;, score=0.427 total time=   0.8s
# [CV 5/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=8;, score=0.419 total time=   0.8s
# [CV 1/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=9;, score=0.422 total time=   0.8s
# [CV 2/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=9;, score=0.413 total time=   0.7s
# [CV 3/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=9;, score=0.408 total time=   0.8s
# [CV 4/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=9;, score=0.427 total time=   0.7s
# [CV 5/5] END criterion=entropy, max_depth=9, min_samples_leaf=3, min_samples_split=9;, score=0.419 total time=   0.9s
# [CV 1/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=2;, score=0.422 total time=   0.8s
# [CV 2/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=2;, score=0.413 total time=   0.8s
# [CV 3/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=2;, score=0.409 total time=   0.9s
# [CV 4/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=2;, score=0.430 total time=   0.9s
# [CV 5/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=2;, score=0.417 total time=   0.9s
# [CV 1/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=3;, score=0.422 total time=   0.8s
# [CV 2/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=3;, score=0.413 total time=   0.8s
# [CV 3/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=3;, score=0.409 total time=   0.8s
# [CV 4/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=3;, score=0.430 total time=   0.8s
# [CV 5/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=3;, score=0.417 total time=   0.8s
# [CV 1/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=4;, score=0.422 total time=   0.8s
# [CV 2/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=4;, score=0.413 total time=   0.9s
# [CV 3/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=4;, score=0.409 total time=   0.8s
# [CV 4/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=4;, score=0.430 total time=   1.0s
# [CV 5/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=4;, score=0.417 total time=   1.0s
# [CV 1/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=5;, score=0.422 total time=   0.9s
# [CV 2/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=5;, score=0.413 total time=   0.9s
# [CV 3/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=5;, score=0.409 total time=   0.9s
# [CV 4/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=5;, score=0.430 total time=   1.0s
# [CV 5/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=5;, score=0.417 total time=   1.2s
# [CV 1/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=6;, score=0.422 total time=   1.0s
# [CV 2/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=6;, score=0.413 total time=   1.2s
# [CV 3/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=6;, score=0.409 total time=   0.9s
# [CV 4/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=6;, score=0.430 total time=   1.0s
# [CV 5/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=6;, score=0.417 total time=   1.0s
# [CV 1/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=7;, score=0.422 total time=   0.9s
# [CV 2/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=7;, score=0.413 total time=   0.8s
# [CV 3/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=7;, score=0.409 total time=   0.8s
# [CV 4/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=7;, score=0.430 total time=   0.8s
# [CV 5/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=7;, score=0.417 total time=   0.8s
# [CV 1/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=8;, score=0.422 total time=   0.8s
# [CV 2/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=8;, score=0.413 total time=   0.8s
# [CV 3/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=8;, score=0.409 total time=   0.8s
# [CV 4/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=8;, score=0.430 total time=   0.8s
# [CV 5/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=8;, score=0.417 total time=   0.8s
# [CV 1/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=9;, score=0.422 total time=   0.8s
# [CV 2/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=9;, score=0.413 total time=   0.8s
# [CV 3/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=9;, score=0.409 total time=   0.9s
# [CV 4/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=9;, score=0.429 total time=   0.8s
# [CV 5/5] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=9;, score=0.417 total time=   0.8s
# {'criterion': 'gini', 'max_depth': 9, 'min_samples_leaf': 1, 'min_samples_split': 4}

# %%
tree = DecisionTreeClassifier(random_state=42, criterion='gini', max_depth=9, min_samples_leaf=4, min_samples_split=2)
tree.fit(x_train, y_train)
    
y_pred = tree.predict(x_test)

# %% [markdown]
# # Score Decision Tree untag

# %%
print(all_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.50      0.97      0.66      1708
#     Positive       0.78      0.10      0.17      1800
#
#     accuracy                           0.52      3508
#    macro avg       0.64      0.53      0.42      3508
# weighted avg       0.65      0.52      0.41      3508

# %%
import pickle

# save the model to disk
filename = 'DecisionTree_Untag.pkl'
pickle.dump(tree, open(filename, 'wb'))

# %%
from sklearn.metrics import f1_score

# Menghitung F1-score dengan label positif "1"
f1 = f1_score(y_test, y_pred, pos_label='Negative')

# Mencetak hasil
print("F1 Score:", f1)
# Out:
# F1 Score: 0.6645316253002402
