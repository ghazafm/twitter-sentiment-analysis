# %% [markdown]
# # Dataframe

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('https://raw.githubusercontent.com/ghazafm/SocialMediaSentiment/main/preprocessing/Training/data/clean/pos_tagging/gabungan.csv')
df = df.dropna()

# %%
df
# Out:
#                                                    Tweet     label  \
# 0                                   info  anies presiden  Positive
# 1      politisi partai gerindra sandiaga uno menjawab...  Positive
# 2       lanjut pak anies kita kawal sampai jadi presiden  Positive
# 3      semoga allah swt menyelamatkan bangsa dan nega...  Positive
# 4      chotimah kasian ya pa anies makanya sudah teka...  Positive
# ...                                                  ...       ...
# 24317           pa ganjar pranowo nex presiden indonesia  Negative
# 24318  rt ganjaristdltras ganjarist deltras jatim sia...  Negative
# 24319                    artinya ganjar pranowo presiden  Negative
# 24320  semakin banyak rakyat yang siap mendukung ganj...  Negative
# 24321  selamat hari penerbangan nasional oktober terb...  Negative
#
#                                                  no_alay  \
# 0                                    info anies presiden
# 1      politisi partai gerindra sandiaga uno menjawab...
# 2       lanjut pak anies kita kawal sampai jadi presiden
# 3      semoga allah swt menyelamatkan bangsa dan nega...
# 4      chotimah kasihan ya apa anies makanya sudah te...
# ...                                                  ...
# 24317          apa ganjar pranowo nex presiden indonesia
# 24318  rt ganjaristdltras ganjarist deltras jatim sia...
# 24319                    artinya ganjar pranowo presiden
# 24320  semakin banyak rakyat yang siap mendukung ganj...
# 24321  selamat hari penerbangan nasional oktober terb...
#
#                                                      pos  \
# 0      [('info', 'NN'), ('anies', 'NN'), ('presiden',...
# 1      [('politisi', 'NN'), ('partai', 'NN'), ('gerin...
# 2      [('lanjut', 'VB'), ('pak', 'NN'), ('anies', 'N...
# 3      [('semoga', 'SC'), ('allah', 'VB'), ('swt', 'N...
# 4      [('chotimah', 'NN'), ('kasihan', 'NN'), ('ya',...
# ...                                                  ...
# 24317  [('apa', 'WH'), ('ganjar', 'FW'), ('pranowo', ...
# 24318  [('rt', 'FW'), ('ganjaristdltras', 'FW'), ('ga...
# 24319  [('artinya', 'RB'), ('ganjar', 'VB'), ('pranow...
# 24320  [('semakin', 'RB'), ('banyak', 'CD'), ('rakyat...
# 24321  [('selamat', 'NN'), ('hari', 'NN'), ('penerban...
#
#                                             clean_manual  \
# 0                                                info NN
# 1      politisi NN menjawab VB soal NN diduetkan VB k...
# 2           lanjut VB pak NN kita PRP kawal NN sampai SC
# 3      swt NN menyelamatkan VB bangsa NN dan CC negar...
# 4      kasihan NN ya NN makanya RB sudah MD tekad VB ...
# ...                                                  ...
# 24317                                             nex FW
# 24318  rt FW ganjaristdltras FW ganjarist FW deltras ...
# 24319                                         artinya RB
# 24320  semakin RB yang SC siap VB untuk SC sebagai IN...
# 24321  selamat NN penerbangan NN nasional JJ oktober ...
#
#                                                  stemmed  \
# 0                                                info NN
# 1      politis NN jawab VB soal NN duet VB kembali VB...
# 2           lanjut VB pak NN kita PRP kawal NN sampai SC
# 3      swt NN selamat VB bangsa NN dan CC negara NN r...
# 4      kasihan NN ya NN makanya RB sudah MD tekad VB ...
# ...                                                  ...
# 24317                                             nex FW
# 24318  rt FW ganjaristdltras FW ganjarist FW deltras ...
# 24319                                            arti RB
# 24320  makin RB yang SC siap VB untuk SC bagai IN ke ...
# 24321  selamat NN terbang NN nasional JJ oktober NN t...
#
#                                             no_stopwords
# 0                                                info NN
# 1      politis NN jawab VB soal NN duet VB mantan JJ ...
# 2                              lanjut VB pak NN kawal NN
# 3      swt NN selamat VB bangsa NN negara NN republik...
# 4             kasihan NN makanya RB tekad VB keluarga NN
# ...                                                  ...
# 24317                                             nex FW
# 24318  rt FW ganjaristdltras FW ganjarist FW deltras ...
# 24319                                            arti RB
# 24320  makin RB siap VB bagai IN selamat JJ ulang VB ...
# 24321  selamat NN terbang NN nasional JJ oktober NN t...
#
# [24322 rows x 7 columns]

# %% [markdown]
# # Function

# %%
# label encoder
def label_encoder(y):
    from sklearn.preprocessing import LabelEncoder
    le = LabelEncoder()
    y = le.fit_transform(y)
    return y

# under dan over sampling
def undersampling(x, y):
    from imblearn.under_sampling import RandomUnderSampler
    rus = RandomUnderSampler()
    x, y = rus.fit_resample(x.values.reshape(-1,1),y)
    x = x.flatten()
    return x, y

def oversampling(x, y):
    from imblearn.over_sampling import RandomOverSampler
    ros = RandomOverSampler()
    x, y = ros.fit_resample(x.values.reshape(-1,1),y)
    x = x.flatten()
    return x, y

# train test split
def bagi_data(x, y):
    from sklearn.model_selection import train_test_split
    x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=2)
    return x_train, x_test, y_train, y_test

# cetak csv
def cetak_csv(data):
    data.to_csv('name.csv')

# Vectorizing
def tfidf_vec(x_train, x_test):
    from sklearn.feature_extraction.text import TfidfVectorizer
    vectorizer = TfidfVectorizer()
    x_train = vectorizer.fit_transform(x_train)
    x_test = vectorizer.transform(x_test)
    return x_train, x_test

def count_vec(x_train, x_test):
    from sklearn.feature_extraction.text import CountVectorizer
    vectorizer = CountVectorizer()
    x_train = vectorizer.fit_transform(x_train)
    x_test = vectorizer.transform(x_test)
    return x_train, x_test

# Metric Scorer
def accuracy_score(y_test, y_pred):
    from sklearn.metrics import accuracy_score
    
    accuracy = accuracy_score(y_test, y_pred)
    return accuracy

def f1_score_pos(x,y):
    from sklearn.metrics import f1_score
    f1 = f1_score(x,y,pos_label='Positive')
    return f1
def f1_score_neg(x,y):
    from sklearn.metrics import f1_score
    f1 = f1_score(x,y,pos_label='Negative')
    return f1

def precission_pos(x,y):
    from sklearn.metrics import precision_score
    precision = precision_score(x,y,pos_label='Positive')
    return precision
def precission_neg(x,y):
    from sklearn.metrics import precision_score
    precision = precision_score(x,y,pos_label='Negative')
    return precision

def recall_pos(x,y):
    from sklearn.metrics import recall_score
    recall = recall_score(x,y,'Positive')
    return recall
def recall_neg(x,y):
    from sklearn.metrics import recall_score
    recall = recall_score(x,y,'Negative')
    return recall

def all_report (x,y):
    from sklearn.metrics import classification_report
    report = classification_report(x,y)
    return report

# %% [markdown]
# # splitting & under sampling

# %%
x = df['no_stopwords']
y = df['label']

x, y = undersampling(x, y)

x_train, x_test, y_train, y_test = bagi_data(x, y)

y.value_counts()
# Out:
# label
# Negative    8752
# Positive    8752
# Name: count, dtype: int64

# %% [markdown]
# # TF-idf vectorizing

# %%
x_train, x_test = tfidf_vec(x_train, x_test)

# %% [markdown]
# # Modeling

# %%
from sklearn.svm import SVC
svm_classifier = SVC(random_state=42)

# %%
parameter = {
    "C": [0.1, 1, 10, 100, 1000],
    "kernel": ["linear", "rbf", "poly", "sigmoid"],
    "gamma": ["scale", "auto"]
}

from sklearn.model_selection import GridSearchCV
GS = GridSearchCV(estimator = svm_classifier,
                    param_grid = parameter,
                    scoring = 'f1_macro', 
                    refit = False,
                    cv=5,
                    verbose = 3)

GS.fit(x_train, y_train)
print(GS.best_params_)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [CV 1/5] END .C=0.1, gamma=scale, kernel=linear;, score=0.566 total time=  48.8s
# [CV 2/5] END .C=0.1, gamma=scale, kernel=linear;, score=0.556 total time=  51.1s
# [CV 3/5] END .C=0.1, gamma=scale, kernel=linear;, score=0.572 total time=  49.6s
# [CV 4/5] END .C=0.1, gamma=scale, kernel=linear;, score=0.581 total time=  48.0s
# [CV 5/5] END .C=0.1, gamma=scale, kernel=linear;, score=0.569 total time=  49.1s
# [CV 1/5] END ....C=0.1, gamma=scale, kernel=rbf;, score=0.541 total time=  58.3s
# [CV 2/5] END ....C=0.1, gamma=scale, kernel=rbf;, score=0.553 total time= 1.1min
# [CV 3/5] END ....C=0.1, gamma=scale, kernel=rbf;, score=0.546 total time=  53.7s
# [CV 4/5] END ....C=0.1, gamma=scale, kernel=rbf;, score=0.525 total time=  54.1s
# [CV 5/5] END ....C=0.1, gamma=scale, kernel=rbf;, score=0.555 total time=  53.3s
# [CV 1/5] END ...C=0.1, gamma=scale, kernel=poly;, score=0.495 total time=  49.3s
# [CV 2/5] END ...C=0.1, gamma=scale, kernel=poly;, score=0.487 total time=  49.4s
# [CV 3/5] END ...C=0.1, gamma=scale, kernel=poly;, score=0.470 total time=  46.8s
# [CV 4/5] END ...C=0.1, gamma=scale, kernel=poly;, score=0.459 total time=  48.4s
# [CV 5/5] END ...C=0.1, gamma=scale, kernel=poly;, score=0.517 total time=  49.4s
# [CV 1/5] END C=0.1, gamma=scale, kernel=sigmoid;, score=0.563 total time=  52.3s
# [CV 2/5] END C=0.1, gamma=scale, kernel=sigmoid;, score=0.553 total time=  52.8s
# [CV 3/5] END C=0.1, gamma=scale, kernel=sigmoid;, score=0.573 total time=  54.0s
# [CV 4/5] END C=0.1, gamma=scale, kernel=sigmoid;, score=0.583 total time=  54.2s
# [CV 5/5] END C=0.1, gamma=scale, kernel=sigmoid;, score=0.568 total time=  53.6s
# [CV 1/5] END ..C=0.1, gamma=auto, kernel=linear;, score=0.566 total time=  46.7s
# [CV 2/5] END ..C=0.1, gamma=auto, kernel=linear;, score=0.556 total time=  47.0s
# [CV 3/5] END ..C=0.1, gamma=auto, kernel=linear;, score=0.572 total time=  47.4s
# [CV 4/5] END ..C=0.1, gamma=auto, kernel=linear;, score=0.581 total time=  46.4s
# [CV 5/5] END ..C=0.1, gamma=auto, kernel=linear;, score=0.569 total time=  46.9s
# [CV 1/5] END .....C=0.1, gamma=auto, kernel=rbf;, score=0.334 total time=  51.1s
# [CV 2/5] END .....C=0.1, gamma=auto, kernel=rbf;, score=0.334 total time=  50.9s
# [CV 3/5] END .....C=0.1, gamma=auto, kernel=rbf;, score=0.334 total time=  51.0s
# [CV 4/5] END .....C=0.1, gamma=auto, kernel=rbf;, score=0.334 total time=  51.7s
# [CV 5/5] END .....C=0.1, gamma=auto, kernel=rbf;, score=0.334 total time=  52.6s
# [CV 1/5] END ....C=0.1, gamma=auto, kernel=poly;, score=0.334 total time=  46.3s
# [CV 2/5] END ....C=0.1, gamma=auto, kernel=poly;, score=0.334 total time=  45.7s
# [CV 3/5] END ....C=0.1, gamma=auto, kernel=poly;, score=0.334 total time=  46.7s
# [CV 4/5] END ....C=0.1, gamma=auto, kernel=poly;, score=0.334 total time=  48.9s
# [CV 5/5] END ....C=0.1, gamma=auto, kernel=poly;, score=0.334 total time=  47.4s
# [CV 1/5] END .C=0.1, gamma=auto, kernel=sigmoid;, score=0.334 total time=  52.6s
# [CV 2/5] END .C=0.1, gamma=auto, kernel=sigmoid;, score=0.334 total time=  49.4s
# [CV 3/5] END .C=0.1, gamma=auto, kernel=sigmoid;, score=0.334 total time=  47.6s
# [CV 4/5] END .C=0.1, gamma=auto, kernel=sigmoid;, score=0.334 total time=  44.9s
# [CV 5/5] END .C=0.1, gamma=auto, kernel=sigmoid;, score=0.334 total time=  44.7s
# [CV 1/5] END ...C=1, gamma=scale, kernel=linear;, score=0.586 total time=  37.5s
# [CV 2/5] END ...C=1, gamma=scale, kernel=linear;, score=0.560 total time=  35.6s
# [CV 3/5] END ...C=1, gamma=scale, kernel=linear;, score=0.573 total time=  36.3s
# [CV 4/5] END ...C=1, gamma=scale, kernel=linear;, score=0.579 total time=  36.0s
# [CV 5/5] END ...C=1, gamma=scale, kernel=linear;, score=0.581 total time=  39.0s
# [CV 1/5] END ......C=1, gamma=scale, kernel=rbf;, score=0.583 total time=  54.6s
# [CV 2/5] END ......C=1, gamma=scale, kernel=rbf;, score=0.561 total time=  46.7s
# [CV 3/5] END ......C=1, gamma=scale, kernel=rbf;, score=0.572 total time=  46.3s
# [CV 4/5] END ......C=1, gamma=scale, kernel=rbf;, score=0.579 total time=  36.7s
# [CV 5/5] END ......C=1, gamma=scale, kernel=rbf;, score=0.575 total time=  22.8s
# [CV 1/5] END .....C=1, gamma=scale, kernel=poly;, score=0.584 total time=  37.1s
# [CV 2/5] END .....C=1, gamma=scale, kernel=poly;, score=0.569 total time=  42.2s
# [CV 3/5] END .....C=1, gamma=scale, kernel=poly;, score=0.568 total time=  30.3s
# [CV 4/5] END .....C=1, gamma=scale, kernel=poly;, score=0.571 total time=  35.2s
# [CV 5/5] END .....C=1, gamma=scale, kernel=poly;, score=0.576 total time=  34.1s
# [CV 1/5] END ..C=1, gamma=scale, kernel=sigmoid;, score=0.582 total time=  21.3s
# [CV 2/5] END ..C=1, gamma=scale, kernel=sigmoid;, score=0.560 total time=  22.6s
# [CV 3/5] END ..C=1, gamma=scale, kernel=sigmoid;, score=0.572 total time=  24.1s
# [CV 4/5] END ..C=1, gamma=scale, kernel=sigmoid;, score=0.578 total time=  34.7s
# [CV 5/5] END ..C=1, gamma=scale, kernel=sigmoid;, score=0.587 total time=  41.2s
# [CV 1/5] END ....C=1, gamma=auto, kernel=linear;, score=0.586 total time=  25.8s
# [CV 2/5] END ....C=1, gamma=auto, kernel=linear;, score=0.560 total time=  26.4s
# [CV 3/5] END ....C=1, gamma=auto, kernel=linear;, score=0.573 total time=  26.3s
# [CV 4/5] END ....C=1, gamma=auto, kernel=linear;, score=0.579 total time=  31.6s
# [CV 5/5] END ....C=1, gamma=auto, kernel=linear;, score=0.581 total time=  18.2s
# [CV 1/5] END .......C=1, gamma=auto, kernel=rbf;, score=0.334 total time=  20.4s
# [CV 2/5] END .......C=1, gamma=auto, kernel=rbf;, score=0.334 total time=  20.4s
# [CV 3/5] END .......C=1, gamma=auto, kernel=rbf;, score=0.334 total time=  20.6s
# [CV 4/5] END .......C=1, gamma=auto, kernel=rbf;, score=0.334 total time=  20.6s
# [CV 5/5] END .......C=1, gamma=auto, kernel=rbf;, score=0.334 total time=  20.7s
# [CV 1/5] END ......C=1, gamma=auto, kernel=poly;, score=0.334 total time=  19.2s
# [CV 2/5] END ......C=1, gamma=auto, kernel=poly;, score=0.334 total time=  19.3s
# [CV 3/5] END ......C=1, gamma=auto, kernel=poly;, score=0.334 total time=  19.5s
# [CV 4/5] END ......C=1, gamma=auto, kernel=poly;, score=0.334 total time=  19.3s
# [CV 5/5] END ......C=1, gamma=auto, kernel=poly;, score=0.334 total time=  19.3s
# [CV 1/5] END ...C=1, gamma=auto, kernel=sigmoid;, score=0.334 total time=  21.9s
# [CV 2/5] END ...C=1, gamma=auto, kernel=sigmoid;, score=0.334 total time=  20.9s
# [CV 3/5] END ...C=1, gamma=auto, kernel=sigmoid;, score=0.334 total time=  22.6s
# [CV 4/5] END ...C=1, gamma=auto, kernel=sigmoid;, score=0.334 total time=  21.8s
# [CV 5/5] END ...C=1, gamma=auto, kernel=sigmoid;, score=0.334 total time=  20.1s
# [CV 1/5] END ..C=10, gamma=scale, kernel=linear;, score=0.584 total time=  33.4s
# [CV 2/5] END ..C=10, gamma=scale, kernel=linear;, score=0.561 total time=  34.1s
# [CV 3/5] END ..C=10, gamma=scale, kernel=linear;, score=0.558 total time=  33.6s
# [CV 4/5] END ..C=10, gamma=scale, kernel=linear;, score=0.579 total time=  34.6s
# [CV 5/5] END ..C=10, gamma=scale, kernel=linear;, score=0.562 total time=  35.7s
# [CV 1/5] END .....C=10, gamma=scale, kernel=rbf;, score=0.571 total time= 1.0min
# [CV 2/5] END .....C=10, gamma=scale, kernel=rbf;, score=0.558 total time= 1.0min
# [CV 3/5] END .....C=10, gamma=scale, kernel=rbf;, score=0.567 total time= 1.0min
# [CV 4/5] END .....C=10, gamma=scale, kernel=rbf;, score=0.571 total time= 1.1min
# [CV 5/5] END .....C=10, gamma=scale, kernel=rbf;, score=0.573 total time=  55.8s
# [CV 1/5] END ....C=10, gamma=scale, kernel=poly;, score=0.569 total time=  45.8s
# [CV 2/5] END ....C=10, gamma=scale, kernel=poly;, score=0.559 total time=  50.0s
# [CV 3/5] END ....C=10, gamma=scale, kernel=poly;, score=0.553 total time=  44.3s
# [CV 4/5] END ....C=10, gamma=scale, kernel=poly;, score=0.562 total time=  41.9s
# [CV 5/5] END ....C=10, gamma=scale, kernel=poly;, score=0.570 total time=  44.5s
# [CV 1/5] END .C=10, gamma=scale, kernel=sigmoid;, score=0.552 total time=  23.8s
# [CV 2/5] END .C=10, gamma=scale, kernel=sigmoid;, score=0.542 total time=  24.3s
# [CV 3/5] END .C=10, gamma=scale, kernel=sigmoid;, score=0.554 total time=  24.7s
# [CV 4/5] END .C=10, gamma=scale, kernel=sigmoid;, score=0.544 total time=  22.7s
# [CV 5/5] END .C=10, gamma=scale, kernel=sigmoid;, score=0.558 total time=  19.9s
# [CV 1/5] END ...C=10, gamma=auto, kernel=linear;, score=0.584 total time=  32.9s
# [CV 2/5] END ...C=10, gamma=auto, kernel=linear;, score=0.561 total time=  33.2s
# [CV 3/5] END ...C=10, gamma=auto, kernel=linear;, score=0.558 total time=  28.5s
# [CV 4/5] END ...C=10, gamma=auto, kernel=linear;, score=0.579 total time=  26.8s
# [CV 5/5] END ...C=10, gamma=auto, kernel=linear;, score=0.562 total time=  27.3s
# [CV 1/5] END ......C=10, gamma=auto, kernel=rbf;, score=0.334 total time=  15.7s
# [CV 2/5] END ......C=10, gamma=auto, kernel=rbf;, score=0.334 total time=  15.6s
# [CV 3/5] END ......C=10, gamma=auto, kernel=rbf;, score=0.334 total time=  15.3s
# [CV 4/5] END ......C=10, gamma=auto, kernel=rbf;, score=0.334 total time=  15.4s
# [CV 5/5] END ......C=10, gamma=auto, kernel=rbf;, score=0.334 total time=  17.6s
# [CV 1/5] END .....C=10, gamma=auto, kernel=poly;, score=0.334 total time=  14.9s
# [CV 2/5] END .....C=10, gamma=auto, kernel=poly;, score=0.334 total time=  14.9s
# [CV 3/5] END .....C=10, gamma=auto, kernel=poly;, score=0.334 total time=  14.6s
# [CV 4/5] END .....C=10, gamma=auto, kernel=poly;, score=0.334 total time=  14.6s
# [CV 5/5] END .....C=10, gamma=auto, kernel=poly;, score=0.334 total time=  15.6s
# [CV 1/5] END ..C=10, gamma=auto, kernel=sigmoid;, score=0.334 total time=  15.4s
# [CV 2/5] END ..C=10, gamma=auto, kernel=sigmoid;, score=0.334 total time=  15.3s
# [CV 3/5] END ..C=10, gamma=auto, kernel=sigmoid;, score=0.334 total time=  15.8s
# [CV 4/5] END ..C=10, gamma=auto, kernel=sigmoid;, score=0.334 total time=  15.7s
# [CV 5/5] END ..C=10, gamma=auto, kernel=sigmoid;, score=0.334 total time=  15.7s
# [CV 1/5] END .C=100, gamma=scale, kernel=linear;, score=0.564 total time= 1.4min
# [CV 2/5] END .C=100, gamma=scale, kernel=linear;, score=0.551 total time= 1.2min
# [CV 3/5] END .C=100, gamma=scale, kernel=linear;, score=0.541 total time= 1.1min
# [CV 4/5] END .C=100, gamma=scale, kernel=linear;, score=0.556 total time= 1.2min
# [CV 5/5] END .C=100, gamma=scale, kernel=linear;, score=0.540 total time= 1.2min
# [CV 1/5] END ....C=100, gamma=scale, kernel=rbf;, score=0.566 total time=  48.9s
# [CV 2/5] END ....C=100, gamma=scale, kernel=rbf;, score=0.556 total time=  50.5s
# [CV 3/5] END ....C=100, gamma=scale, kernel=rbf;, score=0.563 total time=  51.9s
# [CV 4/5] END ....C=100, gamma=scale, kernel=rbf;, score=0.569 total time=  49.9s
# [CV 5/5] END ....C=100, gamma=scale, kernel=rbf;, score=0.567 total time=  45.6s
# [CV 1/5] END ...C=100, gamma=scale, kernel=poly;, score=0.566 total time=  39.5s
# [CV 2/5] END ...C=100, gamma=scale, kernel=poly;, score=0.557 total time=  40.0s
# [CV 3/5] END ...C=100, gamma=scale, kernel=poly;, score=0.557 total time=  39.6s
# [CV 4/5] END ...C=100, gamma=scale, kernel=poly;, score=0.560 total time=  40.2s
# [CV 5/5] END ...C=100, gamma=scale, kernel=poly;, score=0.565 total time=  40.4s
# [CV 1/5] END C=100, gamma=scale, kernel=sigmoid;, score=0.538 total time=  25.6s
# [CV 2/5] END C=100, gamma=scale, kernel=sigmoid;, score=0.526 total time=  18.0s
# [CV 3/5] END C=100, gamma=scale, kernel=sigmoid;, score=0.535 total time=  29.2s
# [CV 4/5] END C=100, gamma=scale, kernel=sigmoid;, score=0.548 total time=  21.0s
# [CV 5/5] END C=100, gamma=scale, kernel=sigmoid;, score=0.539 total time=  27.2s
# [CV 1/5] END ..C=100, gamma=auto, kernel=linear;, score=0.564 total time= 1.4min
# [CV 2/5] END ..C=100, gamma=auto, kernel=linear;, score=0.551 total time= 1.3min
# [CV 3/5] END ..C=100, gamma=auto, kernel=linear;, score=0.541 total time= 1.3min
# [CV 4/5] END ..C=100, gamma=auto, kernel=linear;, score=0.556 total time= 1.3min
# [CV 5/5] END ..C=100, gamma=auto, kernel=linear;, score=0.540 total time= 1.4min
# [CV 1/5] END .....C=100, gamma=auto, kernel=rbf;, score=0.448 total time=  17.6s
# [CV 2/5] END .....C=100, gamma=auto, kernel=rbf;, score=0.401 total time=  17.2s
# [CV 3/5] END .....C=100, gamma=auto, kernel=rbf;, score=0.374 total time=  17.4s
# [CV 4/5] END .....C=100, gamma=auto, kernel=rbf;, score=0.534 total time=  17.2s
# [CV 5/5] END .....C=100, gamma=auto, kernel=rbf;, score=0.417 total time=  16.8s
# [CV 1/5] END ....C=100, gamma=auto, kernel=poly;, score=0.334 total time=  17.7s
# [CV 2/5] END ....C=100, gamma=auto, kernel=poly;, score=0.334 total time=  16.8s
# [CV 3/5] END ....C=100, gamma=auto, kernel=poly;, score=0.334 total time=  17.1s
# [CV 4/5] END ....C=100, gamma=auto, kernel=poly;, score=0.334 total time=  15.2s
# [CV 5/5] END ....C=100, gamma=auto, kernel=poly;, score=0.334 total time=  15.0s
# [CV 1/5] END .C=100, gamma=auto, kernel=sigmoid;, score=0.334 total time=  15.9s
# [CV 2/5] END .C=100, gamma=auto, kernel=sigmoid;, score=0.334 total time=  16.1s
# [CV 3/5] END .C=100, gamma=auto, kernel=sigmoid;, score=0.334 total time=  16.0s
# [CV 4/5] END .C=100, gamma=auto, kernel=sigmoid;, score=0.334 total time=  15.7s
# [CV 5/5] END .C=100, gamma=auto, kernel=sigmoid;, score=0.334 total time=  15.7s
# [CV 1/5] END C=1000, gamma=scale, kernel=linear;, score=0.545 total time= 9.6min
# [CV 2/5] END C=1000, gamma=scale, kernel=linear;, score=0.554 total time= 8.9min
# [CV 3/5] END C=1000, gamma=scale, kernel=linear;, score=0.533 total time= 8.0min
# [CV 4/5] END C=1000, gamma=scale, kernel=linear;, score=0.549 total time= 7.9min
# [CV 5/5] END C=1000, gamma=scale, kernel=linear;, score=0.530 total time= 7.6min
# [CV 1/5] END ...C=1000, gamma=scale, kernel=rbf;, score=0.565 total time=  42.4s
# [CV 2/5] END ...C=1000, gamma=scale, kernel=rbf;, score=0.558 total time=  43.6s
# [CV 3/5] END ...C=1000, gamma=scale, kernel=rbf;, score=0.564 total time=  43.0s
# [CV 4/5] END ...C=1000, gamma=scale, kernel=rbf;, score=0.567 total time=  42.7s
# [CV 5/5] END ...C=1000, gamma=scale, kernel=rbf;, score=0.564 total time=  43.7s
# [CV 1/5] END ..C=1000, gamma=scale, kernel=poly;, score=0.566 total time=  39.6s
# [CV 2/5] END ..C=1000, gamma=scale, kernel=poly;, score=0.559 total time=  38.4s
# [CV 3/5] END ..C=1000, gamma=scale, kernel=poly;, score=0.556 total time=  37.9s
# [CV 4/5] END ..C=1000, gamma=scale, kernel=poly;, score=0.560 total time=  38.0s
# [CV 5/5] END ..C=1000, gamma=scale, kernel=poly;, score=0.562 total time=  39.1s
# [CV 1/5] END C=1000, gamma=scale, kernel=sigmoid;, score=0.548 total time=  35.6s
# [CV 2/5] END C=1000, gamma=scale, kernel=sigmoid;, score=0.535 total time=  35.8s
# [CV 3/5] END C=1000, gamma=scale, kernel=sigmoid;, score=0.549 total time=  25.8s
# [CV 4/5] END C=1000, gamma=scale, kernel=sigmoid;, score=0.543 total time=  32.8s
# [CV 5/5] END C=1000, gamma=scale, kernel=sigmoid;, score=0.547 total time=  35.0s
# [CV 1/5] END .C=1000, gamma=auto, kernel=linear;, score=0.545 total time=10.6min
# [CV 2/5] END .C=1000, gamma=auto, kernel=linear;, score=0.554 total time=10.3min
# [CV 3/5] END .C=1000, gamma=auto, kernel=linear;, score=0.533 total time= 9.3min
# [CV 4/5] END .C=1000, gamma=auto, kernel=linear;, score=0.549 total time= 9.0min
# [CV 5/5] END .C=1000, gamma=auto, kernel=linear;, score=0.530 total time= 7.4min
# [CV 1/5] END ....C=1000, gamma=auto, kernel=rbf;, score=0.572 total time=  12.9s
# [CV 2/5] END ....C=1000, gamma=auto, kernel=rbf;, score=0.566 total time=  12.8s
# [CV 3/5] END ....C=1000, gamma=auto, kernel=rbf;, score=0.579 total time=  13.0s
# [CV 4/5] END ....C=1000, gamma=auto, kernel=rbf;, score=0.582 total time=  13.0s
# [CV 5/5] END ....C=1000, gamma=auto, kernel=rbf;, score=0.576 total time=  13.0s
# [CV 1/5] END ...C=1000, gamma=auto, kernel=poly;, score=0.334 total time=  12.6s
# [CV 2/5] END ...C=1000, gamma=auto, kernel=poly;, score=0.334 total time=  13.0s
# [CV 3/5] END ...C=1000, gamma=auto, kernel=poly;, score=0.334 total time=  13.0s
# [CV 4/5] END ...C=1000, gamma=auto, kernel=poly;, score=0.334 total time=  12.8s
# [CV 5/5] END ...C=1000, gamma=auto, kernel=poly;, score=0.334 total time=  13.7s
# [CV 1/5] END C=1000, gamma=auto, kernel=sigmoid;, score=0.561 total time=  14.1s
# [CV 2/5] END C=1000, gamma=auto, kernel=sigmoid;, score=0.552 total time=  14.0s
# [CV 3/5] END C=1000, gamma=auto, kernel=sigmoid;, score=0.576 total time=  14.2s
# [CV 4/5] END C=1000, gamma=auto, kernel=sigmoid;, score=0.570 total time=  14.2s
# [CV 5/5] END C=1000, gamma=auto, kernel=sigmoid;, score=0.567 total time=  14.1s
# {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}

# %%
print(GS.best_params_)
# Out:
# {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}

# %%
from sklearn.svm import SVC
svm_classifier = SVC(random_state=42, C=1, gamma='scale', kernel='linear')
svm_classifier.fit(x_train, y_train)

y_pred = svm_classifier.predict(x_test)

# %% [markdown]
# # Score Support Vector Machine with tag

# %%
print(all_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.57      0.56      0.56      1725
#     Positive       0.58      0.60      0.59      1776
#
#     accuracy                           0.58      3501
#    macro avg       0.58      0.58      0.58      3501
# weighted avg       0.58      0.58      0.58      3501

# %%
import pickle

# save the model to disk
filename = 'SVM_Tag.pkl'
pickle.dump(svm_classifier, open(filename, 'wb'))

# %%
from sklearn.metrics import f1_score

# Menghitung F1-score dengan label positif "1"
f1 = f1_score(y_test, y_pred, pos_label='Negative')

# Mencetak hasil
print("F1 Score:", f1)
# Out:
# F1 Score: 0.5636203349985307
