# %% [markdown]
# # Dataframe

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('https://raw.githubusercontent.com/ghazafm/SocialMediaSentiment/main/preprocessing/Training/data/clean/regular/gabungan.csv')
df = df.dropna()

# %%
df
# Out:
#                                                    Tweet     label  \
# 0                                   info  anies presiden  Positive
# 1      politisi partai gerindra sandiaga uno menjawab...  Positive
# 2       lanjut pak anies kita kawal sampai jadi presiden  Positive
# 3      semoga allah swt menyelamatkan bangsa dan nega...  Positive
# 4      chotimah kasian ya pa anies makanya sudah teka...  Positive
# ...                                                  ...       ...
# 24713           pa ganjar pranowo nex presiden indonesia  Negative
# 24714  rt ganjaristdltras ganjarist deltras jatim sia...  Negative
# 24715                    artinya ganjar pranowo presiden  Negative
# 24716  semakin banyak rakyat yang siap mendukung ganj...  Negative
# 24717  selamat hari penerbangan nasional oktober terb...  Negative
#
#                                                  no_alay  \
# 0                                    info anies presiden
# 1      politisi partai gerindra sandiaga uno menjawab...
# 2       lanjut pak anies kita kawal sampai jadi presiden
# 3      semoga allah swt menyelamatkan bangsa dan nega...
# 4      chotimah kasihan ya apa anies makanya sudah te...
# ...                                                  ...
# 24713          apa ganjar pranowo nex presiden indonesia
# 24714  rt ganjaristdltras ganjarist deltras jatim sia...
# 24715                    artinya ganjar pranowo presiden
# 24716  semakin banyak rakyat yang siap mendukung ganj...
# 24717  selamat hari penerbangan nasional oktober terb...
#
#                                             clean_manual  \
# 0                                                   info
# 1      politisi menjawab soal diduetkan kembali denga...
# 2                           lanjut pak kita kawal sampai
# 3      swt menyelamatkan bangsa dan negara republik d...
# 4           kasihan ya makanya sudah tekad keluarga saya
# ...                                                  ...
# 24713                                                nex
# 24714    rt ganjaristdltras ganjarist deltras jatim siap
# 24715                                            artinya
# 24716  semakin yang siap untuk sebagai ke selamat ula...
# 24717  selamat penerbangan nasional oktober terbangla...
#
#                                                  stemmed  \
# 0                                                   info
# 1      politis jawab soal duet kembali dengan mantan ...
# 2                           lanjut pak kita kawal sampai
# 3      swt selamat bangsa dan negara republik dari pa...
# 4           kasihan ya makanya sudah tekad keluarga saya
# ...                                                  ...
# 24713                                                nex
# 24714    rt ganjaristdltras ganjarist deltras jatim siap
# 24715                                               arti
# 24716  makin yang siap untuk bagai ke selamat ulang p...
# 24717  selamat terbang nasional oktober terbang tingg...
#
#                                             no_stopwords
# 0                                                   info
# 1      politis jawab soal duet dengan mantan dki jaka...
# 2                                       lanjut pak kawal
# 3      swt selamat bangsa negara republik para penghi...
# 4                         kasihan makanya tekad keluarga
# ...                                                  ...
# 24713                                                nex
# 24714    rt ganjaristdltras ganjarist deltras jatim siap
# 24715                                               arti
# 24716           makin siap bagai selamat ulang pak tuhan
# 24717  selamat terbang nasional oktober terbang tingg...
#
# [24384 rows x 6 columns]

# %% [markdown]
# # Function

# %%
# label encoder
def label_encoder(y):
    from sklearn.preprocessing import LabelEncoder
    le = LabelEncoder()
    y = le.fit_transform(y)
    return y

# under dan over sampling
def undersampling(x, y):
    from imblearn.under_sampling import RandomUnderSampler
    rus = RandomUnderSampler()
    x, y = rus.fit_resample(x.values.reshape(-1,1),y)
    x = x.flatten()
    return x, y

def oversampling(x, y):
    from imblearn.over_sampling import RandomOverSampler
    ros = RandomOverSampler()
    x, y = ros.fit_resample(x.values.reshape(-1,1),y)
    x = x.flatten()
    return x, y

# train test split
def bagi_data(x, y):
    from sklearn.model_selection import train_test_split
    x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=2)
    return x_train, x_test, y_train, y_test

# cetak csv
def cetak_csv(data):
    data.to_csv('name.csv')

# Vectorizing
def tfidf_vec(x_train, x_test):
    from sklearn.feature_extraction.text import TfidfVectorizer
    vectorizer = TfidfVectorizer()
    x_train = vectorizer.fit_transform(x_train)
    x_test = vectorizer.transform(x_test)
    return x_train, x_test

def count_vec(x_train, x_test):
    from sklearn.feature_extraction.text import CountVectorizer
    vectorizer = CountVectorizer()
    x_train = vectorizer.fit_transform(x_train)
    x_test = vectorizer.transform(x_test)
    return x_train, x_test

# Metric Scorer
def accuracy_score(y_test, y_pred):
    from sklearn.metrics import accuracy_score
    
    accuracy = accuracy_score(y_test, y_pred)
    return accuracy

def f1_score_pos(x,y):
    from sklearn.metrics import f1_score
    f1 = f1_score(x,y,pos_label='Positive')
    return f1
def f1_score_neg(x,y):
    from sklearn.metrics import f1_score
    f1 = f1_score(x,y,pos_label='Negative')
    return f1

def precission_pos(x,y):
    from sklearn.metrics import precision_score
    precision = precision_score(x,y,pos_label='Positive')
    return precision
def precission_neg(x,y):
    from sklearn.metrics import precision_score
    precision = precision_score(x,y,pos_label='Negative')
    return precision

def recall_pos(x,y):
    from sklearn.metrics import recall_score
    recall = recall_score(x,y,'Positive')
    return recall
def recall_neg(x,y):
    from sklearn.metrics import recall_score
    recall = recall_score(x,y,'Negative')
    return recall

def all_report (x,y):
    from sklearn.metrics import classification_report
    report = classification_report(x,y)
    return report

# %% [markdown]
# # splitting & under sampling

# %%
x = df['no_stopwords']
y = df['label']

x, y = undersampling(x, y)

x_train, x_test, y_train, y_test = bagi_data(x, y)

y.value_counts()
# Out:
# label
# Negative    8770
# Positive    8770
# Name: count, dtype: int64

# %% [markdown]
# # TF-idf vectorizing

# %%
x_train, x_test = tfidf_vec(x_train, x_test)

# %% [markdown]
# # Modeling

# %%
from sklearn.svm import SVC
svm_classifier = SVC(random_state=42)

# %%
parameter = {
    "C": [0.1, 1, 10, 100, 1000],
    "kernel": ["linear", "rbf", "poly", "sigmoid"],
    "gamma": ["scale", "auto"]
}

from sklearn.model_selection import GridSearchCV
GS = GridSearchCV(estimator = svm_classifier,
                    param_grid = parameter,
                    scoring = 'f1_macro', 
                    refit = False,
                    cv=5,
                    verbose = 3)

GS.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [CV 1/5] END .C=0.1, gamma=scale, kernel=linear;, score=0.582 total time=  34.6s
# [CV 2/5] END .C=0.1, gamma=scale, kernel=linear;, score=0.560 total time=  36.8s
# [CV 3/5] END .C=0.1, gamma=scale, kernel=linear;, score=0.581 total time=  34.5s
# [CV 4/5] END .C=0.1, gamma=scale, kernel=linear;, score=0.558 total time=  34.5s
# [CV 5/5] END .C=0.1, gamma=scale, kernel=linear;, score=0.578 total time=  34.7s
# [CV 1/5] END ....C=0.1, gamma=scale, kernel=rbf;, score=0.553 total time=  39.2s
# [CV 2/5] END ....C=0.1, gamma=scale, kernel=rbf;, score=0.561 total time=  41.8s
# [CV 3/5] END ....C=0.1, gamma=scale, kernel=rbf;, score=0.560 total time=  41.5s
# [CV 4/5] END ....C=0.1, gamma=scale, kernel=rbf;, score=0.512 total time=  49.2s
# [CV 5/5] END ....C=0.1, gamma=scale, kernel=rbf;, score=0.564 total time=  44.4s
# [CV 1/5] END ...C=0.1, gamma=scale, kernel=poly;, score=0.366 total time=  35.1s
# [CV 2/5] END ...C=0.1, gamma=scale, kernel=poly;, score=0.365 total time=  36.4s
# [CV 3/5] END ...C=0.1, gamma=scale, kernel=poly;, score=0.362 total time=  35.6s
# [CV 4/5] END ...C=0.1, gamma=scale, kernel=poly;, score=0.360 total time=  35.2s
# [CV 5/5] END ...C=0.1, gamma=scale, kernel=poly;, score=0.359 total time=  35.1s
# [CV 1/5] END C=0.1, gamma=scale, kernel=sigmoid;, score=0.580 total time=  38.9s
# [CV 2/5] END C=0.1, gamma=scale, kernel=sigmoid;, score=0.563 total time=  36.5s
# [CV 3/5] END C=0.1, gamma=scale, kernel=sigmoid;, score=0.578 total time=  36.1s
# [CV 4/5] END C=0.1, gamma=scale, kernel=sigmoid;, score=0.558 total time=  36.2s
# [CV 5/5] END C=0.1, gamma=scale, kernel=sigmoid;, score=0.578 total time=  36.5s
# [CV 1/5] END ..C=0.1, gamma=auto, kernel=linear;, score=0.582 total time=  33.4s
# [CV 2/5] END ..C=0.1, gamma=auto, kernel=linear;, score=0.560 total time=  32.3s
# [CV 3/5] END ..C=0.1, gamma=auto, kernel=linear;, score=0.581 total time=  33.0s
# [CV 4/5] END ..C=0.1, gamma=auto, kernel=linear;, score=0.558 total time=  34.1s
# [CV 5/5] END ..C=0.1, gamma=auto, kernel=linear;, score=0.578 total time=  33.2s
# [CV 1/5] END .....C=0.1, gamma=auto, kernel=rbf;, score=0.335 total time=  39.3s
# [CV 2/5] END .....C=0.1, gamma=auto, kernel=rbf;, score=0.335 total time=  38.8s
# [CV 3/5] END .....C=0.1, gamma=auto, kernel=rbf;, score=0.335 total time=  38.9s
# [CV 4/5] END .....C=0.1, gamma=auto, kernel=rbf;, score=0.335 total time=  38.7s
# [CV 5/5] END .....C=0.1, gamma=auto, kernel=rbf;, score=0.335 total time=  39.7s
# [CV 1/5] END ....C=0.1, gamma=auto, kernel=poly;, score=0.335 total time=  35.3s
# [CV 2/5] END ....C=0.1, gamma=auto, kernel=poly;, score=0.335 total time=  36.0s
# [CV 3/5] END ....C=0.1, gamma=auto, kernel=poly;, score=0.335 total time=  34.7s
# [CV 4/5] END ....C=0.1, gamma=auto, kernel=poly;, score=0.335 total time=  34.5s
# [CV 5/5] END ....C=0.1, gamma=auto, kernel=poly;, score=0.335 total time=  34.5s
# [CV 1/5] END .C=0.1, gamma=auto, kernel=sigmoid;, score=0.335 total time=  37.3s
# [CV 2/5] END .C=0.1, gamma=auto, kernel=sigmoid;, score=0.335 total time=  36.5s
# [CV 3/5] END .C=0.1, gamma=auto, kernel=sigmoid;, score=0.335 total time=  35.9s
# [CV 4/5] END .C=0.1, gamma=auto, kernel=sigmoid;, score=0.335 total time=  36.7s
# [CV 5/5] END .C=0.1, gamma=auto, kernel=sigmoid;, score=0.335 total time=  36.8s
# [CV 1/5] END ...C=1, gamma=scale, kernel=linear;, score=0.575 total time=  31.9s
# [CV 2/5] END ...C=1, gamma=scale, kernel=linear;, score=0.557 total time=  32.5s
# [CV 3/5] END ...C=1, gamma=scale, kernel=linear;, score=0.577 total time=  31.7s
# [CV 4/5] END ...C=1, gamma=scale, kernel=linear;, score=0.576 total time=  30.6s
# [CV 5/5] END ...C=1, gamma=scale, kernel=linear;, score=0.581 total time=  30.7s
# [CV 1/5] END ......C=1, gamma=scale, kernel=rbf;, score=0.576 total time=  38.9s
# [CV 2/5] END ......C=1, gamma=scale, kernel=rbf;, score=0.561 total time=  41.4s
# [CV 3/5] END ......C=1, gamma=scale, kernel=rbf;, score=0.572 total time=  39.9s
# [CV 4/5] END ......C=1, gamma=scale, kernel=rbf;, score=0.577 total time=  42.0s
# [CV 5/5] END ......C=1, gamma=scale, kernel=rbf;, score=0.576 total time=  37.9s
# [CV 1/5] END .....C=1, gamma=scale, kernel=poly;, score=0.564 total time=  56.9s
# [CV 2/5] END .....C=1, gamma=scale, kernel=poly;, score=0.550 total time=  53.1s
# [CV 3/5] END .....C=1, gamma=scale, kernel=poly;, score=0.556 total time=  52.5s
# [CV 4/5] END .....C=1, gamma=scale, kernel=poly;, score=0.567 total time=  51.6s
# [CV 5/5] END .....C=1, gamma=scale, kernel=poly;, score=0.567 total time=  49.6s
# [CV 1/5] END ..C=1, gamma=scale, kernel=sigmoid;, score=0.575 total time=  30.8s
# [CV 2/5] END ..C=1, gamma=scale, kernel=sigmoid;, score=0.561 total time=  29.4s
# [CV 3/5] END ..C=1, gamma=scale, kernel=sigmoid;, score=0.570 total time=  31.7s
# [CV 4/5] END ..C=1, gamma=scale, kernel=sigmoid;, score=0.573 total time=  36.1s
# [CV 5/5] END ..C=1, gamma=scale, kernel=sigmoid;, score=0.582 total time=  34.5s
# [CV 1/5] END ....C=1, gamma=auto, kernel=linear;, score=0.575 total time=  29.2s
# [CV 2/5] END ....C=1, gamma=auto, kernel=linear;, score=0.557 total time=  29.0s
# [CV 3/5] END ....C=1, gamma=auto, kernel=linear;, score=0.577 total time=  29.2s
# [CV 4/5] END ....C=1, gamma=auto, kernel=linear;, score=0.576 total time=  23.8s
# [CV 5/5] END ....C=1, gamma=auto, kernel=linear;, score=0.581 total time=  12.6s
# [CV 1/5] END .......C=1, gamma=auto, kernel=rbf;, score=0.335 total time=  17.5s
# [CV 2/5] END .......C=1, gamma=auto, kernel=rbf;, score=0.335 total time=  20.9s
# [CV 3/5] END .......C=1, gamma=auto, kernel=rbf;, score=0.335 total time=  15.7s
# [CV 4/5] END .......C=1, gamma=auto, kernel=rbf;, score=0.335 total time=  26.4s
# [CV 5/5] END .......C=1, gamma=auto, kernel=rbf;, score=0.335 total time=  15.5s
# [CV 1/5] END ......C=1, gamma=auto, kernel=poly;, score=0.335 total time=  14.1s
# [CV 2/5] END ......C=1, gamma=auto, kernel=poly;, score=0.335 total time=  14.3s
# [CV 3/5] END ......C=1, gamma=auto, kernel=poly;, score=0.335 total time=  15.6s
# [CV 4/5] END ......C=1, gamma=auto, kernel=poly;, score=0.335 total time=  16.1s
# [CV 5/5] END ......C=1, gamma=auto, kernel=poly;, score=0.335 total time=  16.3s
# [CV 1/5] END ...C=1, gamma=auto, kernel=sigmoid;, score=0.335 total time=  17.2s
# [CV 2/5] END ...C=1, gamma=auto, kernel=sigmoid;, score=0.335 total time=  17.1s
# [CV 3/5] END ...C=1, gamma=auto, kernel=sigmoid;, score=0.335 total time=  17.5s
# [CV 4/5] END ...C=1, gamma=auto, kernel=sigmoid;, score=0.335 total time=  18.5s
# [CV 5/5] END ...C=1, gamma=auto, kernel=sigmoid;, score=0.335 total time=  19.1s
# [CV 1/5] END ..C=10, gamma=scale, kernel=linear;, score=0.567 total time=  59.2s
# [CV 2/5] END ..C=10, gamma=scale, kernel=linear;, score=0.551 total time=  50.9s
# [CV 3/5] END ..C=10, gamma=scale, kernel=linear;, score=0.557 total time=  53.1s
# [CV 4/5] END ..C=10, gamma=scale, kernel=linear;, score=0.552 total time=  38.4s
# [CV 5/5] END ..C=10, gamma=scale, kernel=linear;, score=0.559 total time=  31.2s
# [CV 1/5] END .....C=10, gamma=scale, kernel=rbf;, score=0.563 total time=  45.6s
# [CV 2/5] END .....C=10, gamma=scale, kernel=rbf;, score=0.556 total time=  45.5s
# [CV 3/5] END .....C=10, gamma=scale, kernel=rbf;, score=0.563 total time=  45.6s
# [CV 4/5] END .....C=10, gamma=scale, kernel=rbf;, score=0.563 total time=  45.7s
# [CV 5/5] END .....C=10, gamma=scale, kernel=rbf;, score=0.571 total time=  46.6s
# [CV 1/5] END ....C=10, gamma=scale, kernel=poly;, score=0.551 total time=  36.2s
# [CV 2/5] END ....C=10, gamma=scale, kernel=poly;, score=0.542 total time=  33.5s
# [CV 3/5] END ....C=10, gamma=scale, kernel=poly;, score=0.559 total time=  34.7s
# [CV 4/5] END ....C=10, gamma=scale, kernel=poly;, score=0.566 total time=  33.6s
# [CV 5/5] END ....C=10, gamma=scale, kernel=poly;, score=0.561 total time=  33.5s
# [CV 1/5] END .C=10, gamma=scale, kernel=sigmoid;, score=0.568 total time=  22.0s
# [CV 2/5] END .C=10, gamma=scale, kernel=sigmoid;, score=0.540 total time=  23.8s
# [CV 3/5] END .C=10, gamma=scale, kernel=sigmoid;, score=0.556 total time=  20.7s
# [CV 4/5] END .C=10, gamma=scale, kernel=sigmoid;, score=0.567 total time=  29.9s
# [CV 5/5] END .C=10, gamma=scale, kernel=sigmoid;, score=0.568 total time=  31.6s
# [CV 1/5] END ...C=10, gamma=auto, kernel=linear;, score=0.567 total time=  33.6s
# [CV 2/5] END ...C=10, gamma=auto, kernel=linear;, score=0.551 total time=  32.0s
# [CV 3/5] END ...C=10, gamma=auto, kernel=linear;, score=0.557 total time=  34.1s
# [CV 4/5] END ...C=10, gamma=auto, kernel=linear;, score=0.552 total time=  34.6s
# [CV 5/5] END ...C=10, gamma=auto, kernel=linear;, score=0.559 total time=  33.6s
# [CV 1/5] END ......C=10, gamma=auto, kernel=rbf;, score=0.335 total time=  17.3s
# [CV 2/5] END ......C=10, gamma=auto, kernel=rbf;, score=0.335 total time=  16.7s
# [CV 3/5] END ......C=10, gamma=auto, kernel=rbf;, score=0.335 total time=  16.5s
# [CV 4/5] END ......C=10, gamma=auto, kernel=rbf;, score=0.335 total time=  16.5s
# [CV 5/5] END ......C=10, gamma=auto, kernel=rbf;, score=0.335 total time=  16.6s
# [CV 1/5] END .....C=10, gamma=auto, kernel=poly;, score=0.335 total time=  15.7s
# [CV 2/5] END .....C=10, gamma=auto, kernel=poly;, score=0.335 total time=  16.3s
# [CV 3/5] END .....C=10, gamma=auto, kernel=poly;, score=0.335 total time=  16.8s
# [CV 4/5] END .....C=10, gamma=auto, kernel=poly;, score=0.335 total time=  16.3s
# [CV 5/5] END .....C=10, gamma=auto, kernel=poly;, score=0.335 total time=  15.2s
# [CV 1/5] END ..C=10, gamma=auto, kernel=sigmoid;, score=0.335 total time=  15.9s
# [CV 2/5] END ..C=10, gamma=auto, kernel=sigmoid;, score=0.335 total time=  15.8s
# [CV 3/5] END ..C=10, gamma=auto, kernel=sigmoid;, score=0.335 total time=  15.5s
# [CV 4/5] END ..C=10, gamma=auto, kernel=sigmoid;, score=0.335 total time=  14.6s
# [CV 5/5] END ..C=10, gamma=auto, kernel=sigmoid;, score=0.335 total time=  15.0s
# [CV 1/5] END .C=100, gamma=scale, kernel=linear;, score=0.556 total time= 1.7min
# [CV 2/5] END .C=100, gamma=scale, kernel=linear;, score=0.537 total time= 1.5min
# [CV 3/5] END .C=100, gamma=scale, kernel=linear;, score=0.550 total time= 1.3min
# [CV 4/5] END .C=100, gamma=scale, kernel=linear;, score=0.540 total time= 1.3min
# [CV 5/5] END .C=100, gamma=scale, kernel=linear;, score=0.534 total time= 1.4min
# [CV 1/5] END ....C=100, gamma=scale, kernel=rbf;, score=0.565 total time=  35.5s
# [CV 2/5] END ....C=100, gamma=scale, kernel=rbf;, score=0.553 total time=  33.9s
# [CV 3/5] END ....C=100, gamma=scale, kernel=rbf;, score=0.562 total time=  34.9s
# [CV 4/5] END ....C=100, gamma=scale, kernel=rbf;, score=0.565 total time=  36.3s
# [CV 5/5] END ....C=100, gamma=scale, kernel=rbf;, score=0.569 total time=  37.3s
# [CV 1/5] END ...C=100, gamma=scale, kernel=poly;, score=0.550 total time=  30.4s
# [CV 2/5] END ...C=100, gamma=scale, kernel=poly;, score=0.543 total time=  30.4s
# [CV 3/5] END ...C=100, gamma=scale, kernel=poly;, score=0.559 total time=  28.1s
# [CV 4/5] END ...C=100, gamma=scale, kernel=poly;, score=0.566 total time=  27.4s
# [CV 5/5] END ...C=100, gamma=scale, kernel=poly;, score=0.559 total time=  26.7s
# [CV 1/5] END C=100, gamma=scale, kernel=sigmoid;, score=0.555 total time=  25.7s
# [CV 2/5] END C=100, gamma=scale, kernel=sigmoid;, score=0.534 total time=  32.3s
# [CV 3/5] END C=100, gamma=scale, kernel=sigmoid;, score=0.556 total time=  19.0s
# [CV 4/5] END C=100, gamma=scale, kernel=sigmoid;, score=0.539 total time=  20.5s
# [CV 5/5] END C=100, gamma=scale, kernel=sigmoid;, score=0.540 total time=  26.9s
# [CV 1/5] END ..C=100, gamma=auto, kernel=linear;, score=0.556 total time= 1.4min
# [CV 2/5] END ..C=100, gamma=auto, kernel=linear;, score=0.537 total time= 1.4min
# [CV 3/5] END ..C=100, gamma=auto, kernel=linear;, score=0.550 total time= 1.4min
# [CV 4/5] END ..C=100, gamma=auto, kernel=linear;, score=0.540 total time= 1.4min
# [CV 5/5] END ..C=100, gamma=auto, kernel=linear;, score=0.534 total time= 1.6min
# [CV 1/5] END .....C=100, gamma=auto, kernel=rbf;, score=0.335 total time=  13.8s
# [CV 2/5] END .....C=100, gamma=auto, kernel=rbf;, score=0.335 total time=  14.8s
# [CV 3/5] END .....C=100, gamma=auto, kernel=rbf;, score=0.335 total time=  14.6s
# [CV 4/5] END .....C=100, gamma=auto, kernel=rbf;, score=0.335 total time=  14.7s
# [CV 5/5] END .....C=100, gamma=auto, kernel=rbf;, score=0.335 total time=  14.4s
# [CV 1/5] END ....C=100, gamma=auto, kernel=poly;, score=0.335 total time=  13.2s
# [CV 2/5] END ....C=100, gamma=auto, kernel=poly;, score=0.335 total time=  13.4s
# [CV 3/5] END ....C=100, gamma=auto, kernel=poly;, score=0.335 total time=  13.7s
# [CV 4/5] END ....C=100, gamma=auto, kernel=poly;, score=0.335 total time=  13.7s
# [CV 5/5] END ....C=100, gamma=auto, kernel=poly;, score=0.335 total time=  13.2s
# [CV 1/5] END .C=100, gamma=auto, kernel=sigmoid;, score=0.335 total time=  14.4s
# [CV 2/5] END .C=100, gamma=auto, kernel=sigmoid;, score=0.335 total time=  13.1s
# [CV 3/5] END .C=100, gamma=auto, kernel=sigmoid;, score=0.335 total time=  12.8s
# [CV 4/5] END .C=100, gamma=auto, kernel=sigmoid;, score=0.335 total time=  13.5s
# [CV 5/5] END .C=100, gamma=auto, kernel=sigmoid;, score=0.335 total time=  14.5s
# [CV 1/5] END C=1000, gamma=scale, kernel=linear;, score=0.550 total time= 9.6min
# [CV 2/5] END C=1000, gamma=scale, kernel=linear;, score=0.538 total time= 8.2min
# [CV 3/5] END C=1000, gamma=scale, kernel=linear;, score=0.534 total time= 9.1min
# [CV 4/5] END C=1000, gamma=scale, kernel=linear;, score=0.541 total time= 8.3min
# [CV 5/5] END C=1000, gamma=scale, kernel=linear;, score=0.538 total time= 9.2min
# [CV 1/5] END ...C=1000, gamma=scale, kernel=rbf;, score=0.563 total time=  33.9s
# [CV 2/5] END ...C=1000, gamma=scale, kernel=rbf;, score=0.553 total time=  34.3s
# [CV 3/5] END ...C=1000, gamma=scale, kernel=rbf;, score=0.562 total time=  34.7s
# [CV 4/5] END ...C=1000, gamma=scale, kernel=rbf;, score=0.563 total time=  34.7s
# [CV 5/5] END ...C=1000, gamma=scale, kernel=rbf;, score=0.569 total time=  34.6s
# [CV 1/5] END ..C=1000, gamma=scale, kernel=poly;, score=0.549 total time=  26.4s
# [CV 2/5] END ..C=1000, gamma=scale, kernel=poly;, score=0.543 total time=  26.8s
# [CV 3/5] END ..C=1000, gamma=scale, kernel=poly;, score=0.559 total time=  27.4s
# [CV 4/5] END ..C=1000, gamma=scale, kernel=poly;, score=0.569 total time=  27.3s
# [CV 5/5] END ..C=1000, gamma=scale, kernel=poly;, score=0.559 total time=  26.0s
# [CV 1/5] END C=1000, gamma=scale, kernel=sigmoid;, score=0.529 total time=  20.3s
# [CV 2/5] END C=1000, gamma=scale, kernel=sigmoid;, score=0.540 total time=  26.9s
# [CV 3/5] END C=1000, gamma=scale, kernel=sigmoid;, score=0.560 total time=  34.8s
# [CV 4/5] END C=1000, gamma=scale, kernel=sigmoid;, score=0.545 total time=  31.5s
# [CV 5/5] END C=1000, gamma=scale, kernel=sigmoid;, score=0.552 total time=  39.8s
# [CV 1/5] END .C=1000, gamma=auto, kernel=linear;, score=0.550 total time= 9.0min
# [CV 2/5] END .C=1000, gamma=auto, kernel=linear;, score=0.538 total time= 9.0min
# [CV 3/5] END .C=1000, gamma=auto, kernel=linear;, score=0.534 total time= 9.8min
# [CV 4/5] END .C=1000, gamma=auto, kernel=linear;, score=0.541 total time= 9.7min
# [CV 5/5] END .C=1000, gamma=auto, kernel=linear;, score=0.538 total time=10.6min
# [CV 1/5] END ....C=1000, gamma=auto, kernel=rbf;, score=0.585 total time=  12.9s
# [CV 2/5] END ....C=1000, gamma=auto, kernel=rbf;, score=0.563 total time=  12.6s
# [CV 3/5] END ....C=1000, gamma=auto, kernel=rbf;, score=0.581 total time=  12.7s
# [CV 4/5] END ....C=1000, gamma=auto, kernel=rbf;, score=0.568 total time=  12.4s
# [CV 5/5] END ....C=1000, gamma=auto, kernel=rbf;, score=0.585 total time=  13.1s
# [CV 1/5] END ...C=1000, gamma=auto, kernel=poly;, score=0.335 total time=  12.0s
# [CV 2/5] END ...C=1000, gamma=auto, kernel=poly;, score=0.335 total time=  12.1s
# [CV 3/5] END ...C=1000, gamma=auto, kernel=poly;, score=0.335 total time=  12.1s
# [CV 4/5] END ...C=1000, gamma=auto, kernel=poly;, score=0.335 total time=  12.2s
# [CV 5/5] END ...C=1000, gamma=auto, kernel=poly;, score=0.335 total time=  12.2s
# [CV 1/5] END C=1000, gamma=auto, kernel=sigmoid;, score=0.581 total time=  13.1s
# [CV 2/5] END C=1000, gamma=auto, kernel=sigmoid;, score=0.566 total time=  12.7s
# [CV 3/5] END C=1000, gamma=auto, kernel=sigmoid;, score=0.574 total time=  12.7s
# [CV 4/5] END C=1000, gamma=auto, kernel=sigmoid;, score=0.559 total time=  12.9s
# [CV 5/5] END C=1000, gamma=auto, kernel=sigmoid;, score=0.585 total time=  13.0s
# GridSearchCV(cv=5, estimator=SVC(random_state=42),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'rbf', 'poly', 'sigmoid']},
#              refit=False, scoring='f1_macro', verbose=3)

# %%
GS.best_params_
# Out:
# {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}

# %%
from sklearn.svm import SVC
svm_classifier = SVC(random_state=42,C=1000,gamma='auto',kernel='rbf')
y_pred = svm_classifier.fit(x_train, y_train).predict(x_test)

# %% [markdown]
# # Score Support Vector Machine untag

# %%
print(all_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.57      0.66      0.61      1708
#     Positive       0.62      0.53      0.57      1800
#
#     accuracy                           0.59      3508
#    macro avg       0.60      0.59      0.59      3508
# weighted avg       0.60      0.59      0.59      3508

# %%
import pickle

# save the model to disk
filename = 'SVM_Untag.pkl'
pickle.dump(svm_classifier, open(filename, 'wb'))

# %%
# from sklearn.metrics import f1_score

# # Menghitung F1-score dengan label positif "1"
# f1 = f1_score(y_test, y_pred, pos_label='Negative')

# # Mencetak hasil
# print("F1 Score:", f1)
